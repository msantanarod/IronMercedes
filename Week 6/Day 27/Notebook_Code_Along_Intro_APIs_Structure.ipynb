# %% [markdown]
#  ### Sending requests

# %%
import requests

google = requests.get("https://developers.google.com")
print("Google:", google.status_code)

NBA = response = requests.get("https://api.sportsdata.io/api/nba/fantasy/json/CurrentSeason")
print("NBA:", NBA.status_code)

rotten_tomato = requests.get("http://api.rottentomatoes.com/api/public/v1.0/lists/movies/box_office.json")
print("Rotten Tomatoes:", rotten_tomato.status_code)
# Out:
# Google: 200
# NBA: 401
# Rotten Tomatoes: 403

# %% [markdown]
# Check [here](https://www.restapitutorial.com/httpstatuscodes.html) the meaning of each error code.

# %% [markdown]
# ### json response

# %%
# install if needed
import json

response = requests.get("https://jsonplaceholder.typicode.com/todos")
print(response.status_code)
results = response.json()
results[0]["title"]
# Out:
# 200
# 'delectus aut autem'

# %%
import pandas as pd
# json to pandas dataframe

# %% [markdown]
# ### GitHub API
#
# Docs here: https://docs.github.com/en/free-pro-team@latest/rest/reference/activity

# %%
response = requests.get('https://api.github.com/events')

# %%
response.json()
# Out:
# [{'id': '19030667340',
#   'type': 'PushEvent',
#   'actor': {'id': 7842,
#    'login': 'prabhu',
#    'display_login': 'prabhu',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/prabhu',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7842?'},
#   'repo': {'id': 226311004,
#    'name': 'AppThreat/cve_feeds',
#    'url': 'https://api.github.com/repos/AppThreat/cve_feeds'},
#   'payload': {'push_id': 8461328744,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'c8f4fb8ebd3b55cbab8aea8440eae1756ba361e9',
#    'before': '67826d4467afdb31a49639df16a508104ad99c50',
#    'commits': [{'sha': 'c8f4fb8ebd3b55cbab8aea8440eae1756ba361e9',
#      'author': {'email': 'prabhu@users.noreply.github.com', 'name': 'prabhu'},
#      'message': 'Auto Pushed From Action',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/AppThreat/cve_feeds/commits/c8f4fb8ebd3b55cbab8aea8440eae1756ba361e9'}]},
#   'public': True,
#   'created_at': '2021-11-24T10:19:40Z',
#   'org': {'id': 58593322,
#    'login': 'AppThreat',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/AppThreat',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58593322?'}},
#  {'id': '19030667380',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 548849,
#    'login': 'mtias',
#    'display_login': 'mtias',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mtias',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/548849?'},
#   'repo': {'id': 80862584,
#    'name': 'WordPress/gutenberg',
#    'url': 'https://api.github.com/repos/WordPress/gutenberg'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/WordPress/gutenberg/issues/36718',
#     'repository_url': 'https://api.github.com/repos/WordPress/gutenberg',
#     'labels_url': 'https://api.github.com/repos/WordPress/gutenberg/issues/36718/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/WordPress/gutenberg/issues/36718/comments',
#     'events_url': 'https://api.github.com/repos/WordPress/gutenberg/issues/36718/events',
#     'html_url': 'https://github.com/WordPress/gutenberg/pull/36718',
#     'id': 1059886873,
#     'node_id': 'PR_kwDOBNHdeM4u1p9j',
#     'number': 36718,
#     'title': 'Add elements support to the typography panel in global styles',
#     'user': {'login': 'youknowriad',
#      'id': 272444,
#      'node_id': 'MDQ6VXNlcjI3MjQ0NA==',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/272444?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/youknowriad',
#      'html_url': 'https://github.com/youknowriad',
#      'followers_url': 'https://api.github.com/users/youknowriad/followers',
#      'following_url': 'https://api.github.com/users/youknowriad/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/youknowriad/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/youknowriad/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/youknowriad/subscriptions',
#      'organizations_url': 'https://api.github.com/users/youknowriad/orgs',
#      'repos_url': 'https://api.github.com/users/youknowriad/repos',
#      'events_url': 'https://api.github.com/users/youknowriad/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/youknowriad/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 1353182771,
#       'node_id': 'MDU6TGFiZWwxMzUzMTgyNzcx',
#       'url': 'https://api.github.com/repos/WordPress/gutenberg/labels/Backport%20to%20WP%20Beta/RC',
#       'name': 'Backport to WP Beta/RC',
#       'color': '491d8e',
#       'default': False,
#       'description': "PRs to be back-ported to the WordPress major release that's currently in beta."},
#      {'id': 1800807983,
#       'node_id': 'MDU6TGFiZWwxODAwODA3OTgz',
#       'url': 'https://api.github.com/repos/WordPress/gutenberg/labels/Global%20Styles',
#       'name': 'Global Styles',
#       'color': '2100b7',
#       'default': False,
#       'description': ''}],
#     'state': 'open',
#     'locked': False,
#     'assignee': {'login': 'youknowriad',
#      'id': 272444,
#      'node_id': 'MDQ6VXNlcjI3MjQ0NA==',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/272444?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/youknowriad',
#      'html_url': 'https://github.com/youknowriad',
#      'followers_url': 'https://api.github.com/users/youknowriad/followers',
#      'following_url': 'https://api.github.com/users/youknowriad/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/youknowriad/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/youknowriad/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/youknowriad/subscriptions',
#      'organizations_url': 'https://api.github.com/users/youknowriad/orgs',
#      'repos_url': 'https://api.github.com/users/youknowriad/repos',
#      'events_url': 'https://api.github.com/users/youknowriad/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/youknowriad/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'assignees': [{'login': 'youknowriad',
#       'id': 272444,
#       'node_id': 'MDQ6VXNlcjI3MjQ0NA==',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/272444?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/youknowriad',
#       'html_url': 'https://github.com/youknowriad',
#       'followers_url': 'https://api.github.com/users/youknowriad/followers',
#       'following_url': 'https://api.github.com/users/youknowriad/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/youknowriad/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/youknowriad/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/youknowriad/subscriptions',
#       'organizations_url': 'https://api.github.com/users/youknowriad/orgs',
#       'repos_url': 'https://api.github.com/users/youknowriad/repos',
#       'events_url': 'https://api.github.com/users/youknowriad/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/youknowriad/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'milestone': None,
#     'comments': 15,
#     'created_at': '2021-11-22T09:13:25Z',
#     'updated_at': '2021-11-24T10:19:40Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'active_lock_reason': None,
#     'draft': False,
#     'pull_request': {'url': 'https://api.github.com/repos/WordPress/gutenberg/pulls/36718',
#      'html_url': 'https://github.com/WordPress/gutenberg/pull/36718',
#      'diff_url': 'https://github.com/WordPress/gutenberg/pull/36718.diff',
#      'patch_url': 'https://github.com/WordPress/gutenberg/pull/36718.patch',
#      'merged_at': None},
#     'body': "closes #36546 \r\n\r\nThis PR adds an element selector to the typography panel to match the proposed global styles design.\r\nThe panel is only enabled in the root of the global styles for the moment. (We don't have a clear way to say which blocks supports which element)\r\n\r\n**Notes**\r\n\r\nIf we want to add headings there, I think we'd need a row per heading level if I'm not wrong. right @jorgefilipecosta @oandregal ?",
#     'reactions': {'url': 'https://api.github.com/repos/WordPress/gutenberg/issues/36718/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/WordPress/gutenberg/issues/36718/timeline',
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/WordPress/gutenberg/issues/comments/977734709',
#     'html_url': 'https://github.com/WordPress/gutenberg/pull/36718#issuecomment-977734709',
#     'issue_url': 'https://api.github.com/repos/WordPress/gutenberg/issues/36718',
#     'id': 977734709,
#     'node_id': 'IC_kwDOBNHdeM46Rww1',
#     'user': {'login': 'mtias',
#      'id': 548849,
#      'node_id': 'MDQ6VXNlcjU0ODg0OQ==',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/548849?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/mtias',
#      'html_url': 'https://github.com/mtias',
#      'followers_url': 'https://api.github.com/users/mtias/followers',
#      'following_url': 'https://api.github.com/users/mtias/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/mtias/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/mtias/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/mtias/subscriptions',
#      'organizations_url': 'https://api.github.com/users/mtias/orgs',
#      'repos_url': 'https://api.github.com/users/mtias/repos',
#      'events_url': 'https://api.github.com/users/mtias/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/mtias/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2021-11-24T10:19:40Z',
#     'updated_at': '2021-11-24T10:19:40Z',
#     'author_association': 'CONTRIBUTOR',
#     'body': 'Yes, the size is meant to be hard-coded in the small preview.',
#     'reactions': {'url': 'https://api.github.com/repos/WordPress/gutenberg/issues/comments/977734709/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2021-11-24T10:19:40Z',
#   'org': {'id': 276006,
#    'login': 'WordPress',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/WordPress',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/276006?'}},
#  {'id': '19030667332',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 3521094,
#    'login': 'WinterSilence',
#    'display_login': 'WinterSilence',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/WinterSilence',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3521094?'},
#   'repo': {'id': 384377614,
#    'name': 'yiisoft/yii2-bootstrap5',
#    'url': 'https://api.github.com/repos/yiisoft/yii2-bootstrap5'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/yiisoft/yii2-bootstrap5/issues/18',
#     'repository_url': 'https://api.github.com/repos/yiisoft/yii2-bootstrap5',
#     'labels_url': 'https://api.github.com/repos/yiisoft/yii2-bootstrap5/issues/18/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/yiisoft/yii2-bootstrap5/issues/18/comments',
#     'events_url': 'https://api.github.com/repos/yiisoft/yii2-bootstrap5/issues/18/events',
#     'html_url': 'https://github.com/yiisoft/yii2-bootstrap5/pull/18',
#     'id': 1053953883,
#     'node_id': 'PR_kwDOFukjDs4ujCkS',
#     'number': 18,
#     'title': 'ActiveField: add rangeInput(), colorInput() and switch mode to checkbox()',
#     'user': {'login': 'WinterSilence',
#      'id': 3521094,
#      'node_id': 'MDQ6VXNlcjM1MjEwOTQ=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/3521094?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/WinterSilence',
#      'html_url': 'https://github.com/WinterSilence',
#      'followers_url': 'https://api.github.com/users/WinterSilence/followers',
#      'following_url': 'https://api.github.com/users/WinterSilence/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/WinterSilence/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/WinterSilence/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/WinterSilence/subscriptions',
#      'organizations_url': 'https://api.github.com/users/WinterSilence/orgs',
#      'repos_url': 'https://api.github.com/users/WinterSilence/repos',
#      'events_url': 'https://api.github.com/users/WinterSilence/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/WinterSilence/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 5,
#     'created_at': '2021-11-15T18:02:10Z',
#     'updated_at': '2021-11-24T10:19:40Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'draft': False,
#     'pull_request': {'url': 'https://api.github.com/repos/yiisoft/yii2-bootstrap5/pulls/18',
#      'html_url': 'https://github.com/yiisoft/yii2-bootstrap5/pull/18',
#      'diff_url': 'https://github.com/yiisoft/yii2-bootstrap5/pull/18.diff',
#      'patch_url': 'https://github.com/yiisoft/yii2-bootstrap5/pull/18.patch',
#      'merged_at': None},
#     'body': '| Q             | A\r\n| ------------- | ---\r\n| Is bugfix?    | ❌\r\n| New feature?  | ✔️\r\n| Breaks BC?    | ❌\r\n| Fixed issues  | \r\n',
#     'reactions': {'url': 'https://api.github.com/repos/yiisoft/yii2-bootstrap5/issues/18/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/yiisoft/yii2-bootstrap5/issues/18/timeline',
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/yiisoft/yii2-bootstrap5/issues/comments/977734706',
#     'html_url': 'https://github.com/yiisoft/yii2-bootstrap5/pull/18#issuecomment-977734706',
#     'issue_url': 'https://api.github.com/repos/yiisoft/yii2-bootstrap5/issues/18',
#     'id': 977734706,
#     'node_id': 'IC_kwDOFukjDs46Rwwy',
#     'user': {'login': 'WinterSilence',
#      'id': 3521094,
#      'node_id': 'MDQ6VXNlcjM1MjEwOTQ=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/3521094?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/WinterSilence',
#      'html_url': 'https://github.com/WinterSilence',
#      'followers_url': 'https://api.github.com/users/WinterSilence/followers',
#      'following_url': 'https://api.github.com/users/WinterSilence/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/WinterSilence/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/WinterSilence/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/WinterSilence/subscriptions',
#      'organizations_url': 'https://api.github.com/users/WinterSilence/orgs',
#      'repos_url': 'https://api.github.com/users/WinterSilence/repos',
#      'events_url': 'https://api.github.com/users/WinterSilence/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/WinterSilence/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2021-11-24T10:19:40Z',
#     'updated_at': '2021-11-24T10:19:40Z',
#     'author_association': 'NONE',
#     'body': '@simialbi done',
#     'reactions': {'url': 'https://api.github.com/repos/yiisoft/yii2-bootstrap5/issues/comments/977734706/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2021-11-24T10:19:40Z',
#   'org': {'id': 993323,
#    'login': 'yiisoft',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/yiisoft',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/993323?'}},
#  {'id': '19030667363',
#   'type': 'CreateEvent',
#   'actor': {'id': 73880125,
#    'login': 'GeremyBeaugas',
#    'display_login': 'GeremyBeaugas',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/GeremyBeaugas',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/73880125?'},
#   'repo': {'id': 431437664,
#    'name': 'GeremyBeaugas/ProjetUbiquity',
#    'url': 'https://api.github.com/repos/GeremyBeaugas/ProjetUbiquity'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-11-24T10:19:40Z'},
#  {'id': '19030667369',
#   'type': 'CreateEvent',
#   'actor': {'id': 145845,
#    'login': 'bussyjd',
#    'display_login': 'bussyjd',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bussyjd',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/145845?'},
#   'repo': {'id': 364729518,
#    'name': 'Stacktical/stacktical-dsla-developer-toolkit',
#    'url': 'https://api.github.com/repos/Stacktical/stacktical-dsla-developer-toolkit'},
#   'payload': {'ref': 'feature/packages_maintenance',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-11-24T10:19:40Z',
#   'org': {'id': 14309507,
#    'login': 'Stacktical',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Stacktical',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/14309507?'}},
#  {'id': '19030667307',
#   'type': 'PushEvent',
#   'actor': {'id': 89670698,
#    'login': 'changfengoss',
#    'display_login': 'changfengoss',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/changfengoss',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/89670698?'},
#   'repo': {'id': 401220038,
#    'name': 'changfengoss/pub',
#    'url': 'https://api.github.com/repos/changfengoss/pub'},
#   'payload': {'push_id': 8461328728,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '0654dbaf5980ecc9f62c744b56cc7517b3a95789',
#    'before': 'f6780d1d268a6ce9085c4d8690aa8454c28c22ba',
#    'commits': [{'sha': '0654dbaf5980ecc9f62c744b56cc7517b3a95789',
#      'author': {'email': '89670698+changfengoss@users.noreply.github.com',
#       'name': 'changfengoss'},
#      'message': 'v2rayse comment file',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/changfengoss/pub/commits/0654dbaf5980ecc9f62c744b56cc7517b3a95789'}]},
#   'public': True,
#   'created_at': '2021-11-24T10:19:40Z'},
#  {'id': '19030667330',
#   'type': 'CreateEvent',
#   'actor': {'id': 93844326,
#    'login': 'Larrypeters777',
#    'display_login': 'Larrypeters777',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Larrypeters777',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/93844326?'},
#   'repo': {'id': 431436975,
#    'name': 'Larrypeters777/sunnyside-agency-landing-page-main-group13',
#    'url': 'https://api.github.com/repos/Larrypeters777/sunnyside-agency-landing-page-main-group13'},
#   'payload': {'ref': 'main',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-11-24T10:19:40Z'},
#  {'id': '19030667315',
#   'type': 'CreateEvent',
#   'actor': {'id': 11543329,
#    'login': 'ConfluentJenkins',
#    'display_login': 'ConfluentJenkins',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ConfluentJenkins',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11543329?'},
#   'repo': {'id': 205213732,
#    'name': 'confluentinc/kafka-mqtt-images',
#    'url': 'https://api.github.com/repos/confluentinc/kafka-mqtt-images'},
#   'payload': {'ref': 'v7.1.0-67',
#    'ref_type': 'tag',
#    'master_branch': 'master',
#    'description': 'Confluent Docker images for Kafka MQTT',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-11-24T10:19:40Z',
#   'org': {'id': 9439498,
#    'login': 'confluentinc',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/confluentinc',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9439498?'}},
#  {'id': '19030667264',
#   'type': 'WatchEvent',
#   'actor': {'id': 520895,
#    'login': 'Wundark',
#    'display_login': 'Wundark',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Wundark',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/520895?'},
#   'repo': {'id': 234739976,
#    'name': 'medusajs/medusa',
#    'url': 'https://api.github.com/repos/medusajs/medusa'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2021-11-24T10:19:40Z',
#   'org': {'id': 62591822,
#    'login': 'medusajs',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/medusajs',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/62591822?'}},
#  {'id': '19030667251',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 48274553,
#    'login': 'Lachouri',
#    'display_login': 'Lachouri',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Lachouri',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/48274553?'},
#   'repo': {'id': 266584277,
#    'name': 'Lachouri/online-cv',
#    'url': 'https://api.github.com/repos/Lachouri/online-cv'},
#   'payload': {'action': 'closed',
#    'number': 2,
#    'pull_request': {'url': 'https://api.github.com/repos/Lachouri/online-cv/pulls/2',
#     'id': 785468861,
#     'node_id': 'PR_kwDOD-PA1c4u0U29',
#     'html_url': 'https://github.com/Lachouri/online-cv/pull/2',
#     'diff_url': 'https://github.com/Lachouri/online-cv/pull/2.diff',
#     'patch_url': 'https://github.com/Lachouri/online-cv/pull/2.patch',
#     'issue_url': 'https://api.github.com/repos/Lachouri/online-cv/issues/2',
#     'number': 2,
#     'state': 'closed',
#     'locked': False,
#     'title': 'Bump tmpl from 1.0.4 to 1.0.5',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': '[//]: # (dependabot-start)\n⚠️  **Dependabot is rebasing this PR** ⚠️ \n\nRebasing might not happen immediately, so don\'t worry if this takes some time.\n\nNote: if you make any changes to this PR yourself, they will take precedence over the rebase.\n\n---\n\n[//]: # (dependabot-end)\n\nBumps [tmpl](https://github.com/daaku/nodejs-tmpl) from 1.0.4 to 1.0.5.\n<details>\n<summary>Commits</summary>\n<ul>\n<li>See full diff in <a href="https://github.com/daaku/nodejs-tmpl/commits/v1.0.5">compare view</a></li>\n</ul>\n</details>\n<br />\n\n\n[![Dependabot compatibility score](https://dependabot-badges.githubapp.com/badges/compatibility_score?dependency-name=tmpl&package-manager=npm_and_yarn&previous-version=1.0.4&new-version=1.0.5)](https://docs.github.com/en/github/managing-security-vulnerabilities/about-dependabot-security-updates#about-compatibility-scores)\n\nDependabot will resolve any conflicts with this PR as long as you don\'t alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\n\n[//]: # (dependabot-automerge-start)\n[//]: # (dependabot-automerge-end)\n\n---\n\n<details>\n<summary>Dependabot commands and options</summary>\n<br />\n\nYou can trigger Dependabot actions by commenting on this PR:\n- `@dependabot rebase` will rebase this PR\n- `@dependabot recreate` will recreate this PR, overwriting any edits that have been made to it\n- `@dependabot merge` will merge this PR after your CI passes on it\n- `@dependabot squash and merge` will squash and merge this PR after your CI passes on it\n- `@dependabot cancel merge` will cancel a previously requested merge and block automerging\n- `@dependabot reopen` will reopen this PR if it is closed\n- `@dependabot close` will close this PR and stop Dependabot recreating it. You can achieve the same result by closing it manually\n- `@dependabot ignore this major version` will close this PR and stop Dependabot creating any more for this major version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this minor version` will close this PR and stop Dependabot creating any more for this minor version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this dependency` will close this PR and stop Dependabot creating any more for this dependency (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot use these labels` will set the current labels as the default for future PRs for this repo and language\n- `@dependabot use these reviewers` will set the current reviewers as the default for future PRs for this repo and language\n- `@dependabot use these assignees` will set the current assignees as the default for future PRs for this repo and language\n- `@dependabot use this milestone` will set the current milestone as the default for future PRs for this repo and language\n\nYou can disable automated security fix PRs for this repo from the [Security Alerts page](https://github.com/Lachouri/online-cv/network/alerts).\n\n</details>',
#     'created_at': '2021-11-21T20:42:35Z',
#     'updated_at': '2021-11-24T10:19:40Z',
#     'closed_at': '2021-11-24T10:19:40Z',
#     'merged_at': None,
#     'merge_commit_sha': '1220eb3e0cfe1d28bed9c14b1964c0adec68a11f',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [{'id': 2993443518,
#       'node_id': 'MDU6TGFiZWwyOTkzNDQzNTE4',
#       'url': 'https://api.github.com/repos/Lachouri/online-cv/labels/dependencies',
#       'name': 'dependencies',
#       'color': '0366d6',
#       'default': False,
#       'description': 'Pull requests that update a dependency file'}],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/Lachouri/online-cv/pulls/2/commits',
#     'review_comments_url': 'https://api.github.com/repos/Lachouri/online-cv/pulls/2/comments',
#     'review_comment_url': 'https://api.github.com/repos/Lachouri/online-cv/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/Lachouri/online-cv/issues/2/comments',
#     'statuses_url': 'https://api.github.com/repos/Lachouri/online-cv/statuses/930725d9c96cb72591285fd10ad94d650ba6fec8',
#     'head': {'label': 'Lachouri:dependabot/npm_and_yarn/tmpl-1.0.5',
#      'ref': 'dependabot/npm_and_yarn/tmpl-1.0.5',
#      'sha': '930725d9c96cb72591285fd10ad94d650ba6fec8',
#      'user': {'login': 'Lachouri',
#       'id': 48274553,
#       'node_id': 'MDQ6VXNlcjQ4Mjc0NTUz',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/48274553?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Lachouri',
#       'html_url': 'https://github.com/Lachouri',
#       'followers_url': 'https://api.github.com/users/Lachouri/followers',
#       'following_url': 'https://api.github.com/users/Lachouri/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Lachouri/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Lachouri/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Lachouri/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Lachouri/orgs',
#       'repos_url': 'https://api.github.com/users/Lachouri/repos',
#       'events_url': 'https://api.github.com/users/Lachouri/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Lachouri/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 266584277,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyNjY1ODQyNzc=',
#       'name': 'online-cv',
#       'full_name': 'Lachouri/online-cv',
#       'private': False,
#       'owner': {'login': 'Lachouri',
#        'id': 48274553,
#        'node_id': 'MDQ6VXNlcjQ4Mjc0NTUz',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/48274553?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/Lachouri',
#        'html_url': 'https://github.com/Lachouri',
#        'followers_url': 'https://api.github.com/users/Lachouri/followers',
#        'following_url': 'https://api.github.com/users/Lachouri/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/Lachouri/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/Lachouri/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/Lachouri/subscriptions',
#        'organizations_url': 'https://api.github.com/users/Lachouri/orgs',
#        'repos_url': 'https://api.github.com/users/Lachouri/repos',
#        'events_url': 'https://api.github.com/users/Lachouri/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/Lachouri/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/Lachouri/online-cv',
#       'description': 'My personal website',
#       'fork': False,
#       'url': 'https://api.github.com/repos/Lachouri/online-cv',
#       'forks_url': 'https://api.github.com/repos/Lachouri/online-cv/forks',
#       'keys_url': 'https://api.github.com/repos/Lachouri/online-cv/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/Lachouri/online-cv/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/Lachouri/online-cv/teams',
#       'hooks_url': 'https://api.github.com/repos/Lachouri/online-cv/hooks',
#       'issue_events_url': 'https://api.github.com/repos/Lachouri/online-cv/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/Lachouri/online-cv/events',
#       'assignees_url': 'https://api.github.com/repos/Lachouri/online-cv/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/Lachouri/online-cv/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/Lachouri/online-cv/tags',
#       'blobs_url': 'https://api.github.com/repos/Lachouri/online-cv/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/Lachouri/online-cv/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/Lachouri/online-cv/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/Lachouri/online-cv/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/Lachouri/online-cv/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/Lachouri/online-cv/languages',
#       'stargazers_url': 'https://api.github.com/repos/Lachouri/online-cv/stargazers',
#       'contributors_url': 'https://api.github.com/repos/Lachouri/online-cv/contributors',
#       'subscribers_url': 'https://api.github.com/repos/Lachouri/online-cv/subscribers',
#       'subscription_url': 'https://api.github.com/repos/Lachouri/online-cv/subscription',
#       'commits_url': 'https://api.github.com/repos/Lachouri/online-cv/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/Lachouri/online-cv/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/Lachouri/online-cv/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/Lachouri/online-cv/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/Lachouri/online-cv/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/Lachouri/online-cv/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/Lachouri/online-cv/merges',
#       'archive_url': 'https://api.github.com/repos/Lachouri/online-cv/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/Lachouri/online-cv/downloads',
#       'issues_url': 'https://api.github.com/repos/Lachouri/online-cv/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/Lachouri/online-cv/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/Lachouri/online-cv/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/Lachouri/online-cv/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/Lachouri/online-cv/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/Lachouri/online-cv/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/Lachouri/online-cv/deployments',
#       'created_at': '2020-05-24T16:49:47Z',
#       'updated_at': '2021-11-24T10:18:00Z',
#       'pushed_at': '2021-11-24T10:17:57Z',
#       'git_url': 'git://github.com/Lachouri/online-cv.git',
#       'ssh_url': 'git@github.com:Lachouri/online-cv.git',
#       'clone_url': 'https://github.com/Lachouri/online-cv.git',
#       'svn_url': 'https://github.com/Lachouri/online-cv',
#       'homepage': 'http://www.ludivineachouri.com/',
#       'size': 4800,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'Lachouri:master',
#      'ref': 'master',
#      'sha': '3754b1ebd25878bf244633f70b310d9bdfa73d15',
#      'user': {'login': 'Lachouri',
#       'id': 48274553,
#       'node_id': 'MDQ6VXNlcjQ4Mjc0NTUz',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/48274553?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Lachouri',
#       'html_url': 'https://github.com/Lachouri',
#       'followers_url': 'https://api.github.com/users/Lachouri/followers',
#       'following_url': 'https://api.github.com/users/Lachouri/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Lachouri/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Lachouri/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Lachouri/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Lachouri/orgs',
#       'repos_url': 'https://api.github.com/users/Lachouri/repos',
#       'events_url': 'https://api.github.com/users/Lachouri/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Lachouri/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 266584277,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyNjY1ODQyNzc=',
#       'name': 'online-cv',
#       'full_name': 'Lachouri/online-cv',
#       'private': False,
#       'owner': {'login': 'Lachouri',
#        'id': 48274553,
#        'node_id': 'MDQ6VXNlcjQ4Mjc0NTUz',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/48274553?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/Lachouri',
#        'html_url': 'https://github.com/Lachouri',
#        'followers_url': 'https://api.github.com/users/Lachouri/followers',
#        'following_url': 'https://api.github.com/users/Lachouri/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/Lachouri/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/Lachouri/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/Lachouri/subscriptions',
#        'organizations_url': 'https://api.github.com/users/Lachouri/orgs',
#        'repos_url': 'https://api.github.com/users/Lachouri/repos',
#        'events_url': 'https://api.github.com/users/Lachouri/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/Lachouri/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/Lachouri/online-cv',
#       'description': 'My personal website',
#       'fork': False,
#       'url': 'https://api.github.com/repos/Lachouri/online-cv',
#       'forks_url': 'https://api.github.com/repos/Lachouri/online-cv/forks',
#       'keys_url': 'https://api.github.com/repos/Lachouri/online-cv/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/Lachouri/online-cv/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/Lachouri/online-cv/teams',
#       'hooks_url': 'https://api.github.com/repos/Lachouri/online-cv/hooks',
#       'issue_events_url': 'https://api.github.com/repos/Lachouri/online-cv/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/Lachouri/online-cv/events',
#       'assignees_url': 'https://api.github.com/repos/Lachouri/online-cv/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/Lachouri/online-cv/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/Lachouri/online-cv/tags',
#       'blobs_url': 'https://api.github.com/repos/Lachouri/online-cv/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/Lachouri/online-cv/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/Lachouri/online-cv/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/Lachouri/online-cv/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/Lachouri/online-cv/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/Lachouri/online-cv/languages',
#       'stargazers_url': 'https://api.github.com/repos/Lachouri/online-cv/stargazers',
#       'contributors_url': 'https://api.github.com/repos/Lachouri/online-cv/contributors',
#       'subscribers_url': 'https://api.github.com/repos/Lachouri/online-cv/subscribers',
#       'subscription_url': 'https://api.github.com/repos/Lachouri/online-cv/subscription',
#       'commits_url': 'https://api.github.com/repos/Lachouri/online-cv/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/Lachouri/online-cv/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/Lachouri/online-cv/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/Lachouri/online-cv/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/Lachouri/online-cv/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/Lachouri/online-cv/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/Lachouri/online-cv/merges',
#       'archive_url': 'https://api.github.com/repos/Lachouri/online-cv/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/Lachouri/online-cv/downloads',
#       'issues_url': 'https://api.github.com/repos/Lachouri/online-cv/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/Lachouri/online-cv/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/Lachouri/online-cv/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/Lachouri/online-cv/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/Lachouri/online-cv/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/Lachouri/online-cv/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/Lachouri/online-cv/deployments',
#       'created_at': '2020-05-24T16:49:47Z',
#       'updated_at': '2021-11-24T10:18:00Z',
#       'pushed_at': '2021-11-24T10:17:57Z',
#       'git_url': 'git://github.com/Lachouri/online-cv.git',
#       'ssh_url': 'git@github.com:Lachouri/online-cv.git',
#       'clone_url': 'https://github.com/Lachouri/online-cv.git',
#       'svn_url': 'https://github.com/Lachouri/online-cv',
#       'homepage': 'http://www.ludivineachouri.com/',
#       'size': 4800,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/Lachouri/online-cv/pulls/2'},
#      'html': {'href': 'https://github.com/Lachouri/online-cv/pull/2'},
#      'issue': {'href': 'https://api.github.com/repos/Lachouri/online-cv/issues/2'},
#      'comments': {'href': 'https://api.github.com/repos/Lachouri/online-cv/issues/2/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/Lachouri/online-cv/pulls/2/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/Lachouri/online-cv/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/Lachouri/online-cv/pulls/2/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/Lachouri/online-cv/statuses/930725d9c96cb72591285fd10ad94d650ba6fec8'}},
#     'author_association': 'CONTRIBUTOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': True,
#     'rebaseable': False,
#     'mergeable_state': 'clean',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 6,
#     'deletions': 6,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2021-11-24T10:19:40Z'},
#  {'id': '19030667268',
#   'type': 'DeleteEvent',
#   'actor': {'id': 71354125,
#    'login': 'aws-connector-for-github[bot]',
#    'display_login': 'aws-connector-for-github',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/aws-connector-for-github[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71354125?'},
#   'repo': {'id': 429551228,
#    'name': 'bullet-dev-team/python-pyramid-public',
#    'url': 'https://api.github.com/repos/bullet-dev-team/python-pyramid-public'},
#   'payload': {'ref': 'cicd-e2e-7mxgnq',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-11-24T10:19:40Z'},
#  {'id': '19030666985',
#   'type': 'PushEvent',
#   'actor': {'id': 67962326,
#    'login': '4Mugala',
#    'display_login': '4Mugala',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/4Mugala',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/67962326?'},
#   'repo': {'id': 431229456,
#    'name': '4Mugala/4mugala.AnswerBoxWeb.io',
#    'url': 'https://api.github.com/repos/4Mugala/4mugala.AnswerBoxWeb.io'},
#   'payload': {'push_id': 8461328570,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/gh-pages',
#    'head': '941fe2dc54facafc537138c8c87968e6832dfeb0',
#    'before': '3b1ae9a735c475e400d2105352a76d643767709b',
#    'commits': [{'sha': '941fe2dc54facafc537138c8c87968e6832dfeb0',
#      'author': {'email': '67962326+4Mugala@users.noreply.github.com',
#       'name': 'Musangu J. Mugala'},
#      'message': 'Create index.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/4Mugala/4mugala.AnswerBoxWeb.io/commits/941fe2dc54facafc537138c8c87968e6832dfeb0'}]},
#   'public': True,
#   'created_at': '2021-11-24T10:19:39Z'},
#  {'id': '19030667243',
#   'type': 'DeleteEvent',
#   'actor': {'id': 1589939,
#    'login': 'RandomByte',
#    'display_login': 'RandomByte',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/RandomByte',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1589939?'},
#   'repo': {'id': 126844045,
#    'name': 'SAP/ui5-project',
#    'url': 'https://api.github.com/repos/SAP/ui5-project'},
#   'payload': {'ref': 'enable-next-ci',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-11-24T10:19:40Z',
#   'org': {'id': 2531208,
#    'login': 'SAP',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/SAP',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2531208?'}},
#  {'id': '19030666978',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 58601,
#    'login': 'nikku',
#    'display_login': 'nikku',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nikku',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58601?'},
#   'repo': {'id': 147165190,
#    'name': 'camunda/camunda-modeler-linter-plugin',
#    'url': 'https://api.github.com/repos/camunda/camunda-modeler-linter-plugin'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/camunda/camunda-modeler-linter-plugin/issues/19',
#     'repository_url': 'https://api.github.com/repos/camunda/camunda-modeler-linter-plugin',
#     'labels_url': 'https://api.github.com/repos/camunda/camunda-modeler-linter-plugin/issues/19/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/camunda/camunda-modeler-linter-plugin/issues/19/comments',
#     'events_url': 'https://api.github.com/repos/camunda/camunda-modeler-linter-plugin/issues/19/events',
#     'html_url': 'https://github.com/camunda/camunda-modeler-linter-plugin/issues/19',
#     'id': 1058222291,
#     'node_id': 'I_kwDOCMWQBs4_EzDT',
#     'number': 19,
#     'title': 'Bugs while working with camunda modeler version 4.11.1',
#     'user': {'login': 'Nelly1313',
#      'id': 94673055,
#      'node_id': 'U_kgDOBaSYnw',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/94673055?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Nelly1313',
#      'html_url': 'https://github.com/Nelly1313',
#      'followers_url': 'https://api.github.com/users/Nelly1313/followers',
#      'following_url': 'https://api.github.com/users/Nelly1313/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Nelly1313/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Nelly1313/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Nelly1313/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Nelly1313/orgs',
#      'repos_url': 'https://api.github.com/users/Nelly1313/repos',
#      'events_url': 'https://api.github.com/users/Nelly1313/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Nelly1313/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 1043740054,
#       'node_id': 'MDU6TGFiZWwxMDQzNzQwMDU0',
#       'url': 'https://api.github.com/repos/camunda/camunda-modeler-linter-plugin/labels/help%20wanted',
#       'name': 'help wanted',
#       'color': '008672',
#       'default': True,
#       'description': 'Extra attention is needed'}],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 2,
#     'created_at': '2021-11-19T07:17:00Z',
#     'updated_at': '2021-11-24T10:19:39Z',
#     'closed_at': '2021-11-24T10:19:39Z',
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'body': "The linter plugin starts having bugs if used with camunda modeler version 4.11.1. It's still possible to check if a process has start and end events and it does realize if an event is missing and even updates the counter but the error is not shown in the diagram itself.",
#     'reactions': {'url': 'https://api.github.com/repos/camunda/camunda-modeler-linter-plugin/issues/19/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/camunda/camunda-modeler-linter-plugin/issues/19/timeline',
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/camunda/camunda-modeler-linter-plugin/issues/comments/977734695',
#     'html_url': 'https://github.com/camunda/camunda-modeler-linter-plugin/issues/19#issuecomment-977734695',
#     'issue_url': 'https://api.github.com/repos/camunda/camunda-modeler-linter-plugin/issues/19',
#     'id': 977734695,
#     'node_id': 'IC_kwDOCMWQBs46Rwwn',
#     'user': {'login': 'nikku',
#      'id': 58601,
#      'node_id': 'MDQ6VXNlcjU4NjAx',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/58601?v=4',
#      'gravatar_id': '',
# ...
#       'subscribers_url': 'https://api.github.com/repos/Yishaiaz/Cell2CellComunicationAnalyzer/subscribers',
#       'subscription_url': 'https://api.github.com/repos/Yishaiaz/Cell2CellComunicationAnalyzer/subscription',
#       'commits_url': 'https://api.github.com/repos/Yishaiaz/Cell2CellComunicationAnalyzer/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/Yishaiaz/Cell2CellComunicationAnalyzer/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/Yishaiaz/Cell2CellComunicationAnalyzer/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/Yishaiaz/Cell2CellComunicationAnalyzer/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/Yishaiaz/Cell2CellComunicationAnalyzer/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/Yishaiaz/Cell2CellComunicationAnalyzer/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/Yishaiaz/Cell2CellComunicationAnalyzer/merges',
#       'archive_url': 'https://api.github.com/repos/Yishaiaz/Cell2CellComunicationAnalyzer/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/Yishaiaz/Cell2CellComunicationAnalyzer/downloads',
#       'issues_url': 'https://api.github.com/repos/Yishaiaz/Cell2CellComunicationAnalyzer/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/Yishaiaz/Cell2CellComunicationAnalyzer/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/Yishaiaz/Cell2CellComunicationAnalyzer/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/Yishaiaz/Cell2CellComunicationAnalyzer/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/Yishaiaz/Cell2CellComunicationAnalyzer/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/Yishaiaz/Cell2CellComunicationAnalyzer/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/Yishaiaz/Cell2CellComunicationAnalyzer/deployments',
#       'created_at': '2021-10-21T10:38:48Z',
#       'updated_at': '2021-11-12T16:59:02Z',
#       'pushed_at': '2021-11-24T09:43:03Z',
#       'git_url': 'git://github.com/Yishaiaz/Cell2CellComunicationAnalyzer.git',
#       'ssh_url': 'git@github.com:Yishaiaz/Cell2CellComunicationAnalyzer.git',
#       'clone_url': 'https://github.com/Yishaiaz/Cell2CellComunicationAnalyzer.git',
#       'svn_url': 'https://github.com/Yishaiaz/Cell2CellComunicationAnalyzer',
#       'homepage': None,
#       'size': 887,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Python',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': {'key': 'gpl-3.0',
#        'name': 'GNU General Public License v3.0',
#        'spdx_id': 'GPL-3.0',
#        'url': 'https://api.github.com/licenses/gpl-3.0',
#        'node_id': 'MDc6TGljZW5zZTk='},
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/Yishaiaz/Cell2CellComunicationAnalyzer/pulls/4'},
#      'html': {'href': 'https://github.com/Yishaiaz/Cell2CellComunicationAnalyzer/pull/4'},
#      'issue': {'href': 'https://api.github.com/repos/Yishaiaz/Cell2CellComunicationAnalyzer/issues/4'},
#      'comments': {'href': 'https://api.github.com/repos/Yishaiaz/Cell2CellComunicationAnalyzer/issues/4/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/Yishaiaz/Cell2CellComunicationAnalyzer/pulls/4/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/Yishaiaz/Cell2CellComunicationAnalyzer/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/Yishaiaz/Cell2CellComunicationAnalyzer/pulls/4/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/Yishaiaz/Cell2CellComunicationAnalyzer/statuses/2d49eb916e905b77fb47ce5d7ba976dbc16339c7'}},
#     'author_association': 'COLLABORATOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 4,
#     'additions': 3565,
#     'deletions': 53,
#     'changed_files': 22}},
#   'public': True,
#   'created_at': '2021-11-24T10:19:40Z'},
#  {'id': '19030666862',
#   'type': 'PushEvent',
#   'actor': {'id': 12016372,
#    'login': 'Thierry25',
#    'display_login': 'Thierry25',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Thierry25',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12016372?'},
#   'repo': {'id': 423393437,
#    'name': 'SOA-LouDLy/Jobify',
#    'url': 'https://api.github.com/repos/SOA-LouDLy/Jobify'},
#   'payload': {'push_id': 8461328523,
#    'size': 2,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '9bd029c54001fdc91b590386ccf2d0b1ebf220b5',
#    'before': 'e07ce928772f02959d2da57cc052f9eda1444270',
#    'commits': [{'sha': 'f966289ee960b91dd0101a7e4655023b80108987',
#      'author': {'email': 'marcelinthierry@gmail.com', 'name': 'Thierry'},
#      'message': 'Fix DB error',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/SOA-LouDLy/Jobify/commits/f966289ee960b91dd0101a7e4655023b80108987'},
#     {'sha': '9bd029c54001fdc91b590386ccf2d0b1ebf220b5',
#      'author': {'email': 'marcelinthierry@gmail.com', 'name': 'Thierry25'},
#      'message': 'Merge pull request #15 from SOA-LouDLy/develop\n\nFix DB error',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/SOA-LouDLy/Jobify/commits/9bd029c54001fdc91b590386ccf2d0b1ebf220b5'}]},
#   'public': True,
#   'created_at': '2021-11-24T10:19:39Z',
#   'org': {'id': 92246765,
#    'login': 'SOA-LouDLy',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/SOA-LouDLy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/92246765?'}},
#  {'id': '19030667192',
#   'type': 'PushEvent',
#   'actor': {'id': 94719717,
#    'login': 'psalm136',
#    'display_login': 'psalm136',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/psalm136',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/94719717?'},
#   'repo': {'id': 431381000,
#    'name': 'psalm136/time',
#    'url': 'https://api.github.com/repos/psalm136/time'},
#   'payload': {'push_id': 8461328665,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '13cc843b956e6beff17eb70fda30543339eea120',
#    'before': 'ac6b7e8a276cd6b2719801afe6be89ec11189a40',
#    'commits': [{'sha': '13cc843b956e6beff17eb70fda30543339eea120',
#      'author': {'email': 'psalm@posteo.net', 'name': 'Elias Howell'},
#      'message': 'update time',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/psalm136/time/commits/13cc843b956e6beff17eb70fda30543339eea120'}]},
#   'public': True,
#   'created_at': '2021-11-24T10:19:40Z'},
#  {'id': '19030667156',
#   'type': 'CreateEvent',
#   'actor': {'id': 71520923,
#    'login': 'ptamas98',
#    'display_login': 'ptamas98',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ptamas98',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71520923?'},
#   'repo': {'id': 431437661,
#    'name': 'ptamas98/oak-basics-master',
#    'url': 'https://api.github.com/repos/ptamas98/oak-basics-master'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-11-24T10:19:40Z'},
#  {'id': '19030667149',
#   'type': 'WatchEvent',
#   'actor': {'id': 36675164,
#    'login': 'celiamaure',
#    'display_login': 'celiamaure',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/celiamaure',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36675164?'},
#   'repo': {'id': 356521531,
#    'name': 'leMaur/laravel-image-sitemap',
#    'url': 'https://api.github.com/repos/leMaur/laravel-image-sitemap'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2021-11-24T10:19:40Z'},
#  {'id': '19030667176',
#   'type': 'PushEvent',
#   'actor': {'id': 55102105,
#    'login': 'toth152',
#    'display_login': 'toth152',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/toth152',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/55102105?'},
#   'repo': {'id': 406691953,
#    'name': 'toth152/WTX6LW_XMLgyak',
#    'url': 'https://api.github.com/repos/toth152/WTX6LW_XMLgyak'},
#   'payload': {'push_id': 8461328664,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '51ee75a3d48123570cb954b07de6292a9ca041c6',
#    'before': 'd8c571e62cb58a8604837ef7554f41c6b591830a',
#    'commits': [{'sha': '51ee75a3d48123570cb954b07de6292a9ca041c6',
#      'author': {'email': '55102105+toth152@users.noreply.github.com',
#       'name': 'toth152'},
#      'message': '1. feladat',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/toth152/WTX6LW_XMLgyak/commits/51ee75a3d48123570cb954b07de6292a9ca041c6'}]},
#   'public': True,
#   'created_at': '2021-11-24T10:19:40Z'},
#  {'id': '19030667132',
#   'type': 'PushEvent',
#   'actor': {'id': 46171121,
#    'login': 'goodtrailer',
#    'display_login': 'goodtrailer',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/goodtrailer',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/46171121?'},
#   'repo': {'id': 352459801,
#    'name': 'goodtrailer/soyokaze',
#    'url': 'https://api.github.com/repos/goodtrailer/soyokaze'},
#   'payload': {'push_id': 8461328643,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '8f087feabc39ad6a785b7373c80c248c46d98d39',
#    'before': 'b88a653b2dd9fb32a0253ddddce8a8d6e3239861',
#    'commits': [{'sha': '8f087feabc39ad6a785b7373c80c248c46d98d39',
#      'author': {'email': 'aldenwu0@gmail.com', 'name': 'goodtrailer'},
#      'message': 'Visual Studio code cleanup',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/goodtrailer/soyokaze/commits/8f087feabc39ad6a785b7373c80c248c46d98d39'}]},
#   'public': True,
#   'created_at': '2021-11-24T10:19:40Z'},
#  {'id': '19030667143',
#   'type': 'PushEvent',
#   'actor': {'id': 10861600,
#    'login': 'bvenkysubbu',
#    'display_login': 'bvenkysubbu',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bvenkysubbu',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10861600?'},
#   'repo': {'id': 346297856,
#    'name': 'bvenkysubbu/tymlymonitor',
#    'url': 'https://api.github.com/repos/bvenkysubbu/tymlymonitor'},
#   'payload': {'push_id': 8461328653,
#    'size': 6,
#    'distinct_size': 6,
#    'ref': 'refs/heads/master',
#    'head': '8c0ba196471d2afbb2ad26be6179db381cb0c610',
#    'before': '20da12491935e5104d541450b46548a64eb4a65d',
#    'commits': [{'sha': '825e56ec81821d6232cd3941145153fd2ef97edc',
#      'author': {'email': '73812536+upptime-bot@users.noreply.github.com',
#       'name': 'Upptime Bot'},
#      'message': '🟥 Trifecta Esplanade Multipurpose Hall is down (521 in 210 ms) [skip ci] [upptime]',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/bvenkysubbu/tymlymonitor/commits/825e56ec81821d6232cd3941145153fd2ef97edc'},
#     {'sha': '6d73ce7bbcf4d7bcf189b57d2d6f0046b0cc7f48',
#      'author': {'email': '73812536+upptime-bot@users.noreply.github.com',
#       'name': 'Upptime Bot'},
#      'message': '🟥 Sterling Villa Grande is down (521 in 210 ms) [skip ci] [upptime]',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/bvenkysubbu/tymlymonitor/commits/6d73ce7bbcf4d7bcf189b57d2d6f0046b0cc7f48'},
#     {'sha': '13dcfd6dabd3bacc36afe4917b25a00366d23dda',
#      'author': {'email': '73812536+upptime-bot@users.noreply.github.com',
#       'name': 'Upptime Bot'},
#      'message': '🟥 SMR Vinay Cascade B Block is down (521 in 20267 ms) [skip ci] [upptime]',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/bvenkysubbu/tymlymonitor/commits/13dcfd6dabd3bacc36afe4917b25a00366d23dda'},
#     {'sha': '7384357c25d18147a7216396d4b0250d6441acf7',
#      'author': {'email': '73812536+upptime-bot@users.noreply.github.com',
#       'name': 'Upptime Bot'},
#      'message': '🟩 SMR Vinay Cascade A Block is up (200 in 10131 ms) [skip ci] [upptime]',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/bvenkysubbu/tymlymonitor/commits/7384357c25d18147a7216396d4b0250d6441acf7'},
#     {'sha': 'ed8ac32bb7b5ad630071e2e76d1a24677265b461',
#      'author': {'email': '73812536+upptime-bot@users.noreply.github.com',
#       'name': 'Upptime Bot'},
#      'message': '🟩 White Breeze 1 is up (200 in 10036 ms) [skip ci] [upptime]',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/bvenkysubbu/tymlymonitor/commits/ed8ac32bb7b5ad630071e2e76d1a24677265b461'},
#     {'sha': '8c0ba196471d2afbb2ad26be6179db381cb0c610',
#      'author': {'email': '73812536+upptime-bot@users.noreply.github.com',
#       'name': 'Upptime Bot'},
#      'message': '🟩 White Breeze 2 is up (200 in 6316 ms) [skip ci] [upptime]',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/bvenkysubbu/tymlymonitor/commits/8c0ba196471d2afbb2ad26be6179db381cb0c610'}]},
#   'public': True,
#   'created_at': '2021-11-24T10:19:40Z'},
#  {'id': '19030667137',
#   'type': 'PushEvent',
#   'actor': {'id': 35823124,
#    'login': 'llllb',
#    'display_login': 'llllb',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/llllb',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/35823124?'},
#   'repo': {'id': 431330635,
#    'name': 'llllb/llllb.github.io',
#    'url': 'https://api.github.com/repos/llllb/llllb.github.io'},
#   'payload': {'push_id': 8461328660,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'b458ea9958c5800b44902c53d728353192d5c251',
#    'before': 'e65e6ec882d8a9374048688c82382a7129db11d4',
#    'commits': [{'sha': 'b458ea9958c5800b44902c53d728353192d5c251',
#      'author': {'email': 'liubo@gyenno.com', 'name': 'liubo'},
#      'message': 'Site updated: 2021-11-24 18:19:35',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/llllb/llllb.github.io/commits/b458ea9958c5800b44902c53d728353192d5c251'}]},
#   'public': True,
#   'created_at': '2021-11-24T10:19:40Z'},
#  {'id': '19030667142',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 331800414,
#    'name': 'mikeal/congress.ipsql',
#    'url': 'https://api.github.com/repos/mikeal/congress.ipsql'},
#   'payload': {'push_id': 8461328656,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '78ea6a19548e0fa9346b2d0fd2d6cd793359d5d9',
#    'before': 'f373cf9ee3eb235b00cbf80ae2ce1fc03a0746b8',
#    'commits': [{'sha': '78ea6a19548e0fa9346b2d0fd2d6cd793359d5d9',
#      'author': {'email': 'actions@users.noreply.github.com',
#       'name': 'Automated Publisher'},
#      'message': 'Automated publish: Wed Nov 24 10:19:38 UTC 2021 f373cf9ee3eb235b00cbf80ae2ce1fc03a0746b8',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mikeal/congress.ipsql/commits/78ea6a19548e0fa9346b2d0fd2d6cd793359d5d9'}]},
#   'public': True,
#   'created_at': '2021-11-24T10:19:40Z'},
#  {'id': '19030667130',
#   'type': 'WatchEvent',
#   'actor': {'id': 40001125,
#    'login': 'kim-sunghoon',
#    'display_login': 'kim-sunghoon',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kim-sunghoon',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/40001125?'},
#   'repo': {'id': 49662454,
#    'name': 'junegunn/gv.vim',
#    'url': 'https://api.github.com/repos/junegunn/gv.vim'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2021-11-24T10:19:40Z'}]

# %%
pd.DataFrame(response.json())
# Out:
#              id              type  \
# 0   19027907810         PushEvent
# 1   19027907832       CreateEvent
# 2   19027907838       CreateEvent
# 3   19027907799         PushEvent
# 4   19027907796         PushEvent
# 5   19027907769         PushEvent
# 6   19027907797         PushEvent
# 7   19027907792         PushEvent
# 8   19027907747         PushEvent
# 9   19027907773  PullRequestEvent
# 10  19027907731         PushEvent
# 11  19027907732         PushEvent
# 12  19027907759         PushEvent
# 13  19027907714  PullRequestEvent
# 14  19027907734       CreateEvent
# 15  19027907697         PushEvent
# 16  19027907692         PushEvent
# 17  19027907712        WatchEvent
# 18  19027907693         PushEvent
# 19  19027907704         PushEvent
# 20  19027907680         PushEvent
# 21  19027907672       CreateEvent
# 22  19027907685         PushEvent
# 23  19027907661         ForkEvent
# 24  19027907664         PushEvent
# 25  19027907674         PushEvent
# 26  19027907670        WatchEvent
# 27  19027907658         PushEvent
# 28  19027907642        WatchEvent
# 29  19027907641  PullRequestEvent
#
#                                                 actor  \
# 0   {'id': 69902583, 'login': 'SG-GIT-HUB', 'displ...
# 1   {'id': 75158103, 'login': 'chen8908', 'display...
# 2   {'id': 71354125, 'login': 'aws-connector-for-g...
# 3   {'id': 93641609, 'login': 'patrick-hoell', 'di...
# 4   {'id': 45362986, 'login': 'joashdev', 'display...
# 5   {'id': 50871412, 'login': 'jerryIsHere', 'disp...
# 6   {'id': 41898282, 'login': 'github-actions[bot]...
# 7   {'id': 52286662, 'login': 'karata-sc', 'displa...
# 8   {'id': 9650581, 'login': 'jiyuujin', 'display_...
# 9   {'id': 39814207, 'login': 'pull[bot]', 'displa...
# 10  {'id': 41898282, 'login': 'github-actions[bot]...
# 11  {'id': 24356597, 'login': 'foramgandhi12', 'di...
# 12  {'id': 82928831, 'login': 'imjoud', 'display_l...
# 13  {'id': 49859594, 'login': 'Speedwag00n', 'disp...
# 14  {'id': 80814896, 'login': 'TaeYunAhn', 'displa...
# 15  {'id': 59991511, 'login': 'w-endo', 'display_l...
# 16  {'id': 41898282, 'login': 'github-actions[bot]...
# 17  {'id': 40334071, 'login': 'alicanertop', 'disp...
# 18  {'id': 22478978, 'login': 'LastSprint', 'displ...
# 19  {'id': 41898282, 'login': 'github-actions[bot]...
# 20  {'id': 69158844, 'login': 'project20911', 'dis...
# 21  {'id': 6956310, 'login': 'jimmyzhen', 'display...
# 22  {'id': 90423959, 'login': 'pringle97', 'displa...
# 23  {'id': 13044753, 'login': 'menghaniv', 'displa...
# 24  {'id': 91318945, 'login': 'PablioKonst88', 'di...
# 25  {'id': 85677360, 'login': 'shuming-yu', 'displ...
# 26  {'id': 89684029, 'login': 'Phongdho', 'display...
# 27  {'id': 41898282, 'login': 'github-actions[bot]...
# 28  {'id': 63482, 'login': 'defstream', 'display_l...
# 29  {'id': 9650581, 'login': 'jiyuujin', 'display_...
#
#                                                  repo  \
# 0   {'id': 421312252, 'name': 'SG-GIT-HUB/React-Fo...
# 1   {'id': 431383749, 'name': 'chen8908/chen8908.g...
# 2   {'id': 431383747, 'name': 'devhub-blue-sea/org...
# 3   {'id': 431377784, 'name': 'patrick-hoell/mslea...
# 4   {'id': 430790785, 'name': 'joashdev/pomotime',...
# 5   {'id': 413235913, 'name': 'jerryIsHere/K-Cube'...
# 6   {'id': 388644227, 'name': 'Pinheiro-Lucas/Pinh...
# 7   {'id': 431373387, 'name': 'keito1029/communica...
# 8   {'id': 313598056, 'name': 'jiyuujin/payment-la...
# 9   {'id': 369191018, 'name': 'sd462355991111/JDDJ...
# 10  {'id': 289198022, 'name': 'magdapoppins/magdap...
# 11  {'id': 428845279, 'name': 'foramgandhi12/MedBa...
# 12  {'id': 429472355, 'name': 'imjoud/imjoud.githu...
# 13  {'id': 114762520, 'name': 'luxteam/rpr_pipelin...
# 14  {'id': 431383745, 'name': 'TaeYunAhn/tahn.gith...
# 15  {'id': 399304076, 'name': 'w-endo/MaoEditor202...
# 16  {'id': 407312546, 'name': 'giovanniryan/giovan...
# 17  {'id': 313330998, 'name': 'bradtraversy/50proj...
# 18  {'id': 371601902, 'name': 'LastSprint/feedback...
# 19  {'id': 378400741, 'name': 'DataHerb/dataset-da...
# 20  {'id': 287324470, 'name': 'project20911/TestRe...
# 21  {'id': 332571994, 'name': 'MoTrPAC/exercise-tr...
# 22  {'id': 430985226, 'name': 'pringle97/weather-d...
# 23  {'id': 406307445, 'name': 'prayas-energy/PIER'...
# 24  {'id': 416715002, 'name': 'PablioKonst88/GB', ...
# 25  {'id': 431016243, 'name': 'shuming-yu/todolist...
# 26  {'id': 135614069, 'name': 'sudheerj/reactjs-in...
# 27  {'id': 383514868, 'name': 'benaisc/demo-MMM-pa...
# 28  {'id': 283529901, 'name': 'bobg/subcmd', 'url'...
# 29  {'id': 313598056, 'name': 'jiyuujin/payment-la...
#
#                                               payload  public  \
# 0   {'push_id': 8459975109, 'size': 1, 'distinct_s...    True
# 1   {'ref': None, 'ref_type': 'repository', 'maste...    True
# 2   {'ref': None, 'ref_type': 'repository', 'maste...    True
# 3   {'push_id': 8459975104, 'size': 1, 'distinct_s...    True
# 4   {'push_id': 8459975098, 'size': 1, 'distinct_s...    True
# 5   {'push_id': 8459975087, 'size': 1, 'distinct_s...    True
# 6   {'push_id': 8459975099, 'size': 1, 'distinct_s...    True
# 7   {'push_id': 8459975102, 'size': 1, 'distinct_s...    True
# 8   {'push_id': 8459975086, 'size': 2, 'distinct_s...    True
# 9   {'action': 'closed', 'number': 54, 'pull_reque...    True
# 10  {'push_id': 8459975080, 'size': 1, 'distinct_s...    True
# 11  {'push_id': 8459975064, 'size': 12, 'distinct_...    True
# 12  {'push_id': 8459975078, 'size': 1, 'distinct_s...    True
# 13  {'action': 'opened', 'number': 794, 'pull_requ...    True
# 14  {'ref': None, 'ref_type': 'repository', 'maste...    True
# 15  {'push_id': 8459975056, 'size': 1, 'distinct_s...    True
# 16  {'push_id': 8459975049, 'size': 1, 'distinct_s...    True
# 17                              {'action': 'started'}    True
# 18  {'push_id': 8459975069, 'size': 1, 'distinct_s...    True
# 19  {'push_id': 8459975065, 'size': 1, 'distinct_s...    True
# 20  {'push_id': 8459975050, 'size': 1, 'distinct_s...    True
# 21  {'ref': 'dev', 'ref_type': 'branch', 'master_b...    True
# 22  {'push_id': 8459975070, 'size': 1, 'distinct_s...    True
# 23  {'forkee': {'id': 431383746, 'node_id': 'R_kgD...    True
# 24  {'push_id': 8459975051, 'size': 1, 'distinct_s...    True
# 25  {'push_id': 8459975060, 'size': 1, 'distinct_s...    True
# 26                              {'action': 'started'}    True
# 27  {'push_id': 8459975041, 'size': 1, 'distinct_s...    True
# 28                              {'action': 'started'}    True
# 29  {'action': 'closed', 'number': 121, 'pull_requ...    True
#
#               created_at                                                org
# 0   2021-11-24T07:15:56Z                                                NaN
# 1   2021-11-24T07:15:56Z                                                NaN
# 2   2021-11-24T07:15:56Z  {'id': 53108288, 'login': 'devhub-blue-sea', '...
# 3   2021-11-24T07:15:56Z                                                NaN
# 4   2021-11-24T07:15:56Z                                                NaN
# 5   2021-11-24T07:15:56Z                                                NaN
# 6   2021-11-24T07:15:56Z                                                NaN
# 7   2021-11-24T07:15:56Z                                                NaN
# 8   2021-11-24T07:15:56Z                                                NaN
# 9   2021-11-24T07:15:56Z                                                NaN
# 10  2021-11-24T07:15:56Z                                                NaN
# 11  2021-11-24T07:15:56Z                                                NaN
# 12  2021-11-24T07:15:56Z                                                NaN
# 13  2021-11-24T07:15:56Z  {'id': 33544610, 'login': 'luxteam', 'gravatar...
# 14  2021-11-24T07:15:56Z                                                NaN
# 15  2021-11-24T07:15:56Z                                                NaN
# 16  2021-11-24T07:15:56Z                                                NaN
# 17  2021-11-24T07:15:56Z                                                NaN
# 18  2021-11-24T07:15:56Z                                                NaN
# 19  2021-11-24T07:15:56Z  {'id': 60699748, 'login': 'DataHerb', 'gravata...
# 20  2021-11-24T07:15:56Z                                                NaN
# 21  2021-11-24T07:15:56Z  {'id': 47675013, 'login': 'MoTrPAC', 'gravatar...
# 22  2021-11-24T07:15:56Z                                                NaN
# 23  2021-11-24T07:15:56Z  {'id': 16575131, 'login': 'prayas-energy', 'gr...
# 24  2021-11-24T07:15:56Z                                                NaN
# 25  2021-11-24T07:15:56Z                                                NaN
# 26  2021-11-24T07:15:56Z                                                NaN
# 27  2021-11-24T07:15:55Z                                                NaN
# 28  2021-11-24T07:15:55Z                                                NaN
# 29  2021-11-24T07:15:55Z                                                NaN

# %%
# to "unpack" all the columns, we can use pd.json_normalize()
pd.json_normalize(response.json())
# Out:
#              id               type  public            created_at  actor.id  \
# 0   19030667340          PushEvent    True  2021-11-24T10:19:40Z      7842
# 1   19030667380  IssueCommentEvent    True  2021-11-24T10:19:40Z    548849
# 2   19030667332  IssueCommentEvent    True  2021-11-24T10:19:40Z   3521094
# 3   19030667363        CreateEvent    True  2021-11-24T10:19:40Z  73880125
# 4   19030667369        CreateEvent    True  2021-11-24T10:19:40Z    145845
# 5   19030667307          PushEvent    True  2021-11-24T10:19:40Z  89670698
# 6   19030667330        CreateEvent    True  2021-11-24T10:19:40Z  93844326
# 7   19030667315        CreateEvent    True  2021-11-24T10:19:40Z  11543329
# 8   19030667264         WatchEvent    True  2021-11-24T10:19:40Z    520895
# 9   19030667251   PullRequestEvent    True  2021-11-24T10:19:40Z  48274553
# 10  19030667268        DeleteEvent    True  2021-11-24T10:19:40Z  71354125
# 11  19030666985          PushEvent    True  2021-11-24T10:19:39Z  67962326
# 12  19030667243        DeleteEvent    True  2021-11-24T10:19:40Z   1589939
# 13  19030666978  IssueCommentEvent    True  2021-11-24T10:19:39Z     58601
# 14  19030666970        CreateEvent    True  2021-11-24T10:19:39Z  49699333
# 15  19030667197   PullRequestEvent    True  2021-11-24T10:19:40Z   1589939
# 16  19030667212          PushEvent    True  2021-11-24T10:19:40Z  73768462
# 17  19030667225          PushEvent    True  2021-11-24T10:19:40Z  90006330
# 18  19030667208          PushEvent    True  2021-11-24T10:19:40Z  90759393
# 19  19030667179   PullRequestEvent    True  2021-11-24T10:19:40Z  62998985
# 20  19030666862          PushEvent    True  2021-11-24T10:19:39Z  12016372
# 21  19030667192          PushEvent    True  2021-11-24T10:19:40Z  94719717
# 22  19030667156        CreateEvent    True  2021-11-24T10:19:40Z  71520923
# 23  19030667149         WatchEvent    True  2021-11-24T10:19:40Z  36675164
# 24  19030667176          PushEvent    True  2021-11-24T10:19:40Z  55102105
# 25  19030667132          PushEvent    True  2021-11-24T10:19:40Z  46171121
# 26  19030667143          PushEvent    True  2021-11-24T10:19:40Z  10861600
# 27  19030667137          PushEvent    True  2021-11-24T10:19:40Z  35823124
# 28  19030667142          PushEvent    True  2021-11-24T10:19:40Z  41898282
# 29  19030667130         WatchEvent    True  2021-11-24T10:19:40Z  40001125
#
#                       actor.login       actor.display_login actor.gravatar_id  \
# 0                          prabhu                    prabhu
# 1                           mtias                     mtias
# 2                   WinterSilence             WinterSilence
# 3                   GeremyBeaugas             GeremyBeaugas
# 4                         bussyjd                   bussyjd
# 5                    changfengoss              changfengoss
# 6                  Larrypeters777            Larrypeters777
# 7                ConfluentJenkins          ConfluentJenkins
# 8                         Wundark                   Wundark
# 9                        Lachouri                  Lachouri
# 10  aws-connector-for-github[bot]  aws-connector-for-github
# 11                        4Mugala                   4Mugala
# 12                     RandomByte                RandomByte
# 13                          nikku                     nikku
# 14                dependabot[bot]                dependabot
# 15                     RandomByte                RandomByte
# 16                         ymktmk                    ymktmk
# 17                      SashaLado                 SashaLado
# 18                      lperry481                 lperry481
# 19                      saritholl                 saritholl
# 20                      Thierry25                 Thierry25
# 21                       psalm136                  psalm136
# 22                       ptamas98                  ptamas98
# 23                     celiamaure                celiamaure
# 24                        toth152                   toth152
# 25                    goodtrailer               goodtrailer
# 26                    bvenkysubbu               bvenkysubbu
# 27                          llllb                     llllb
# 28            github-actions[bot]            github-actions
# 29                   kim-sunghoon              kim-sunghoon
#
#                                             actor.url  \
# 0                 https://api.github.com/users/prabhu
# 1                  https://api.github.com/users/mtias
# 2          https://api.github.com/users/WinterSilence
# 3          https://api.github.com/users/GeremyBeaugas
# 4                https://api.github.com/users/bussyjd
# 5           https://api.github.com/users/changfengoss
# 6         https://api.github.com/users/Larrypeters777
# 7       https://api.github.com/users/ConfluentJenkins
# 8                https://api.github.com/users/Wundark
# 9               https://api.github.com/users/Lachouri
# 10  https://api.github.com/users/aws-connector-for...
# 11               https://api.github.com/users/4Mugala
# 12            https://api.github.com/users/RandomByte
# 13                 https://api.github.com/users/nikku
# 14       https://api.github.com/users/dependabot[bot]
# 15            https://api.github.com/users/RandomByte
# 16                https://api.github.com/users/ymktmk
# 17             https://api.github.com/users/SashaLado
# 18             https://api.github.com/users/lperry481
# 19             https://api.github.com/users/saritholl
# 20             https://api.github.com/users/Thierry25
# 21              https://api.github.com/users/psalm136
# 22              https://api.github.com/users/ptamas98
# 23            https://api.github.com/users/celiamaure
# 24               https://api.github.com/users/toth152
# 25           https://api.github.com/users/goodtrailer
# 26           https://api.github.com/users/bvenkysubbu
# 27                 https://api.github.com/users/llllb
# 28   https://api.github.com/users/github-actions[bot]
# 29          https://api.github.com/users/kim-sunghoon
#
#                                      actor.avatar_url  ...  \
# 0       https://avatars.githubusercontent.com/u/7842?  ...
# 1     https://avatars.githubusercontent.com/u/548849?  ...
# 2    https://avatars.githubusercontent.com/u/3521094?  ...
# 3   https://avatars.githubusercontent.com/u/73880125?  ...
# 4     https://avatars.githubusercontent.com/u/145845?  ...
# 5   https://avatars.githubusercontent.com/u/89670698?  ...
# 6   https://avatars.githubusercontent.com/u/93844326?  ...
# 7   https://avatars.githubusercontent.com/u/11543329?  ...
# 8     https://avatars.githubusercontent.com/u/520895?  ...
# 9   https://avatars.githubusercontent.com/u/48274553?  ...
# 10  https://avatars.githubusercontent.com/u/71354125?  ...
# 11  https://avatars.githubusercontent.com/u/67962326?  ...
# 12   https://avatars.githubusercontent.com/u/1589939?  ...
# 13     https://avatars.githubusercontent.com/u/58601?  ...
# 14  https://avatars.githubusercontent.com/u/49699333?  ...
# 15   https://avatars.githubusercontent.com/u/1589939?  ...
# 16  https://avatars.githubusercontent.com/u/73768462?  ...
# 17  https://avatars.githubusercontent.com/u/90006330?  ...
# 18  https://avatars.githubusercontent.com/u/90759393?  ...
# 19  https://avatars.githubusercontent.com/u/62998985?  ...
# 20  https://avatars.githubusercontent.com/u/12016372?  ...
# 21  https://avatars.githubusercontent.com/u/94719717?  ...
# 22  https://avatars.githubusercontent.com/u/71520923?  ...
# 23  https://avatars.githubusercontent.com/u/36675164?  ...
# 24  https://avatars.githubusercontent.com/u/55102105?  ...
# 25  https://avatars.githubusercontent.com/u/46171121?  ...
# 26  https://avatars.githubusercontent.com/u/10861600?  ...
# 27  https://avatars.githubusercontent.com/u/35823124?  ...
# 28  https://avatars.githubusercontent.com/u/41898282?  ...
# 29  https://avatars.githubusercontent.com/u/40001125?  ...
#
#          payload.pull_request.merged_by.following_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  https://api.github.com/users/RandomByte/follow...
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#              payload.pull_request.merged_by.gists_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  https://api.github.com/users/RandomByte/gists{...
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#            payload.pull_request.merged_by.starred_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  https://api.github.com/users/RandomByte/starre...
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#      payload.pull_request.merged_by.subscriptions_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  https://api.github.com/users/RandomByte/subscr...
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#     payload.pull_request.merged_by.organizations_url  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
# 10                                               NaN
# 11                                               NaN
# 12                                               NaN
# 13                                               NaN
# 14                                               NaN
# 15      https://api.github.com/users/RandomByte/orgs
# 16                                               NaN
# 17                                               NaN
# 18                                               NaN
# 19                                               NaN
# 20                                               NaN
# 21                                               NaN
# 22                                               NaN
# 23                                               NaN
# 24                                               NaN
# 25                                               NaN
# 26                                               NaN
# 27                                               NaN
# 28                                               NaN
# 29                                               NaN
#
#          payload.pull_request.merged_by.repos_url  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# 5                                             NaN
# 6                                             NaN
# 7                                             NaN
# 8                                             NaN
# 9                                             NaN
# 10                                            NaN
# 11                                            NaN
# 12                                            NaN
# 13                                            NaN
# 14                                            NaN
# 15  https://api.github.com/users/RandomByte/repos
# 16                                            NaN
# 17                                            NaN
# 18                                            NaN
# 19                                            NaN
# 20                                            NaN
# 21                                            NaN
# 22                                            NaN
# 23                                            NaN
# 24                                            NaN
# 25                                            NaN
# 26                                            NaN
# 27                                            NaN
# 28                                            NaN
# 29                                            NaN
#
#             payload.pull_request.merged_by.events_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  https://api.github.com/users/RandomByte/events...
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#    payload.pull_request.merged_by.received_events_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  https://api.github.com/users/RandomByte/receiv...
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#    payload.pull_request.merged_by.type  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# 5                                  NaN
# 6                                  NaN
# 7                                  NaN
# 8                                  NaN
# 9                                  NaN
# 10                                 NaN
# 11                                 NaN
# 12                                 NaN
# 13                                 NaN
# 14                                 NaN
# 15                                User
# 16                                 NaN
# 17                                 NaN
# 18                                 NaN
# 19                                 NaN
# 20                                 NaN
# 21                                 NaN
# 22                                 NaN
# 23                                 NaN
# 24                                 NaN
# 25                                 NaN
# 26                                 NaN
# 27                                 NaN
# 28                                 NaN
# 29                                 NaN
#
#    payload.pull_request.merged_by.site_admin
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 7                                        NaN
# 8                                        NaN
# 9                                        NaN
# 10                                       NaN
# 11                                       NaN
# 12                                       NaN
# 13                                       NaN
# 14                                       NaN
# 15                                     False
# 16                                       NaN
# 17                                       NaN
# 18                                       NaN
# 19                                       NaN
# 20                                       NaN
# 21                                       NaN
# 22                                       NaN
# 23                                       NaN
# 24                                       NaN
# 25                                       NaN
# 26                                       NaN
# 27                                       NaN
# 28                                       NaN
# 29                                       NaN
#
# [30 rows x 474 columns]

# %% [markdown]
# ### Intenational Space Station
#
# Docs here: http://open-notify.org/Open-Notify-API/ISS-Location-Now/

# %%
# Make a get request to get the latest position of the international space station from the opennotify api.
response = requests.get("http://api.open-notify.org/iss-now.json")
# Print the status code of the response.
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'timestamp': 1637739385,
#  'iss_position': {'latitude': '51.0291', 'longitude': '171.5632'},
#  'message': 'success'}

# %% [markdown]
# {'iss_position': {'latitude': '10.7064', 'longitude': '-27.9890'},
#  'message': 'success',
#  'timestamp': 1623745101}

# %%
# last time it was over ironhack
  ## 52.53370520371973, 13.453475292072312
coordinates = {"lat": 52.53370520371973, "lon": 13.453475292072312}
response = requests.get("http://api.open-notify.org/iss-pass.json", params=coordinates)

# %%
response.status_code
# Out:
# 200

# %%
response.url
# Out:
# 'http://api.open-notify.org/iss-pass.json?lat=52.53370520371973&lon=13.453475292072312'

# %%
response = requests.get('http://api.open-notify.org/iss-pass.json?lat=52.53370520371973&lon=13.453475292072312')

# %%
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'message': 'success',
#  'request': {'altitude': 100,
#   'datetime': 1637739535,
#   'latitude': 52.53370520371973,
#   'longitude': 13.453475292072312,
#   'passes': 5},
#  'response': [{'duration': 536, 'risetime': 1637766652},
#   {'duration': 645, 'risetime': 1637772367},
#   {'duration': 660, 'risetime': 1637778159},
#   {'duration': 654, 'risetime': 1637783966},
#   {'duration': 593, 'risetime': 1637789779}]}

# %%
from datetime import datetime
datetime.fromtimestamp(1637772367)
# Out:
# datetime.datetime(2021, 11, 24, 17, 46, 7)

# %%
pd.to_datetime(1637772367, unit="s")
# Out:
# Timestamp('2021-11-24 16:46:07')

# %% [markdown]
# ### Weather API
#
# Create an account at RapidAPI and "subscribe" to the Weather API: https://rapidapi.com/weatherbit/api/

# %%
import requests

## https://rapidapi.com/community/api/open-weather-map/
url = "https://weatherbit-v1-mashape.p.rapidapi.com/current"

#My location coords: lat: 40.545111, lon: -4.204942
querystring = {"lon":"-4.204942","lat":"40.545111"}
querystring["units"] ="metric"
querystring["lang"] = "en"

headers = {
    'x-rapidapi-key': x_rapidapi_key,
    'x-rapidapi-host': "weatherbit-v1-mashape.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/gh/s8b9pd096y13z1bxsq63d0x40000gn/T/ipykernel_26336/494424325.py in <module>
#      10
#      11 headers = {
# ---> 12     'x-rapidapi-key': x_rapidapi_key,
#      13     'x-rapidapi-host': "weatherbit-v1-mashape.p.rapidapi.com"
#      14     }
#
# NameError: name 'x_rapidapi_key' is not defined

# %%
results = response.json()
print(results)
type(results)
# Out:
# {'message': 'success', 'request': {'altitude': 100, 'datetime': 1637739535, 'latitude': 52.53370520371973, 'longitude': 13.453475292072312, 'passes': 5}, 'response': [{'duration': 536, 'risetime': 1637766652}, {'duration': 645, 'risetime': 1637772367}, {'duration': 660, 'risetime': 1637778159}, {'duration': 654, 'risetime': 1637783966}, {'duration': 593, 'risetime': 1637789779}]}
# dict

# %%
results.keys()
# Out:
# dict_keys(['message', 'request', 'response'])

# %%
results['data']
# Out:
# [{'app_temp': 25.4,
#   'aqi': 68,
#   'city_name': 'Zarzalejo',
#   'clouds': 75,
#   'country_code': 'ES',
#   'datetime': '2021-06-15:08',
#   'dewpt': 12.4,
#   'dhi': 92.52,
#   'dni': 808.24,
#   'elev_angle': 34.18,
#   'ghi': 540.97,
#   'h_angle': -45,
#   'lat': 40.55,
#   'lon': -4.2,
#   'ob_time': '2021-06-15 08:00',
#   'pod': 'd',
#   'precip': 0,
#   'pres': 945.1,
#   'rh': 44,
#   'slp': 1018.9,
#   'snow': 0,
#   'solar_rad': 378.2,
#   'state_code': '29',
#   'station': 'F7959',
#   'sunrise': '04:44',
#   'sunset': '19:48',
#   'temp': 25.6,
#   'timezone': 'Europe/Madrid',
#   'ts': 1623744000,
#   'uv': 5.89272,
#   'vis': 5,
#   'weather': {'code': 802, 'description': 'Scattered clouds', 'icon': 'c02d'},
#   'wind_cdir': 'NE',
#   'wind_cdir_full': 'northeast',
#   'wind_dir': 44,
#   'wind_spd': 1}]

# %% [markdown]
# Getting the forecast for the next 5 days at a 3h intervals

# %%
import requests

url = "https://weatherbit-v1-mashape.p.rapidapi.com/forecast/3hourly"

headers = {
    'x-rapidapi-key': x_rapidapi_key,
    'x-rapidapi-host': "weatherbit-v1-mashape.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
results = response.json()
print(results)
# Out:
# {'data': [{'wind_cdir': 'ENE', 'rh': 39, 'pod': 'd', 'timestamp_utc': '2021-06-15T09:00:00', 'pres': 884.145, 'solar_rad': 564.782, 'ozone': 336, 'weather': {'icon': 'c02d', 'code': 802, 'description': 'Scattered clouds'}, 'wind_gust_spd': 11.5571, 'timestamp_local': '2021-06-15T11:00:00', 'snow_depth': 0, 'clouds': 69, 'ts': 1623747600, 'wind_spd': 4.07371, 'pop': 15, 'wind_cdir_full': 'east-northeast', 'slp': 1018.79, 'dni': 868.79, 'dewpt': 7.9, 'snow': 0, 'uv': 2.81755, 'wind_dir': 78, 'clouds_hi': 0, 'precip': 0.001953125, 'vis': 24.128, 'dhi': 103.41, 'app_temp': 22.4, 'datetime': '2021-06-15:09', 'temp': 23, 'ghi': 717.09, 'clouds_mid': 69, 'clouds_low': 0}, {'wind_cdir': 'ESE', 'rh': 27, 'pod': 'd', 'timestamp_utc': '2021-06-15T12:00:00', 'pres': 883.112, 'solar_rad': 974.853, 'ozone': 328, 'weather': {'icon': 'c02d', 'code': 801, 'description': 'Few clouds'}, 'wind_gust_spd': 11.7118, 'timestamp_local': '2021-06-15T14:00:00', 'snow_depth': 0, 'clouds': 38, 'ts': 1623758400, 'wind_spd': 5.50618, 'pop': 0, 'wind_cdir_full': 'east-southeast', 'slp': 1016.89, 'dni': 937.94, 'dewpt': 6, 'snow': 0, 'uv': 7.58151, 'wind_dir': 111, 'clouds_hi': 2, 'precip': 0, 'vis': 24.128, 'dhi': 117.62, 'app_temp': 26.2, 'datetime': '2021-06-15:12', 'temp': 26.8, 'ghi': 1002.88, 'clouds_mid': 39, 'clouds_low': 0}, {'wind_cdir': 'SSE', 'rh': 24, 'pod': 'd', 'timestamp_utc': '2021-06-15T15:00:00', 'pres': 881.339, 'solar_rad': 565.139, 'ozone': 323, 'weather': {'icon': 'c02d', 'code': 802, 'description': 'Scattered clouds'}, 'wind_gust_spd': 12.2921, 'timestamp_local': '2021-06-15T17:00:00', 'snow_depth': 0, 'clouds': 76, 'ts': 1623769200, 'wind_spd': 4.28592, 'pop': 15, 'wind_cdir_full': 'south-southeast', 'slp': 1014.46, 'dni': 892.15, 'dewpt': 5.4, 'snow': 0, 'uv': 3.15302, 'wind_dir': 164, 'clouds_hi': 43, 'precip': 0.048828125, 'vis': 24.128, 'dhi': 107.98, 'app_temp': 26.9, 'datetime': '2021-06-15:15', 'temp': 28.1, 'ghi': 801.62, 'clouds_mid': 56, 'clouds_low': 0}, {'wind_cdir': 'S', 'rh': 28, 'pod': 'd', 'timestamp_utc': '2021-06-15T18:00:00', 'pres': 880.719, 'solar_rad': 170.431, 'ozone': 320.5, 'weather': {'icon': 'c04d', 'code': 804, 'description': 'Overcast clouds'}, 'wind_gust_spd': 10.1157, 'timestamp_local': '2021-06-15T20:00:00', 'snow_depth': 0, 'clouds': 80, 'ts': 1623780000, 'wind_spd': 4.75035, 'pop': 15, 'wind_cdir_full': 'south', 'slp': 1013.91, 'dni': 647.18, 'dewpt': 6, 'snow': 0, 'uv': 0.813903, 'wind_dir': 169, 'clouds_hi': 12, 'precip': 0.021484375, 'vis': 19.2, 'dhi': 68.69, 'app_temp': 25.8, 'datetime': '2021-06-15:18', 'temp': 26.4, 'ghi': 262.69, 'clouds_mid': 78, 'clouds_low': 0}, {'wind_cdir': 'NE', 'rh': 48, 'pod': 'n', 'timestamp_utc': '2021-06-15T21:00:00', 'pres': 881.045, 'solar_rad': 0, 'ozone': 319, 'weather': {'icon': 'c04n', 'code': 804, 'description': 'Overcast clouds'}, 'wind_gust_spd': 7.37562, 'timestamp_local': '2021-06-15T23:00:00', 'snow_depth': 0, 'clouds': 100, 'ts': 1623790800, 'wind_spd': 2.08412, 'pop': 10, 'wind_cdir_full': 'northeast', 'slp': 1015.38, 'dni': 0, 'dewpt': 9.5, 'snow': 0, 'uv': 0, 'wind_dir': 48, 'clouds_hi': 100, 'precip': 0.095703125, 'vis': 24.128, 'dhi': 0, 'app_temp': 20.8, 'datetime': '2021-06-15:21', 'temp': 21.4, 'ghi': 0, 'clouds_mid': 81, 'clouds_low': 8}, {'wind_cdir': 'E', 'rh': 67, 'pod': 'n', 'timestamp_utc': '2021-06-16T00:00:00', 'pres': 881.915, 'solar_rad': 0, 'ozone': 324.75, 'weather': {'icon': 'r04n', 'code': 520, 'description': 'Light shower rain'}, 'wind_gust_spd': 9.4193, 'timestamp_local': '2021-06-16T02:00:00', 'snow_depth': 0, 'clouds': 100, 'ts': 1623801600, 'wind_spd': 1.0167, 'pop': 25, 'wind_cdir_full': 'east', 'slp': 1017.05, 'dni': 0, 'dewpt': 11.9, 'snow': 0, 'uv': 0, 'wind_dir': 90, 'clouds_hi': 100, 'precip': 0.33984375, 'vis': 24.128, 'dhi': 0, 'app_temp': 18.1, 'datetime': '2021-06-16:00', 'temp': 18.4, 'ghi': 0, 'clouds_mid': 70, 'clouds_low': 4}, {'wind_cdir': 'ENE', 'rh': 67, 'pod': 'n', 'timestamp_utc': '2021-06-16T03:00:00', 'pre ...
