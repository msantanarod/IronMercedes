# %% [markdown]
# # Customer Analysis Case Study

# %% [markdown]
# The aim of this project is to develop a machine learning predictive model to estimate the target variable: Total Claim Amount, based on the dataset ('Data_Marketing_Customer_Analysis_Round2.csv'), provided by Ironhack Academy.
#
# Our dataset has 10910 rows and 25 columns. The variables name are provided below:
#
# -Customer <br>
# -State <br>
# -Customer Livetime Value <br>
# -Responses <br>
# -Coverage <br>
# -Education <br>
# -Effective to Date <br>
# -Employment Status <br>
# -Gender <br>
# -Income <br>
# -Location Code <br>
# -Marital Status <br>
# -Monthly Premium Auto <br>
# -Months Since Policy Inception <br>
# -Number of Open Complaints <br>
# -Number of Policies <br>
# -Policy Type <br>
# -Policy <br>
# -Renew offer Type <br>
# -Sales Channel <br>
# -Vehicle Class <br>
# -Vehicle Size <br>
# -Vehicle Type <br>
# -Total Claim Amount<br>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Loading-data" data-toc-modified-id="Loading-data-3">Loading data</a></span></li><li><span><a href="#Important-Functions" data-toc-modified-id="Important-Functions-4">Important Functions</a></span><ul class="toc-item"><li><span><a href="#Data-Cleaning-Function" data-toc-modified-id="Data-Cleaning-Function-4.1">Data Cleaning Function</a></span></li><li><span><a href="#Transform-Function" data-toc-modified-id="Transform-Function-4.2">Transform Function</a></span></li><li><span><a href="#Removing-outlier-function" data-toc-modified-id="Removing-outlier-function-4.3">Removing outlier function</a></span></li></ul></li><li><span><a href="#Cleaning-&amp;-Transforming-Data" data-toc-modified-id="Cleaning-&amp;-Transforming-Data-5">Cleaning &amp; Transforming Data</a></span></li><li><span><a href="#Exploratory-Data-Analysis-(EDA)" data-toc-modified-id="Exploratory-Data-Analysis-(EDA)-6">Exploratory Data Analysis (EDA)</a></span><ul class="toc-item"><li><span><a href="#Filtering-data-and-Correcting-typos" data-toc-modified-id="Filtering-data-and-Correcting-typos-6.1">Filtering data and Correcting typos</a></span></li><li><span><a href="#Replace-&quot;0&quot;-values-for-mean-value" data-toc-modified-id="Replace-&quot;0&quot;-values-for-mean-value-6.2">Replace "0" values for mean value</a></span></li><li><span><a href="#Null-values" data-toc-modified-id="Null-values-6.3">Null values</a></span></li><li><span><a href="#Creating-new-variable" data-toc-modified-id="Creating-new-variable-6.4">Creating new variable</a></span></li></ul></li><li><span><a href="#Numerical/-Categorical-variables" data-toc-modified-id="Numerical/-Categorical-variables-7">Numerical/ Categorical variables</a></span></li><li><span><a href="#Plots" data-toc-modified-id="Plots-8">Plots</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Total-number-of-responses:" data-toc-modified-id="Total-number-of-responses:-8.0.1">Total number of responses:</a></span></li><li><span><a href="#Response-rate-by-the-sales-channel" data-toc-modified-id="Response-rate-by-the-sales-channel-8.0.2">Response rate by the sales channel</a></span></li><li><span><a href="#Response-rate-by-the-total-claim-amount" data-toc-modified-id="Response-rate-by-the-total-claim-amount-8.0.3">Response rate by the total claim amount</a></span></li></ul></li></ul></li><li><span><a href="#Removing-outliers-from-numerical-variables" data-toc-modified-id="Removing-outliers-from-numerical-variables-9">Removing outliers from numerical variables</a></span></li><li><span><a href="#Normality-of-the-numerical-variables" data-toc-modified-id="Normality-of-the-numerical-variables-10">Normality of the numerical variables</a></span></li><li><span><a href="#Predictive-Modeling" data-toc-modified-id="Predictive-Modeling-11">Predictive Modeling</a></span><ul class="toc-item"><li><span><a href="#XY-split" data-toc-modified-id="XY-split-11.1">XY split</a></span></li><li><span><a href="#Scaling" data-toc-modified-id="Scaling-11.2">Scaling</a></span></li><li><span><a href="#Hot-coding-Categorical-Variables" data-toc-modified-id="Hot-coding-Categorical-Variables-11.3">Hot coding Categorical Variables</a></span></li><li><span><a href="#Applying-linear-regresion-using-Statsmodels" data-toc-modified-id="Applying-linear-regresion-using-Statsmodels-11.4">Applying linear regresion using Statsmodels</a></span><ul class="toc-item"><li><span><a href="#Without-Scaler" data-toc-modified-id="Without-Scaler-11.4.1">Without Scaler</a></span></li><li><span><a href="#With-Scaler" data-toc-modified-id="With-Scaler-11.4.2">With Scaler</a></span></li></ul></li></ul></li><li><span><a href="#Model-without-the-irrelevant-variables" data-toc-modified-id="Model-without-the-irrelevant-variables-12">Model without the irrelevant variables</a></span><ul class="toc-item"><li><span><a href="#With-Scaler" data-toc-modified-id="With-Scaler-12.1">With Scaler</a></span></li><li><span><a href="#Without-scaler" data-toc-modified-id="Without-scaler-12.2">Without scaler</a></span></li></ul></li><li><span><a href="#Modeling-using-Scikit-Learn" data-toc-modified-id="Modeling-using-Scikit-Learn-13">Modeling using Scikit Learn</a></span></li><li><span><a href="#Model-Comparison" data-toc-modified-id="Model-Comparison-14">Model Comparison</a></span><ul class="toc-item"><li><span><a href="#Lasso" data-toc-modified-id="Lasso-14.1">Lasso</a></span></li><li><span><a href="#Ridge" data-toc-modified-id="Ridge-14.2">Ridge</a></span></li><li><span><a href="#Linear-regression" data-toc-modified-id="Linear-regression-14.3">Linear regression</a></span></li><li><span><a href="#KNeighborsRegressor" data-toc-modified-id="KNeighborsRegressor-14.4">KNeighborsRegressor</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Loading data

# %%
# we need to import the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection
# %matplotlib inline
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PowerTransformer
from sklearn.linear_model import LinearRegression
from scipy.stats import boxcox
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae
pd.options.display.max_rows = 50
from ipywidgets import interactive
import ipywidgets as widgets
import statsmodels.api as sm
import math
from sklearn import linear_model
from sklearn.linear_model import Ridge
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neighbors import NearestNeighbors
from sklearn.metrics import r2_score
from sklearn.preprocessing import FunctionTransformer

# %%
# We import our data from Excel file
ca_df=pd.read_csv("Data/Data_Marketing_Customer_Analysis_Round2.csv")
ca_df
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0         Basic   College           2/18/11         Employed      M  ...
# 1         Basic   College           1/18/11       Unemployed      F  ...
# 2         Basic  Bachelor           2/10/11         Employed      M  ...
# 3      Extended   College           1/11/11         Employed      M  ...
# 4       Premium  Bachelor           1/17/11    Medical Leave      F  ...
# ...         ...       ...               ...              ...    ...  ...
# 10905   Premium  Bachelor           1/19/11       Unemployed      F  ...
# 10906     Basic   College            1/6/11         Employed      F  ...
# 10907  Extended  Bachelor            2/6/11         Employed      F  ...
# 10908   Premium   College           2/13/11         Employed      F  ...
# 10909     Basic  Bachelor            1/8/11       Unemployed      M  ...
#
#        Number of Open Complaints Number of Policies     Policy Type  \
# 0                            0.0                  9  Corporate Auto
# 1                            0.0                  1   Personal Auto
# 2                            0.0                  2   Personal Auto
# 3                            0.0                  2  Corporate Auto
# 4                            NaN                  7   Personal Auto
# ...                          ...                ...             ...
# 10905                        NaN                  7   Personal Auto
# 10906                        0.0                  6   Personal Auto
# 10907                        0.0                  2  Corporate Auto
# 10908                        4.0                  6   Personal Auto
# 10909                        0.0                  3   Personal Auto
#
#              Policy  Renew Offer Type  Sales Channel  Total Claim Amount  \
# 0      Corporate L3            Offer3          Agent          292.800000
# 1       Personal L3            Offer4    Call Center          744.924331
# 2       Personal L3            Offer3    Call Center          480.000000
# 3      Corporate L3            Offer2         Branch          484.013411
# 4       Personal L2            Offer1         Branch          707.925645
# ...             ...               ...            ...                 ...
# 10905   Personal L1            Offer3            Web         1214.400000
# 10906   Personal L3            Offer2         Branch          273.018929
# 10907  Corporate L3            Offer1            Web          381.306996
# 10908   Personal L1            Offer1         Branch          618.288849
# 10909   Personal L1            Offer4            Web         1021.719397
#
#        Vehicle Class Vehicle Size Vehicle Type
# 0      Four-Door Car      Medsize          NaN
# 1      Four-Door Car      Medsize          NaN
# 2                SUV      Medsize            A
# 3      Four-Door Car      Medsize            A
# 4      Four-Door Car      Medsize          NaN
# ...              ...          ...          ...
# 10905     Luxury Car      Medsize            A
# 10906  Four-Door Car      Medsize            A
# 10907     Luxury SUV      Medsize          NaN
# 10908            SUV      Medsize            A
# 10909            SUV      Medsize          NaN
#
# [10910 rows x 26 columns]

# %% [markdown]
# ## Important Functions

# %% [markdown]
# ### Data Cleaning Function

# %%
def clean_data(df):
    df.columns=[e.lower().replace(' ', '_') for e in df.columns]
    df=df.drop(columns=['unnamed:_0', 'vehicle_type',"customer"])
    df=df.dropna()
    df['effective_to_date']=pd.to_datetime(df['effective_to_date'], errors='coerce')
    df["month"]=list(map(lambda date:date.strftime(format="%B"),df["effective_to_date"]))
    # we drop effective_to_date column
    df=df.drop(columns=['effective_to_date'])
    df.drop_duplicates()
    return df

# %% [markdown]
# ### Transform Function

# %%
def transform(df):
    df=df[df['income']>0]
    df["total_claim_amount"]=round(df["total_claim_amount"],0)
    df["customer_lifetime_value"]=round(df["customer_lifetime_value"],0)
    df.vehicle_class[ca_df.vehicle_class.isin(["Luxury Car","Luxury SUV"])] = "Luxury Car"
    df.vehicle_class[ca_df.vehicle_class.isin(["Four-Door Car","SUV"])] = "Four-Door Car"
    df.policy[df.policy.isin(["Personal L3","Personal L2","Personal L1"]) ] = "Personal"
    df.policy[df.policy.isin(["Corporate L3","Corporate L2","Corporate L1"]) ] = "Corporate"
    df.policy[df.policy.isin(["Special L3","Special L2","Special L1"]) ] = "Special"
    df=df.drop(columns=["month","education"])
    df.number_of_policies[df.number_of_policies>2]=3
    return df

# %% [markdown]
# ## Cleaning & Transforming Data

# %%
ca_df=clean_data(ca_df)
ca_df=transform(ca_df)
# Out:
# C:\Users\merce\AppData\Local\Temp/ipykernel_12160/3271366430.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["total_claim_amount"]=round(df["total_claim_amount"],0)
# C:\Users\merce\AppData\Local\Temp/ipykernel_12160/3271366430.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["customer_lifetime_value"]=round(df["customer_lifetime_value"],0)
# C:\Users\merce\AppData\Local\Temp/ipykernel_12160/3271366430.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.vehicle_class[ca_df.vehicle_class.isin(["Luxury Car","Luxury SUV"])] = "Luxury Car"
# C:\Users\merce\anaconda3\envs\Da_Env1\lib\site-packages\pandas\core\generic.py:8870: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)
# C:\Users\merce\AppData\Local\Temp/ipykernel_12160/3271366430.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.vehicle_class[ca_df.vehicle_class.isin(["Four-Door Car","SUV"])] = "Four-Door Car"
# C:\Users\merce\AppData\Local\Temp/ipykernel_12160/3271366430.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.policy[df.policy.isin(["Personal L3","Personal L2","Personal L1"]) ] = "Personal"
# C:\Users\merce\AppData\Local\Temp/ipykernel_12160/3271366430.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.policy[df.policy.isin(["Corporate L3","Corporate L2","Corporate L1"]) ] = "Corporate"
# C:\Users\merce\AppData\Local\Temp/ipykernel_12160/3271366430.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.policy[df.policy.isin(["Special L3","Special L2","Special L1"]) ] = "Special"
# C:\Users\merce\AppData\Local\Temp/ipykernel_12160/3271366430.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.number_of_policies[df.number_of_policies>2]=3

# %%
ca_df
# Out:
#             state  customer_lifetime_value response  coverage  \
# 0         Arizona                   4809.0       No     Basic
# 2      Washington                  14948.0       No     Basic
# 3          Oregon                  22332.0      Yes  Extended
# 6      California                   5035.0       No     Basic
# 7      California                   4956.0       No     Basic
# ...           ...                      ...      ...       ...
# 10902  California                   3579.0       No  Extended
# 10903     Arizona                   2772.0       No     Basic
# 10906      Oregon                   5259.0       No     Basic
# 10907     Arizona                  23893.0       No  Extended
# 10908  California                  11972.0       No   Premium
#
#       employmentstatus gender  income location_code marital_status  \
# 0             Employed      M   48029      Suburban        Married
# 2             Employed      M   22139      Suburban         Single
# 3             Employed      M   49078      Suburban         Single
# 6             Employed      F   37405         Urban        Married
# 7             Employed      M   87197         Urban         Single
# ...                ...    ...     ...           ...            ...
# 10902         Employed      F   28304      Suburban        Married
# 10903         Employed      M   59855      Suburban        Married
# 10906         Employed      F   61146         Urban        Married
# 10907         Employed      F   39837         Rural        Married
# 10908         Employed      F   64195         Urban       Divorced
#
#        monthly_premium_auto  ...  months_since_policy_inception  \
# 0                        61  ...                             52
# 2                       100  ...                             31
# 3                        97  ...                              3
# 6                        63  ...                             99
# 7                        63  ...                             45
# ...                     ...  ...                            ...
# 10902                    91  ...                             30
# 10903                    74  ...                             82
# 10906                    65  ...                             68
# 10907                   201  ...                             63
# 10908                   158  ...                             27
#
#        number_of_open_complaints  number_of_policies     policy_type  \
# 0                            0.0                   3  Corporate Auto
# 2                            0.0                   2   Personal Auto
# 3                            0.0                   2  Corporate Auto
# 6                            3.0                   3  Corporate Auto
# 7                            0.0                   3   Personal Auto
# ...                          ...                 ...             ...
# 10902                        2.0                   1   Personal Auto
# 10903                        4.0                   1   Personal Auto
# 10906                        0.0                   3   Personal Auto
# 10907                        0.0                   2  Corporate Auto
# 10908                        4.0                   3   Personal Auto
#
#           policy renew_offer_type sales_channel total_claim_amount  \
# 0      Corporate           Offer3         Agent              293.0
# 2       Personal           Offer3   Call Center              480.0
# 3      Corporate           Offer2        Branch              484.0
# 6      Corporate           Offer2        Branch              288.0
# 7       Personal           Offer2        Branch              247.0
# ...          ...              ...           ...                ...
# 10902   Personal           Offer2         Agent              655.0
# 10903   Personal           Offer2        Branch              355.0
# 10906   Personal           Offer2        Branch              273.0
# 10907  Corporate           Offer1           Web              381.0
# 10908   Personal           Offer1        Branch              618.0
#
#        vehicle_class vehicle_size
# 0      Four-Door Car      Medsize
# 2      Four-Door Car      Medsize
# 3      Four-Door Car      Medsize
# 6      Four-Door Car      Medsize
# 7       Two-Door Car      Medsize
# ...              ...          ...
# 10902  Four-Door Car      Medsize
# 10903   Two-Door Car      Medsize
# 10906  Four-Door Car      Medsize
# 10907     Luxury Car      Medsize
# 10908  Four-Door Car      Medsize
#
# [6817 rows x 21 columns]

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
# checking data type of our data set
ca_df.info()
# We this function we can see the data type.
# after checkin the data. The column "number of open complaint" should not be a float.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6817 entries, 0 to 10908
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   state                          6817 non-null   object
#  1   customer_lifetime_value        6817 non-null   float64
#  2   response                       6817 non-null   object
#  3   coverage                       6817 non-null   object
#  4   employmentstatus               6817 non-null   object
#  5   gender                         6817 non-null   object
#  6   income                         6817 non-null   int64
#  7   location_code                  6817 non-null   object
#  8   marital_status                 6817 non-null   object
#  9   monthly_premium_auto           6817 non-null   int64
#  10  months_since_last_claim        6817 non-null   float64
#  11  months_since_policy_inception  6817 non-null   int64
#  12  number_of_open_complaints      6817 non-null   float64
#  13  number_of_policies             6817 non-null   int64
#  14  policy_type                    6817 non-null   object
#  15  policy                         6817 non-null   object
#  16  renew_offer_type               6817 non-null   object
#  17  sales_channel                  6817 non-null   object
#  18  total_claim_amount             6817 non-null   float64
#  19  vehicle_class                  6817 non-null   object
#  20  vehicle_size                   6817 non-null   object
# dtypes: float64(4), int64(4), object(13)
# memory usage: 1.1+ MB

# %%
# variable "number_of_open_complaints" should not be a float number. 
# We can see that there is many NaN values in the columns.
#We cannot transform "number_of_open_complaints" into an integer because of Nan values 
#In this case, we have to replace the NaN values with "0" with replace function.


ca_df['number_of_open_complaints'] = ca_df['number_of_open_complaints'].fillna(0)

# %%
# we can transform "number_of_open_complaints" into an integer

ca_df['number_of_open_complaints'] = ca_df['number_of_open_complaints'].astype('int')

# %%
ca_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6817 entries, 0 to 10908
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   state                          6817 non-null   object
#  1   customer_lifetime_value        6817 non-null   float64
#  2   response                       6817 non-null   object
#  3   coverage                       6817 non-null   object
#  4   employmentstatus               6817 non-null   object
#  5   gender                         6817 non-null   object
#  6   income                         6817 non-null   int64
#  7   location_code                  6817 non-null   object
#  8   marital_status                 6817 non-null   object
#  9   monthly_premium_auto           6817 non-null   int64
#  10  months_since_last_claim        6817 non-null   float64
#  11  months_since_policy_inception  6817 non-null   int64
#  12  number_of_open_complaints      6817 non-null   int32
#  13  number_of_policies             6817 non-null   int64
#  14  policy_type                    6817 non-null   object
#  15  policy                         6817 non-null   object
#  16  renew_offer_type               6817 non-null   object
#  17  sales_channel                  6817 non-null   object
#  18  total_claim_amount             6817 non-null   float64
#  19  vehicle_class                  6817 non-null   object
#  20  vehicle_size                   6817 non-null   object
# dtypes: float64(3), int32(1), int64(4), object(13)
# memory usage: 1.1+ MB

# %% [markdown]
# ### Filtering data and Correcting typos

# %%
# We need to standardize the text in the column "gender".

ca_df['gender'].value_counts()
# Out:
# F    3523
# M    3294
# Name: gender, dtype: int64

# %%
# number of missing values in the column "gender"

len(ca_df[ca_df['gender'].isna()==True])
# Out:
# 0

# %%
# with the new data set, the column text is already standardized

ca_df.gender.unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
#Let's have a look to the column "state"

ca_df['state'].value_counts()
# Out:
# California    2346
# Oregon        1937
# Arizona       1273
# Nevada         665
# Washington     596
# Name: state, dtype: int64

# %%
len(ca_df[ca_df['state'].isna()==True])
# Out:
# 0

# %%
def clean_state(x):
    if x in ['California', 'Cali']:
        return 'california'
    elif x in["Arizona","az"]:
        return 'arizona'
    elif x in ["Washington","wa"]:
         return "washington"
    elif x in ["Oregon"]:
         return "oregon"
    elif x in ["Nevada"]:
        return "nevada"
    else:
        return 'U'

# %%
ca_df['state'] = list(map(clean_state, ca_df['state']))

# %%
ca_df.state.unique()
# Out:
# array(['arizona', 'washington', 'oregon', 'california', 'nevada'],
#       dtype=object)

# %% [markdown]
# ### Replace "0" values for mean value

# %%
# columns "income" and "number_of_open_complaints" have many "0" values. We will replace the values
ca_df['income']=ca_df['income'].replace(0,ca_df['income'].mean())
ca_df['number_of_open_complaints']=ca_df['number_of_open_complaints'].replace(0,ca_df['number_of_open_complaints'].mean())

# %%
ca_df
# Out:
#             state  customer_lifetime_value response  coverage  \
# 0         arizona                   4809.0       No     Basic
# 2      washington                  14948.0       No     Basic
# 3          oregon                  22332.0      Yes  Extended
# 6      california                   5035.0       No     Basic
# 7      california                   4956.0       No     Basic
# ...           ...                      ...      ...       ...
# 10902  california                   3579.0       No  Extended
# 10903     arizona                   2772.0       No     Basic
# 10906      oregon                   5259.0       No     Basic
# 10907     arizona                  23893.0       No  Extended
# 10908  california                  11972.0       No   Premium
#
#       employmentstatus gender  income location_code marital_status  \
# 0             Employed      M   48029      Suburban        Married
# 2             Employed      M   22139      Suburban         Single
# 3             Employed      M   49078      Suburban         Single
# 6             Employed      F   37405         Urban        Married
# 7             Employed      M   87197         Urban         Single
# ...                ...    ...     ...           ...            ...
# 10902         Employed      F   28304      Suburban        Married
# 10903         Employed      M   59855      Suburban        Married
# 10906         Employed      F   61146         Urban        Married
# 10907         Employed      F   39837         Rural        Married
# 10908         Employed      F   64195         Urban       Divorced
#
#        monthly_premium_auto  ...  months_since_policy_inception  \
# 0                        61  ...                             52
# 2                       100  ...                             31
# 3                        97  ...                              3
# 6                        63  ...                             99
# 7                        63  ...                             45
# ...                     ...  ...                            ...
# 10902                    91  ...                             30
# 10903                    74  ...                             82
# 10906                    65  ...                             68
# 10907                   201  ...                             63
# 10908                   158  ...                             27
#
#        number_of_open_complaints  number_of_policies     policy_type  \
# 0                        0.38184                   3  Corporate Auto
# 2                        0.38184                   2   Personal Auto
# 3                        0.38184                   2  Corporate Auto
# 6                        3.00000                   3  Corporate Auto
# 7                        0.38184                   3   Personal Auto
# ...                          ...                 ...             ...
# 10902                    2.00000                   1   Personal Auto
# 10903                    4.00000                   1   Personal Auto
# 10906                    0.38184                   3   Personal Auto
# 10907                    0.38184                   2  Corporate Auto
# 10908                    4.00000                   3   Personal Auto
#
#           policy renew_offer_type sales_channel total_claim_amount  \
# 0      Corporate           Offer3         Agent              293.0
# 2       Personal           Offer3   Call Center              480.0
# 3      Corporate           Offer2        Branch              484.0
# 6      Corporate           Offer2        Branch              288.0
# 7       Personal           Offer2        Branch              247.0
# ...          ...              ...           ...                ...
# 10902   Personal           Offer2         Agent              655.0
# 10903   Personal           Offer2        Branch              355.0
# 10906   Personal           Offer2        Branch              273.0
# 10907  Corporate           Offer1           Web              381.0
# 10908   Personal           Offer1        Branch              618.0
#
#        vehicle_class vehicle_size
# 0      Four-Door Car      Medsize
# 2      Four-Door Car      Medsize
# 3      Four-Door Car      Medsize
# 6      Four-Door Car      Medsize
# 7       Two-Door Car      Medsize
# ...              ...          ...
# 10902  Four-Door Car      Medsize
# 10903   Two-Door Car      Medsize
# 10906  Four-Door Car      Medsize
# 10907     Luxury Car      Medsize
# 10908  Four-Door Car      Medsize
#
# [6817 rows x 21 columns]

# %% [markdown]
# ###  Null values

# %%
# in this section, we check if there are missing values in ca_df. 
#The percentage of missing values in ca_df is 0. 

nulls_df = pd.DataFrame(round(ca_df.isna().sum()/len(ca_df),4)*100)
nulls_df = nulls_df.reset_index()
nulls_df.columns = ['header_name', 'percent_nulls']
nulls_df
# Out:
#                       header_name  percent_nulls
# 0                           state            0.0
# 1         customer_lifetime_value            0.0
# 2                        response            0.0
# 3                        coverage            0.0
# 4                employmentstatus            0.0
# 5                          gender            0.0
# 6                          income            0.0
# 7                   location_code            0.0
# 8                  marital_status            0.0
# 9            monthly_premium_auto            0.0
# 10        months_since_last_claim            0.0
# 11  months_since_policy_inception            0.0
# 12      number_of_open_complaints            0.0
# 13             number_of_policies            0.0
# 14                    policy_type            0.0
# 15                         policy            0.0
# 16               renew_offer_type            0.0
# 17                  sales_channel            0.0
# 18             total_claim_amount            0.0
# 19                  vehicle_class            0.0
# 20                   vehicle_size            0.0

# %% [markdown]
# ### Creating new variable

# %%
# we will create a new column called "region". This new column will represent data from column "state" as follows:

# california = West
# Oregon = North
# washington = East
# Arizona & Nevada = Central

# First, I will create a dictionary with the new labels

# %%
state_labels ={
    "california":"west",
    "oregon":"north",
    "washington":"east",
    "arizona":"central",
    "nevada":"central"
}

# %%
# We can use assign function to append a new column called "region"

ca_df=ca_df.assign(region=ca_df.state.map(state_labels))

# %%
ca_df
# Out:
#             state  customer_lifetime_value response  coverage  \
# 0         arizona                   4809.0       No     Basic
# 2      washington                  14948.0       No     Basic
# 3          oregon                  22332.0      Yes  Extended
# 6      california                   5035.0       No     Basic
# 7      california                   4956.0       No     Basic
# ...           ...                      ...      ...       ...
# 10902  california                   3579.0       No  Extended
# 10903     arizona                   2772.0       No     Basic
# 10906      oregon                   5259.0       No     Basic
# 10907     arizona                  23893.0       No  Extended
# 10908  california                  11972.0       No   Premium
#
#       employmentstatus gender  income location_code marital_status  \
# 0             Employed      M   48029      Suburban        Married
# 2             Employed      M   22139      Suburban         Single
# 3             Employed      M   49078      Suburban         Single
# 6             Employed      F   37405         Urban        Married
# 7             Employed      M   87197         Urban         Single
# ...                ...    ...     ...           ...            ...
# 10902         Employed      F   28304      Suburban        Married
# 10903         Employed      M   59855      Suburban        Married
# 10906         Employed      F   61146         Urban        Married
# 10907         Employed      F   39837         Rural        Married
# 10908         Employed      F   64195         Urban       Divorced
#
#        monthly_premium_auto  ...  number_of_open_complaints  \
# 0                        61  ...                    0.38184
# 2                       100  ...                    0.38184
# 3                        97  ...                    0.38184
# 6                        63  ...                    3.00000
# 7                        63  ...                    0.38184
# ...                     ...  ...                        ...
# 10902                    91  ...                    2.00000
# 10903                    74  ...                    4.00000
# 10906                    65  ...                    0.38184
# 10907                   201  ...                    0.38184
# 10908                   158  ...                    4.00000
#
#        number_of_policies     policy_type     policy renew_offer_type  \
# 0                       3  Corporate Auto  Corporate           Offer3
# 2                       2   Personal Auto   Personal           Offer3
# 3                       2  Corporate Auto  Corporate           Offer2
# 6                       3  Corporate Auto  Corporate           Offer2
# 7                       3   Personal Auto   Personal           Offer2
# ...                   ...             ...        ...              ...
# 10902                   1   Personal Auto   Personal           Offer2
# 10903                   1   Personal Auto   Personal           Offer2
# 10906                   3   Personal Auto   Personal           Offer2
# 10907                   2  Corporate Auto  Corporate           Offer1
# 10908                   3   Personal Auto   Personal           Offer1
#
#       sales_channel total_claim_amount  vehicle_class  vehicle_size   region
# 0             Agent              293.0  Four-Door Car       Medsize  central
# 2       Call Center              480.0  Four-Door Car       Medsize     east
# 3            Branch              484.0  Four-Door Car       Medsize    north
# 6            Branch              288.0  Four-Door Car       Medsize     west
# 7            Branch              247.0   Two-Door Car       Medsize     west
# ...             ...                ...            ...           ...      ...
# 10902         Agent              655.0  Four-Door Car       Medsize     west
# 10903        Branch              355.0   Two-Door Car       Medsize  central
# 10906        Branch              273.0  Four-Door Car       Medsize    north
# 10907           Web              381.0     Luxury Car       Medsize  central
# 10908        Branch              618.0  Four-Door Car       Medsize     west
#
# [6817 rows x 22 columns]

# %% [markdown]
# ## Numerical/ Categorical variables

# %%
# numerical columns:
ca_df._get_numeric_data()
# Out:
#        customer_lifetime_value  income  monthly_premium_auto  \
# 0                       4809.0   48029                    61
# 2                      14948.0   22139                   100
# 3                      22332.0   49078                    97
# 6                       5035.0   37405                    63
# 7                       4956.0   87197                    63
# ...                        ...     ...                   ...
# 10902                   3579.0   28304                    91
# 10903                   2772.0   59855                    74
# 10906                   5259.0   61146                    65
# 10907                  23893.0   39837                   201
# 10908                  11972.0   64195                   158
#
#        months_since_last_claim  months_since_policy_inception  \
# 0                          7.0                             52
# 2                         34.0                             31
# 3                         10.0                              3
# 6                          8.0                             99
# 7                         35.0                             45
# ...                        ...                            ...
# 10902                     10.0                             30
# 10903                     30.0                             82
# 10906                      7.0                             68
# 10907                     11.0                             63
# 10908                      0.0                             27
#
#        number_of_open_complaints  number_of_policies  total_claim_amount
# 0                        0.38184                   3               293.0
# 2                        0.38184                   2               480.0
# 3                        0.38184                   2               484.0
# 6                        3.00000                   3               288.0
# 7                        0.38184                   3               247.0
# ...                          ...                 ...                 ...
# 10902                    2.00000                   1               655.0
# 10903                    4.00000                   1               355.0
# 10906                    0.38184                   3               273.0
# 10907                    0.38184                   2               381.0
# 10908                    4.00000                   3               618.0
#
# [6817 rows x 8 columns]

# %%
# categorical columns
ca_df.select_dtypes('object')
# Out:
#             state response  coverage employmentstatus gender location_code  \
# 0         arizona       No     Basic         Employed      M      Suburban
# 2      washington       No     Basic         Employed      M      Suburban
# 3          oregon      Yes  Extended         Employed      M      Suburban
# 6      california       No     Basic         Employed      F         Urban
# 7      california       No     Basic         Employed      M         Urban
# ...           ...      ...       ...              ...    ...           ...
# 10902  california       No  Extended         Employed      F      Suburban
# 10903     arizona       No     Basic         Employed      M      Suburban
# 10906      oregon       No     Basic         Employed      F         Urban
# 10907     arizona       No  Extended         Employed      F         Rural
# 10908  california       No   Premium         Employed      F         Urban
#
#       marital_status     policy_type     policy renew_offer_type  \
# 0            Married  Corporate Auto  Corporate           Offer3
# 2             Single   Personal Auto   Personal           Offer3
# 3             Single  Corporate Auto  Corporate           Offer2
# 6            Married  Corporate Auto  Corporate           Offer2
# 7             Single   Personal Auto   Personal           Offer2
# ...              ...             ...        ...              ...
# 10902        Married   Personal Auto   Personal           Offer2
# 10903        Married   Personal Auto   Personal           Offer2
# 10906        Married   Personal Auto   Personal           Offer2
# 10907        Married  Corporate Auto  Corporate           Offer1
# 10908       Divorced   Personal Auto   Personal           Offer1
#
#       sales_channel  vehicle_class vehicle_size   region
# 0             Agent  Four-Door Car      Medsize  central
# 2       Call Center  Four-Door Car      Medsize     east
# 3            Branch  Four-Door Car      Medsize    north
# 6            Branch  Four-Door Car      Medsize     west
# 7            Branch   Two-Door Car      Medsize     west
# ...             ...            ...          ...      ...
# 10902         Agent  Four-Door Car      Medsize     west
# 10903        Branch   Two-Door Car      Medsize  central
# 10906        Branch  Four-Door Car      Medsize    north
# 10907           Web     Luxury Car      Medsize  central
# 10908        Branch  Four-Door Car      Medsize     west
#
# [6817 rows x 14 columns]

# %% [markdown]
# ## Plots

# %% [markdown]
# In order to understand our data we will make some interesting plots:

# %% [markdown]
# #### Total number of responses:

# %%
# First we need to know the total number of responses


ca_df.response.value_counts()
# Out:
# No     5707
# Yes    1110
# Name: response, dtype: int64

# %%
total_response =ca_df.response.value_counts()

# %%
ca_df['response'].value_counts().plot(kind="bar")
plt.title("total number of responses",{"fontsize":18})
# Out:
# Text(0.5, 1.0, 'total number of responses')

# %% [markdown]
# #### Response rate by the sales channel

# %%
# response rate by the sales channel.
ca_df.sales_channel.value_counts()
# Out:
# Agent          2573
# Branch         1924
# Call Center    1329
# Web             991
# Name: sales_channel, dtype: int64

# %%
# response_rate= answers_recieved/total_answers
#In order to calculate the response rate, I will create a new column called "Yes_response"

response_labels ={
    "Yes":"1",
    "No":"0"
}

# %%
ca_df=ca_df.assign(yes_response=ca_df.response.map(response_labels))

# %%
ca_df
# Out:
#             state  customer_lifetime_value response  coverage  \
# 0         arizona                   4809.0       No     Basic
# 2      washington                  14948.0       No     Basic
# 3          oregon                  22332.0      Yes  Extended
# 6      california                   5035.0       No     Basic
# 7      california                   4956.0       No     Basic
# ...           ...                      ...      ...       ...
# 10902  california                   3579.0       No  Extended
# 10903     arizona                   2772.0       No     Basic
# 10906      oregon                   5259.0       No     Basic
# 10907     arizona                  23893.0       No  Extended
# 10908  california                  11972.0       No   Premium
#
#       employmentstatus gender  income location_code marital_status  \
# 0             Employed      M   48029      Suburban        Married
# 2             Employed      M   22139      Suburban         Single
# 3             Employed      M   49078      Suburban         Single
# 6             Employed      F   37405         Urban        Married
# 7             Employed      M   87197         Urban         Single
# ...                ...    ...     ...           ...            ...
# 10902         Employed      F   28304      Suburban        Married
# 10903         Employed      M   59855      Suburban        Married
# 10906         Employed      F   61146         Urban        Married
# 10907         Employed      F   39837         Rural        Married
# 10908         Employed      F   64195         Urban       Divorced
#
#        monthly_premium_auto  ...  number_of_policies     policy_type  \
# 0                        61  ...                   3  Corporate Auto
# 2                       100  ...                   2   Personal Auto
# 3                        97  ...                   2  Corporate Auto
# 6                        63  ...                   3  Corporate Auto
# 7                        63  ...                   3   Personal Auto
# ...                     ...  ...                 ...             ...
# 10902                    91  ...                   1   Personal Auto
# 10903                    74  ...                   1   Personal Auto
# 10906                    65  ...                   3   Personal Auto
# 10907                   201  ...                   2  Corporate Auto
# 10908                   158  ...                   3   Personal Auto
#
#           policy  renew_offer_type sales_channel total_claim_amount  \
# 0      Corporate            Offer3         Agent              293.0
# 2       Personal            Offer3   Call Center              480.0
# 3      Corporate            Offer2        Branch              484.0
# 6      Corporate            Offer2        Branch              288.0
# 7       Personal            Offer2        Branch              247.0
# ...          ...               ...           ...                ...
# 10902   Personal            Offer2         Agent              655.0
# 10903   Personal            Offer2        Branch              355.0
# 10906   Personal            Offer2        Branch              273.0
# 10907  Corporate            Offer1           Web              381.0
# 10908   Personal            Offer1        Branch              618.0
#
#        vehicle_class vehicle_size   region yes_response
# 0      Four-Door Car      Medsize  central            0
# 2      Four-Door Car      Medsize     east            0
# 3      Four-Door Car      Medsize    north            1
# 6      Four-Door Car      Medsize     west            0
# 7       Two-Door Car      Medsize     west            0
# ...              ...          ...      ...          ...
# 10902  Four-Door Car      Medsize     west            0
# 10903   Two-Door Car      Medsize  central            0
# 10906  Four-Door Car      Medsize    north            0
# 10907     Luxury Car      Medsize  central            0
# 10908  Four-Door Car      Medsize     west            0
#
# [6817 rows x 23 columns]

# %%
#now we calculate the responsate with the following function:

response_rate = ca_df.groupby(['response','sales_channel'])['yes_response'].count().reset_index()

# %%
response_rate
# Out:
#   response sales_channel  yes_response
# 0       No         Agent          2021
# 1       No        Branch          1660
# 2       No   Call Center          1167
# 3       No           Web           859
# 4      Yes         Agent           552
# 5      Yes        Branch           264
# 6      Yes   Call Center           162
# 7      Yes           Web           132

# %%
sns.set_palette("Paired")
fig,ax=plt.subplots(figsize=(6,6))
sns.barplot(x=response_rate["sales_channel"],y=response_rate["yes_response"],hue=response_rate["response"])
ax.set_title("Response rate by channel")
# Out:
# Text(0.5, 1.0, 'Response rate by channel')

# %% [markdown]
# #### Response rate by the total claim amount

# %%
#Show a plot of the response rate by the total claim amount.
#I create buckets in the variable total_claim_amount
pd.cut(ca_df['total_claim_amount'],4)
# Out:
# 0        (-2.893, 723.25]
# 2        (-2.893, 723.25]
# 3        (-2.893, 723.25]
# 6        (-2.893, 723.25]
# 7        (-2.893, 723.25]
#                ...
# 10902    (-2.893, 723.25]
# 10903    (-2.893, 723.25]
# 10906    (-2.893, 723.25]
# 10907    (-2.893, 723.25]
# 10908    (-2.893, 723.25]
# Name: total_claim_amount, Length: 6817, dtype: category
# Categories (4, interval[float64, right]): [(-2.893, 723.25] < (723.25, 1446.5] < (1446.5, 2169.75] < (2169.75, 2893.0]]

# %%
#I create the label for the new column total_claim_amount_binned
total_claim_amount_labels = ['Low', 'Moderate', 'High', 'Very High']
ca_df['total_claim_amount_binned'] = pd.cut(ca_df['total_claim_amount'],4, labels=total_claim_amount_labels)

# %%
response_rate_c=ca_df.groupby(['response',"total_claim_amount_binned"])['yes_response'].count().reset_index()
response_rate_c
# Out:
#   response total_claim_amount_binned  yes_response
# 0       No                       Low          5293
# 1       No                  Moderate           395
# 2       No                      High            15
# 3       No                 Very High             4
# 4      Yes                       Low          1020
# 5      Yes                  Moderate            90
# 6      Yes                      High             0
# 7      Yes                 Very High             0

# %%
sns.set_palette("Paired")
fig,ax=plt.subplots(figsize=(6,6))
sns.barplot(x=response_rate_c["total_claim_amount_binned"],y=response_rate_c["yes_response"],hue=response_rate_c["response"])
ax.set_title("Response rate by the total claim amount")
# Out:
# Text(0.5, 1.0, 'Response rate by the total claim amount')

# %%
#Show a plot of the response rate by income.
#I create buckets for the column income
pd.cut(ca_df['income'],4)
# Out:
# 0         (32523.0, 55009.0]
# 2        (9947.056, 32523.0]
# 3         (32523.0, 55009.0]
# 6         (32523.0, 55009.0]
# 7         (77495.0, 99981.0]
#                 ...
# 10902    (9947.056, 32523.0]
# 10903     (55009.0, 77495.0]
# 10906     (55009.0, 77495.0]
# 10907     (32523.0, 55009.0]
# 10908     (55009.0, 77495.0]
# Name: income, Length: 6817, dtype: category
# Categories (4, interval[float64, right]): [(9947.056, 32523.0] < (32523.0, 55009.0] < (55009.0, 77495.0] < (77495.0, 99981.0]]

# %%
income_labels = ['Low', 'Lower_middel', 'Upper_middle', 'Hight']
ca_df['income_binned'] = pd.cut(ca_df['income'],4, labels=income_labels)

# %%
response_rate_i=ca_df.groupby(['response',"income_binned"])['yes_response'].count().reset_index()
response_rate_i
# Out:
#   response income_binned  yes_response
# 0       No           Low          1666
# 1       No  Lower_middel          1583
# 2       No  Upper_middle          1424
# 3       No         Hight          1034
# 4      Yes           Low           456
# 5      Yes  Lower_middel           222
# 6      Yes  Upper_middle           294
# 7      Yes         Hight           138

# %%
sns.set_palette("Paired")
fig,ax=plt.subplots(figsize=(6,6))
sns.barplot(x=response_rate_i["income_binned"],y=response_rate_i["yes_response"],hue=response_rate_i["response"])
ax.set_title("Response rate by income")
# Out:
# Text(0.5, 1.0, 'Response rate by income')

# %%
# We have to drop the columns created for plotting
ca_df.drop(["yes_response","total_claim_amount_binned","income_binned"],axis=1,inplace=True)

# %%
ca_df
# Out:
#             state  customer_lifetime_value response  coverage  \
# 0         arizona                   4809.0       No     Basic
# 2      washington                  14948.0       No     Basic
# 3          oregon                  22332.0      Yes  Extended
# 6      california                   5035.0       No     Basic
# 7      california                   4956.0       No     Basic
# ...           ...                      ...      ...       ...
# 10902  california                   3579.0       No  Extended
# 10903     arizona                   2772.0       No     Basic
# 10906      oregon                   5259.0       No     Basic
# 10907     arizona                  23893.0       No  Extended
# 10908  california                  11972.0       No   Premium
#
#       employmentstatus gender  income location_code marital_status  \
# 0             Employed      M   48029      Suburban        Married
# 2             Employed      M   22139      Suburban         Single
# 3             Employed      M   49078      Suburban         Single
# 6             Employed      F   37405         Urban        Married
# 7             Employed      M   87197         Urban         Single
# ...                ...    ...     ...           ...            ...
# 10902         Employed      F   28304      Suburban        Married
# 10903         Employed      M   59855      Suburban        Married
# 10906         Employed      F   61146         Urban        Married
# 10907         Employed      F   39837         Rural        Married
# 10908         Employed      F   64195         Urban       Divorced
#
#        monthly_premium_auto  ...  number_of_open_complaints  \
# 0                        61  ...                    0.38184
# 2                       100  ...                    0.38184
# 3                        97  ...                    0.38184
# 6                        63  ...                    3.00000
# 7                        63  ...                    0.38184
# ...                     ...  ...                        ...
# 10902                    91  ...                    2.00000
# 10903                    74  ...                    4.00000
# 10906                    65  ...                    0.38184
# 10907                   201  ...                    0.38184
# 10908                   158  ...                    4.00000
#
#        number_of_policies     policy_type     policy renew_offer_type  \
# 0                       3  Corporate Auto  Corporate           Offer3
# 2                       2   Personal Auto   Personal           Offer3
# 3                       2  Corporate Auto  Corporate           Offer2
# 6                       3  Corporate Auto  Corporate           Offer2
# 7                       3   Personal Auto   Personal           Offer2
# ...                   ...             ...        ...              ...
# 10902                   1   Personal Auto   Personal           Offer2
# 10903                   1   Personal Auto   Personal           Offer2
# 10906                   3   Personal Auto   Personal           Offer2
# 10907                   2  Corporate Auto  Corporate           Offer1
# 10908                   3   Personal Auto   Personal           Offer1
#
#       sales_channel total_claim_amount  vehicle_class  vehicle_size   region
# 0             Agent              293.0  Four-Door Car       Medsize  central
# 2       Call Center              480.0  Four-Door Car       Medsize     east
# 3            Branch              484.0  Four-Door Car       Medsize    north
# 6            Branch              288.0  Four-Door Car       Medsize     west
# 7            Branch              247.0   Two-Door Car       Medsize     west
# ...             ...                ...            ...           ...      ...
# 10902         Agent              655.0  Four-Door Car       Medsize     west
# 10903        Branch              355.0   Two-Door Car       Medsize  central
# 10906        Branch              273.0  Four-Door Car       Medsize    north
# 10907           Web              381.0     Luxury Car       Medsize  central
# 10908        Branch              618.0  Four-Door Car       Medsize     west
#
# [6817 rows x 22 columns]

# %% [markdown]
# # Correlation analysis

# %%
#I want to see the relation between the variables.
#We use the function pairplot from sns to do that

#sns.pairplot(ca_df)

# %%
# Plot the Correlation Heatmap
#before, we can check the correlation

ca_df.corr()
# Out:
#                                customer_lifetime_value    income  \
# customer_lifetime_value                       1.000000  0.002916
# income                                        0.002916  1.000000
# monthly_premium_auto                          0.399491 -0.012372
# months_since_last_claim                       0.018531 -0.034453
# months_since_policy_inception                 0.011275  0.015799
# number_of_open_complaints                    -0.027501  0.017875
# number_of_policies                            0.202484  0.009224
# total_claim_amount                            0.245436 -0.221917
#
#                                monthly_premium_auto  months_since_last_claim  \
# customer_lifetime_value                    0.399491                 0.018531
# income                                    -0.012372                -0.034453
# monthly_premium_auto                       1.000000                 0.005887
# months_since_last_claim                    0.005887                 1.000000
# months_since_policy_inception              0.020112                -0.039993
# number_of_open_complaints                 -0.008569                 0.007361
# number_of_policies                        -0.039533                 0.018479
# total_claim_amount                         0.636072                 0.001461
#
#                                months_since_policy_inception  \
# customer_lifetime_value                             0.011275
# income                                              0.015799
# monthly_premium_auto                                0.020112
# months_since_last_claim                            -0.039993
# months_since_policy_inception                       1.000000
# number_of_open_complaints                           0.008887
# number_of_policies                                 -0.007764
# total_claim_amount                                 -0.003765
#
#                                number_of_open_complaints  number_of_policies  \
# customer_lifetime_value                        -0.027501            0.202484
# income                                          0.017875            0.009224
# monthly_premium_auto                           -0.008569           -0.039533
# months_since_last_claim                         0.007361            0.018479
# months_since_policy_inception                   0.008887           -0.007764
# number_of_open_complaints                       1.000000            0.012514
# number_of_policies                              0.012514            1.000000
# total_claim_amount                             -0.010667           -0.031187
#
#                                total_claim_amount
# customer_lifetime_value                  0.245436
# income                                  -0.221917
# monthly_premium_auto                     0.636072
# months_since_last_claim                  0.001461
# months_since_policy_inception           -0.003765
# number_of_open_complaints               -0.010667
# number_of_policies                      -0.031187
# total_claim_amount                       1.000000

# %%
sns.heatmap(ca_df.corr(),cmap="mako")
# Out:
# <AxesSubplot:>

# %%
# we use the correlation matrix to check the multicollinearity

corr = ca_df.corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(9, 7))
    ax = sns.heatmap(corr, mask=mask,cmap="mako", vmin=-1,vmax=1,annot=True, square=True)

# %% [markdown]
# There are not high correlation between the variables, we do not drop any variable

# %%
ca_df.corr().to_csv("correllation.csv")

# %% [markdown]
# ## Removing outliers from numerical variables
# We will use box plot to identify them and remove them

# %%
# formula to get numeric variables from our data set
X=ca_df._get_numeric_data()

# %%
#In oder to check the outliers we need the boxplot of the numerical columns:
X.boxplot(figsize=(6,6))
# Out:
# <AxesSubplot:>

# %%
# We can see the "customer_lifetime_value" has many outliers. 
# 1. We need to identify the percentile 25 and the percentile 75
# irq: interquartile range

percentile25 = X['customer_lifetime_value'].quantile(0.25)
percentile75 = X['customer_lifetime_value'].quantile(0.75)
iqr = percentile75 - percentile25

# %%
# 2 Finding upper and lower limit

upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr

# %%
# 3 Finding Outliers
X[X['customer_lifetime_value'] > upper_limit]

X[X['customer_lifetime_value'] < lower_limit]
# Out:
# Empty DataFrame
# Columns: [customer_lifetime_value, income, monthly_premium_auto, months_since_last_claim, months_since_policy_inception, number_of_open_complaints, number_of_policies, total_claim_amount]
# Index: []

# %%
# 4 Trimming
new_X = X[X['customer_lifetime_value'] < upper_limit]
new_X.shape
# Out:
# (6221, 8)

# %%
# 5 Capping

new_X_cap = X.copy()
new_X_cap['customer_lifetime_value'] = np.where(
    new_X_cap['customer_lifetime_value'] > upper_limit,
    upper_limit,
    np.where(
        new_X_cap['customer_lifetime_value'] < lower_limit,
        lower_limit,
        new_X_cap['customer_lifetime_value']
    )
)

# %%
# 7 Compare the plots after capping 
plt.figure(figsize=(8,8))

plt.subplot(2,2,1)
sns.boxplot(X['customer_lifetime_value'])

plt.subplot(2,2,2)
sns.boxplot(new_X_cap['customer_lifetime_value'])

plt.show()
# Out:
# C:\Users\merce\anaconda3\envs\Da_Env1\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\merce\anaconda3\envs\Da_Env1\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
#  We also have to remove the outliers from **"montly_premium_ auto"**

# %%
# 1 We need to identify the percentile 25 and the percentile 75
# irq: interquartile range

percentile25 = X['monthly_premium_auto'].quantile(0.25)
percentile75 = X['monthly_premium_auto'].quantile(0.75)
iqr = percentile75 - percentile25

# %%
# 2 Finding upper and lower limit

upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr

# %%
# 3 Finding Outliers
X[X['monthly_premium_auto'] > upper_limit]

X[X['monthly_premium_auto'] < lower_limit]
# Out:
# Empty DataFrame
# Columns: [customer_lifetime_value, income, monthly_premium_auto, months_since_last_claim, months_since_policy_inception, number_of_open_complaints, number_of_policies, total_claim_amount]
# Index: []

# %%
# 4 Trimming
new_X = X[X['monthly_premium_auto'] < upper_limit]
new_X.shape
# Out:
# (6491, 8)

# %%
# 5 Capping

new_X_cap = X.copy()
new_X_cap['monthly_premium_auto'] = np.where(
    new_X_cap['monthly_premium_auto'] > upper_limit,
    upper_limit,
    np.where(
        new_X_cap['monthly_premium_auto'] < lower_limit,
        lower_limit,
        new_X_cap['monthly_premium_auto']
    )
)

# %%
# 7 Compare the plots after capping 
plt.figure(figsize=(8,8))

plt.subplot(2,2,1)
sns.boxplot(X['monthly_premium_auto'])

plt.subplot(2,2,2)
sns.boxplot(new_X_cap['monthly_premium_auto'])

plt.show()
# Out:
# C:\Users\merce\anaconda3\envs\Da_Env1\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\merce\anaconda3\envs\Da_Env1\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
#  We also have to remove the outliers from **"total_claim_amount"**

# %%
# 1 We need to identify the percentile 25 and the percentile 75
# irq: interquartile range

percentile25 = X['total_claim_amount'].quantile(0.25)
percentile75 = X['total_claim_amount'].quantile(0.75)
iqr = percentile75 - percentile25

# %%
# 2 Finding upper and lower limit

upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr

# %%
# 3 Finding Outliers
X[X['total_claim_amount'] > upper_limit]

X[X['total_claim_amount'] < lower_limit]
# Out:
# Empty DataFrame
# Columns: [customer_lifetime_value, income, monthly_premium_auto, months_since_last_claim, months_since_policy_inception, number_of_open_complaints, number_of_policies, total_claim_amount]
# Index: []

# %%
# 4 Trimming
new_X = X[X['total_claim_amount'] < upper_limit]
new_X.shape
# Out:
# (6592, 8)

# %%
# 5 Capping

new_X_cap = X.copy()
new_X_cap['total_claim_amount'] = np.where(
    new_X_cap['total_claim_amount'] > upper_limit,
    upper_limit,
    np.where(
        new_X_cap['total_claim_amount'] < lower_limit,
        lower_limit,
        new_X_cap['total_claim_amount']
    )
)

# %%
# 6 Compare the plots after capping 
plt.figure(figsize=(8,8))

plt.subplot(2,2,1)
sns.boxplot(X['total_claim_amount'])

plt.subplot(2,2,2)
sns.boxplot(new_X_cap['total_claim_amount'])

plt.show()
# Out:
# C:\Users\merce\anaconda3\envs\Da_Env1\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\merce\anaconda3\envs\Da_Env1\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# now we filter the variables **"customer_lifetime_value","monthly_premium_amount" and "total_claim_amount"**
# so we can remove the outliers

# %%
# filter values of the variable "montly_premium_auto"

ca_df=ca_df[ca_df["monthly_premium_auto"]<160]

# %%
# filter values of the variable "customer_lifetime_value"

ca_df=ca_df[ca_df["customer_lifetime_value"]<16000]

# %%
# filter values of the variable "total_claim_amount"

ca_df=ca_df[ca_df["total_claim_amount"]<900]

# %% [markdown]
# ## Normality of the numerical variables

# %%
# We get the numerical variables from X

X=ca_df._get_numeric_data()

# %%
# We check the histograms of the numberical variables.
X.hist(figsize=(10,10))
# Out:
# array([[<AxesSubplot:title={'center':'customer_lifetime_value'}>,
#         <AxesSubplot:title={'center':'income'}>,
#         <AxesSubplot:title={'center':'monthly_premium_auto'}>],
#        [<AxesSubplot:title={'center':'months_since_last_claim'}>,
#         <AxesSubplot:title={'center':'months_since_policy_inception'}>,
#         <AxesSubplot:title={'center':'number_of_open_complaints'}>],
#        [<AxesSubplot:title={'center':'number_of_policies'}>,
#         <AxesSubplot:title={'center':'total_claim_amount'}>,
#         <AxesSubplot:>]], dtype=object)

# %%
# We use Power Transformation to transform all variables into normal distribution

sns.distplot((ca_df['customer_lifetime_value']), bins=20)
# Out:
# C:\Users\merce\anaconda3\envs\Da_Env1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='customer_lifetime_value', ylabel='Density'>

# %%
pt = PowerTransformer(method="box-cox")
med_customer_lifetime_value_trans=pt.fit_transform(ca_df['customer_lifetime_value'].to_numpy().reshape(-1,1))
sns.displot(med_customer_lifetime_value_trans)

# %%
sns.distplot((ca_df['monthly_premium_auto']), bins=20)
# Out:
# C:\Users\merce\anaconda3\envs\Da_Env1\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='monthly_premium_auto', ylabel='Density'>

# %%
pt = PowerTransformer(method="box-cox")
med_monthly_premium_auto_trans=pt.fit_transform(ca_df['monthly_premium_auto'].to_numpy().reshape(-1,1))
sns.displot(med_monthly_premium_auto_trans)

# %%
# We need to introduce the transform variables in the model

ca_df["med_customer_lifetime_value_trans"]= med_customer_lifetime_value_trans
ca_df["med_monthly_premium_auto_trans"]= med_monthly_premium_auto_trans

# %%
# We need to delete the old column

ca_df.drop(["customer_lifetime_value"],axis=1,inplace=True)
ca_df.drop(["monthly_premium_auto"],axis=1,inplace=True)

# %%
ca_df
# Out:
#             state response  coverage employmentstatus gender  income  \
# 0         arizona       No     Basic         Employed      M   48029
# 2      washington       No     Basic         Employed      M   22139
# 6      california       No     Basic         Employed      F   37405
# 7      california       No     Basic         Employed      M   87197
# 8      california      Yes   Premium         Employed      M   66839
# ...           ...      ...       ...              ...    ...     ...
# 10901  washington       No   Premium         Employed      M   33531
# 10902  california       No  Extended         Employed      F   28304
# 10903     arizona       No     Basic         Employed      M   59855
# 10906      oregon       No     Basic         Employed      F   61146
# 10908  california       No   Premium         Employed      F   64195
#
#       location_code marital_status  months_since_last_claim  \
# 0          Suburban        Married                      7.0
# 2          Suburban         Single                     34.0
# 6             Urban        Married                      8.0
# 7             Urban         Single                     35.0
# 8          Suburban         Single                     33.0
# ...             ...            ...                      ...
# 10901      Suburban        Married                     11.0
# 10902      Suburban        Married                     10.0
# 10903      Suburban        Married                     30.0
# 10906         Urban        Married                      7.0
# 10908         Urban       Divorced                      0.0
#
#        months_since_policy_inception  ...     policy_type     policy  \
# 0                                 52  ...  Corporate Auto  Corporate
# 2                                 31  ...   Personal Auto   Personal
# 6                                 99  ...  Corporate Auto  Corporate
# 7                                 45  ...   Personal Auto   Personal
# 8                                 24  ...   Personal Auto   Personal
# ...                              ...  ...             ...        ...
# 10901                             15  ...   Personal Auto   Personal
# 10902                             30  ...   Personal Auto   Personal
# 10903                             82  ...   Personal Auto   Personal
# 10906                             68  ...   Personal Auto   Personal
# 10908                             27  ...   Personal Auto   Personal
#
#       renew_offer_type sales_channel total_claim_amount  vehicle_class  \
# 0               Offer3         Agent              293.0  Four-Door Car
# 2               Offer3   Call Center              480.0  Four-Door Car
# 6               Offer2        Branch              288.0  Four-Door Car
# 7               Offer2        Branch              247.0   Two-Door Car
# 8               Offer2        Branch              739.0     Sports Car
# ...                ...           ...                ...            ...
# 10901           Offer4         Agent              802.0   Two-Door Car
# 10902           Offer2         Agent              655.0  Four-Door Car
# 10903           Offer2        Branch              355.0   Two-Door Car
# 10906           Offer2        Branch              273.0  Four-Door Car
# 10908           Offer1        Branch              618.0  Four-Door Car
#
#        vehicle_size   region med_customer_lifetime_value_trans  \
# 0           Medsize  central                         -0.245640
# 2           Medsize     east                          2.014000
# 6           Medsize     west                         -0.152508
# 7           Medsize     west                         -0.184564
# 8           Medsize     west                          0.198444
# ...             ...      ...                               ...
# 10901       Medsize     east                         -0.358990
# 10902       Medsize     west                         -0.848042
# 10903       Medsize  central                         -1.373785
# 10906       Medsize    north                         -0.064366
# 10908       Medsize     west                          1.578195
#
#       med_monthly_premium_auto_trans
# 0                          -1.511582
# 2                           0.854797
# 6                          -1.305648
# 7                          -1.305648
# 8                           1.970959
# ...                              ...
# 10901                       1.311997
# 10902                       0.514050
# 10903                      -0.399868
# 10906                      -1.114353
# 10908                       2.019295
#
# [5895 rows x 22 columns]

# %% [markdown]
# ## Predictive Modeling

# %% [markdown]
# ### XY split

# %%
# "total_claim_amount" is our dependent variable. 
# We have to separate our target variable from the others

X=ca_df.drop('total_claim_amount', axis=1)

Y=ca_df.total_claim_amount

# %%
X =X._get_numeric_data()

# %%
type(Y)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### Scaling

# %%
#normalize numeric features / rescaling using Normalizer

X_scaled=StandardScaler().fit_transform(X)

# %%
X_scaled.shape
# Out:
# (5895, 7)

# %%
#variables from X data set are now normalized. 
X_scaled
# Out:
# array([[-0.11048495, -0.79134212,  0.15182729, ...,  1.06726724,
#         -0.24564012, -1.51158192],
#        [-1.17102029,  1.90176589, -0.60110544, ..., -0.04215621,
#          2.01400047,  0.85479654],
#        [-0.5456772 , -0.69159738,  1.83696245, ...,  1.06726724,
#         -0.15250842, -1.30564826],
#        ...,
#        [ 0.37394499,  1.50278692,  1.22744548, ..., -1.15157966,
#         -1.37378458, -0.39986823],
#        [ 0.42682838, -0.79134212,  0.72549032, ...,  1.06726724,
#         -0.064366  , -1.11435298],
#        [ 0.55172496, -1.48955531, -0.74452119, ...,  1.06726724,
#          1.57819507,  2.01929518]])

# %%
# we get our train and test data set
X_train, X_test, y_train, y_test=train_test_split(X_scaled, Y, test_size=0.20, random_state=1000)

# %% [markdown]
# ### Hot coding Categorical Variables

# %%
categorical_df=ca_df.select_dtypes('object')

# %%
categorical_df
# Out:
#             state response  coverage employmentstatus gender location_code  \
# 0         arizona       No     Basic         Employed      M      Suburban
# 2      washington       No     Basic         Employed      M      Suburban
# 6      california       No     Basic         Employed      F         Urban
# 7      california       No     Basic         Employed      M         Urban
# 8      california      Yes   Premium         Employed      M      Suburban
# ...           ...      ...       ...              ...    ...           ...
# 10901  washington       No   Premium         Employed      M      Suburban
# 10902  california       No  Extended         Employed      F      Suburban
# 10903     arizona       No     Basic         Employed      M      Suburban
# 10906      oregon       No     Basic         Employed      F         Urban
# 10908  california       No   Premium         Employed      F         Urban
#
#       marital_status     policy_type     policy renew_offer_type  \
# 0            Married  Corporate Auto  Corporate           Offer3
# 2             Single   Personal Auto   Personal           Offer3
# 6            Married  Corporate Auto  Corporate           Offer2
# 7             Single   Personal Auto   Personal           Offer2
# 8             Single   Personal Auto   Personal           Offer2
# ...              ...             ...        ...              ...
# 10901        Married   Personal Auto   Personal           Offer4
# 10902        Married   Personal Auto   Personal           Offer2
# 10903        Married   Personal Auto   Personal           Offer2
# 10906        Married   Personal Auto   Personal           Offer2
# 10908       Divorced   Personal Auto   Personal           Offer1
#
#       sales_channel  vehicle_class vehicle_size   region
# 0             Agent  Four-Door Car      Medsize  central
# 2       Call Center  Four-Door Car      Medsize     east
# 6            Branch  Four-Door Car      Medsize     west
# 7            Branch   Two-Door Car      Medsize     west
# 8            Branch     Sports Car      Medsize     west
# ...             ...            ...          ...      ...
# 10901         Agent   Two-Door Car      Medsize     east
# 10902         Agent  Four-Door Car      Medsize     west
# 10903        Branch   Two-Door Car      Medsize  central
# 10906        Branch  Four-Door Car      Medsize    north
# 10908        Branch  Four-Door Car      Medsize     west
#
# [5895 rows x 14 columns]

# %%
# get dummies pandas
##pd.DataFrame(OneHotEncoder(drop='first').fit_transform(categoricals_features).toarray(),
## columns=OneHotEncoder(drop='first').fit(categoricals_features).get_feature_names(input_features=categoricals_features.columns)).head()

categorical_df=pd.get_dummies(categorical_df, drop_first=True)

# %%
categorical_df
# Out:
#        state_california  state_nevada  state_oregon  state_washington  \
# 0                     0             0             0                 0
# 2                     0             0             0                 1
# 6                     1             0             0                 0
# 7                     1             0             0                 0
# 8                     1             0             0                 0
# ...                 ...           ...           ...               ...
# 10901                 0             0             0                 1
# 10902                 1             0             0                 0
# 10903                 0             0             0                 0
# 10906                 0             0             1                 0
# 10908                 1             0             0                 0
#
#        response_Yes  coverage_Extended  coverage_Premium  \
# 0                 0                  0                 0
# 2                 0                  0                 0
# 6                 0                  0                 0
# 7                 0                  0                 0
# 8                 1                  0                 1
# ...             ...                ...               ...
# 10901             0                  0                 1
# 10902             0                  1                 0
# 10903             0                  0                 0
# 10906             0                  0                 0
# 10908             0                  0                 1
#
#        employmentstatus_Employed  employmentstatus_Medical Leave  \
# 0                              1                               0
# 2                              1                               0
# 6                              1                               0
# 7                              1                               0
# 8                              1                               0
# ...                          ...                             ...
# 10901                          1                               0
# 10902                          1                               0
# 10903                          1                               0
# 10906                          1                               0
# 10908                          1                               0
#
#        employmentstatus_Retired  ...  sales_channel_Branch  \
# 0                             0  ...                     0
# 2                             0  ...                     0
# 6                             0  ...                     1
# 7                             0  ...                     1
# 8                             0  ...                     1
# ...                         ...  ...                   ...
# 10901                         0  ...                     0
# 10902                         0  ...                     0
# 10903                         0  ...                     1
# 10906                         0  ...                     1
# 10908                         0  ...                     1
#
#        sales_channel_Call Center  sales_channel_Web  vehicle_class_Sports Car  \
# 0                              0                  0                         0
# 2                              1                  0                         0
# 6                              0                  0                         0
# 7                              0                  0                         0
# 8                              0                  0                         1
# ...                          ...                ...                       ...
# 10901                          0                  0                         0
# 10902                          0                  0                         0
# 10903                          0                  0                         0
# 10906                          0                  0                         0
# 10908                          0                  0                         0
#
#        vehicle_class_Two-Door Car  vehicle_size_Medsize  vehicle_size_Small  \
# 0                               0                     1                   0
# 2                               0                     1                   0
# 6                               0                     1                   0
# 7                               1                     1                   0
# 8                               0                     1                   0
# ...                           ...                   ...                 ...
# 10901                           1                     1                   0
# 10902                           0                     1                   0
# 10903                           1                     1                   0
# 10906                           0                     1                   0
# 10908                           0                     1                   0
#
#        region_east  region_north  region_west
# 0                0             0            0
# 2                1             0            0
# 6                0             0            1
# 7                0             0            1
# 8                0             0            1
# ...            ...           ...          ...
# 10901            1             0            0
# 10902            0             0            1
# 10903            0             0            0
# 10906            0             1            0
# 10908            0             0            1
#
# [5895 rows x 32 columns]

# %% [markdown]
# ### Applying linear regresion using Statsmodels

# %%
# We need to concat the numberical (X) and the catogorical variables:

X=pd.concat([X, categorical_df], axis=1) # concat numerical and categorical transformations

# %% [markdown]
# #### Without Scaler

# %%
X_train, X_test, y_train, y_test=train_test_split(X, Y, test_size=0.20, random_state=1000)

# %%
X_train_constant= sm.add_constant(X_train)
X_test_constant= sm.add_constant(X_test)  #adding a constant
model=sm.OLS(y_train,X_train_constant).fit()
predictions=model.predict(X_test_constant)

print_model=model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     total_claim_amount   R-squared:                       0.810
# Model:                            OLS   Adj. R-squared:                  0.809
# Method:                 Least Squares   F-statistic:                     587.2
# Date:                Thu, 20 Jan 2022   Prob (F-statistic):               0.00
# Time:                        10:51:47   Log-Likelihood:                -27426.
# No. Observations:                4716   AIC:                         5.492e+04
# Df Residuals:                    4681   BIC:                         5.515e+04
# Df Model:                          34
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# const                               125.3608      9.749     12.859      0.000     106.249     144.472
# income                               -0.0002   6.03e-05     -3.095      0.002      -0.000   -6.85e-05
# months_since_last_claim              -0.0502      0.119     -0.422      0.673      -0.283       0.183
# months_since_policy_inception        -0.0620      0.043     -1.435      0.151      -0.147       0.023
# number_of_open_complaints            -0.8266      1.477     -0.560      0.576      -3.722       2.069
# number_of_policies                   -6.2553      1.829     -3.419      0.001      -9.842      -2.669
# med_customer_lifetime_value_trans     6.4038      1.838      3.484      0.000       2.800      10.007
# med_monthly_premium_auto_trans       80.0556      1.815     44.114      0.000      76.498      83.613
# state_california                      1.0718      1.717      0.624      0.532      -2.294       4.437
# state_nevada                         -0.1372      4.707     -0.029      0.977      -9.366       9.091
# state_oregon                          0.5900      1.780      0.331      0.740      -2.899       4.079
# state_washington                      3.8767      2.431      1.595      0.111      -0.889       8.643
# response_Yes                         -4.6657      3.585     -1.301      0.193     -11.695       2.363
# coverage_Extended                   -13.5872      3.160     -4.300      0.000     -19.783      -7.392
# coverage_Premium                      0.9096      5.360      0.170      0.865      -9.598      11.418
# employmentstatus_Employed             0.5911      5.629      0.105      0.916     -10.444      11.626
# employmentstatus_Medical Leave        3.0439      6.816      0.447      0.655     -10.319      16.407
# employmentstatus_Retired             11.0865      7.915      1.401      0.161      -4.430      26.603
# gender_M                              1.8174      2.407      0.755      0.450      -2.901       6.536
# location_code_Suburban              347.0665      3.149    110.229      0.000     340.894     353.239
# location_code_Urban                 205.9420      3.499     58.861      0.000     199.083     212.801
# marital_status_Married                1.9513      3.330      0.586      0.558      -4.578       8.480
# marital_status_Single                 7.2271      4.182      1.728      0.084      -0.971      15.425
# policy_type_Personal Auto             0.7169      1.458      0.492      0.623      -2.142       3.576
# policy_type_Special Auto              0.7641      3.195      0.239      0.811      -5.500       7.028
# policy_Personal                       0.7169      1.458      0.492      0.623      -2.142       3.576
# policy_Special                        0.7641      3.195      0.239      0.811      -5.500       7.028
# renew_offer_type_Offer2               5.8791      3.034      1.938      0.053      -0.070      11.828
# renew_offer_type_Offer3               1.4643      3.691      0.397      0.692      -5.772       8.700
# renew_offer_type_Offer4               3.1170      4.097      0.761      0.447      -4.915      11.149
# sales_channel_Branch                  3.7072      2.982      1.243      0.214      -2.139       9.553
# sales_channel_Call Center             0.5924      3.372      0.176      0.861      -6.019       7.204
# sales_channel_Web                     0.3214      3.719      0.086      0.931      -6.970       7.613
# vehicle_class_Sports Car             -3.4541      6.090     -0.567      0.571     -15.394       8.485
# vehicle_class_Two-Door Car           -2.0818      2.967     -0.702      0.483      -7.899       3.735
# vehicle_size_Medsize                  5.5515      3.986      1.393      0.164      -2.262      13.365
# vehicle_size_Small                    9.7241      4.668      2.083      0.037       0.572      18.877
# region_east                           3.8767      2.431      1.595      0.111      -0.889       8.643
# region_north                          0.5900      1.780      0.331      0.740      -2.899       4.079
# region_west                           1.0718      1.717      0.624      0.532      -2.294       4.437
# ==============================================================================
# Omnibus:                      833.205   Durbin-Watson:                   1.940
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1781.933
# Skew:                           1.034   Prob(JB):                         0.00
# Kurtosis:                       5.189   Cond. No.                     1.11e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.2e-19. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# C:\Users\merce\anaconda3\envs\Da_Env1\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %% [markdown]
# #### With Scaler

# %%
std_scaler=StandardScaler().fit(X_train)

X_train_scaled=std_scaler.transform(X_train)
X_test_scaled=std_scaler.transform(X_test)

# %%
X_train_scaled_constant= sm.add_constant(X_train_scaled)
X_test_scaled_constant= sm.add_constant(X_test_scaled)  #adding a constant

model=sm.OLS(y_train,X_train_scaled_constant).fit()
predictions=model.predict(X_test_scaled_constant)

print_model=model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     total_claim_amount   R-squared:                       0.810
# Model:                            OLS   Adj. R-squared:                  0.809
# Method:                 Least Squares   F-statistic:                     587.2
# Date:                Thu, 20 Jan 2022   Prob (F-statistic):               0.00
# Time:                        10:51:48   Log-Likelihood:                -27426.
# No. Observations:                4716   AIC:                         5.492e+04
# Df Residuals:                    4681   BIC:                         5.515e+04
# Df Model:                          34
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        341.0948      1.186    287.512      0.000     338.769     343.421
# x1            -4.5502      1.470     -3.095      0.002      -7.433      -1.668
# x2            -0.5041      1.193     -0.422      0.673      -2.844       1.836
# x3            -1.7257      1.202     -1.435      0.151      -4.083       0.631
# x4            -0.6686      1.195     -0.560      0.576      -3.011       1.673
# x5            -5.6346      1.648     -3.419      0.001      -8.865      -2.404
# x6             6.3929      1.835      3.484      0.000       2.796       9.990
# x7            80.0163      1.814     44.114      0.000      76.460      83.572
# x8             0.5093      0.816      0.624      0.532      -1.090       2.108
# x9            -0.0408      1.399     -0.029      0.977      -2.784       2.703
# x10            0.2662      0.803      0.331      0.740      -1.308       1.841
# x11            1.1018      0.691      1.595      0.111      -0.253       2.456
# x12           -1.7245      1.325     -1.301      0.193      -4.323       0.873
# x13           -6.1497      1.430     -4.300      0.000      -8.954      -3.346
# x14            0.2369      1.396      0.170      0.865      -2.499       2.973
# x15            0.2192      2.087      0.105      0.916      -3.872       4.311
# x16            0.7521      1.684      0.447      0.655      -2.550       4.054
# x17            2.2181      1.584      1.401      0.161      -0.886       5.323
# x18            0.9085      1.203      0.755      0.450      -1.450       3.267
# x19          173.0975      1.570    110.229      0.000     170.019     176.176
# x20           85.2658      1.449     58.861      0.000      82.426      88.106
# x21            0.9169      1.565      0.586      0.558      -2.151       3.985
# x22            2.6614      1.540      1.728      0.084      -0.358       5.680
# x23            0.3128      0.636      0.492      0.623      -0.934       1.560
# x24            0.1525      0.638      0.239      0.811      -1.098       1.403
# x25            0.3128      0.636      0.492      0.623      -0.934       1.560
# x26            0.1525      0.638      0.239      0.811      -1.098       1.403
# x27            2.8176      1.454      1.938      0.053      -0.033       5.669
# x28            0.5372      1.354      0.397      0.692      -2.118       3.192
# x29            1.0357      1.361      0.761      0.447      -1.633       3.705
# x30            1.6689      1.342      1.243      0.214      -0.963       4.301
# x31            0.2348      1.337      0.176      0.861      -2.386       2.856
# x32            0.1138      1.317      0.086      0.931      -2.468       2.695
# x33           -0.7268      1.282     -0.567      0.571      -3.239       1.786
# x34           -0.8672      1.236     -0.702      0.483      -3.291       1.556
# x35            2.5273      1.814      1.393      0.164      -1.030       6.085
# x36            3.8228      1.835      2.083      0.037       0.225       7.421
# x37            1.1018      0.691      1.595      0.111      -0.253       2.456
# x38            0.2662      0.803      0.331      0.740      -1.308       1.841
# x39            0.5093      0.816      0.624      0.532      -1.090       2.108
# ==============================================================================
# Omnibus:                      833.205   Durbin-Watson:                   1.940
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1781.933
# Skew:                           1.034   Prob(JB):                         0.00
# Kurtosis:                       5.189   Cond. No.                     1.30e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 8.11e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
model.params.iloc[1:]
# Out:
# x1      -4.550217
# x2      -0.504072
# x3      -1.725658
# x4      -0.668603
# x5      -5.634611
# x6       6.392863
# x7      80.016276
# x8       0.509253
# x9      -0.040792
# x10      0.266219
# x11      1.101813
# x12     -1.724522
# x13     -6.149732
# x14      0.236864
# x15      0.219170
# x16      0.752055
# x17      2.218077
# x18      0.908465
# x19    173.097504
# x20     85.265814
# x21      0.916879
# x22      2.661423
# x23      0.312762
# x24      0.152506
# x25      0.312762
# x26      0.152506
# x27      2.817645
# x28      0.537235
# x29      1.035712
# x30      1.668933
# x31      0.234835
# x32      0.113795
# x33     -0.726840
# x34     -0.867241
# x35      2.527335
# x36      3.822850
# x37      1.101813
# x38      0.266219
# x39      0.509253
# dtype: float64

# %%
features_importances = pd.DataFrame(data={
    'Attribute': X_train.columns,
    'Importance': model.params.iloc[1:]
})
features_importances = features_importances.sort_values(by='Importance', ascending=False)

# %%
features_importances
# Out:
#                              Attribute  Importance
# x19             location_code_Suburban  173.097504
# x20                location_code_Urban   85.265814
# x7      med_monthly_premium_auto_trans   80.016276
# x6   med_customer_lifetime_value_trans    6.392863
# x36                 vehicle_size_Small    3.822850
# x27            renew_offer_type_Offer2    2.817645
# x22              marital_status_Single    2.661423
# x35               vehicle_size_Medsize    2.527335
# x17           employmentstatus_Retired    2.218077
# x30               sales_channel_Branch    1.668933
# x11                   state_washington    1.101813
# x37                        region_east    1.101813
# x29            renew_offer_type_Offer4    1.035712
# x21             marital_status_Married    0.916879
# x18                           gender_M    0.908465
# x16     employmentstatus_Medical Leave    0.752055
# x28            renew_offer_type_Offer3    0.537235
# x39                        region_west    0.509253
# x8                    state_california    0.509253
# x25                    policy_Personal    0.312762
# x23          policy_type_Personal Auto    0.312762
# x38                       region_north    0.266219
# x10                       state_oregon    0.266219
# x14                   coverage_Premium    0.236864
# x31          sales_channel_Call Center    0.234835
# x15          employmentstatus_Employed    0.219170
# x26                     policy_Special    0.152506
# x24           policy_type_Special Auto    0.152506
# x32                  sales_channel_Web    0.113795
# x9                        state_nevada   -0.040792
# x2             months_since_last_claim   -0.504072
# x4           number_of_open_complaints   -0.668603
# x33           vehicle_class_Sports Car   -0.726840
# x34         vehicle_class_Two-Door Car   -0.867241
# x12                       response_Yes   -1.724522
# x3       months_since_policy_inception   -1.725658
# x1                              income   -4.550217
# x5                  number_of_policies   -5.634611
# x13                  coverage_Extended   -6.149732

# %%
model.params[list(np.where(model.pvalues<0.05)[0])].iloc[1:].index.tolist()
# Out:
# ['x1', 'x5', 'x6', 'x7', 'x13', 'x19', 'x20', 'x36']

# %%
list(X.columns)
# Out:
# ['income',
#  'months_since_last_claim',
#  'months_since_policy_inception',
#  'number_of_open_complaints',
#  'number_of_policies',
#  'med_customer_lifetime_value_trans',
#  'med_monthly_premium_auto_trans',
#  'state_california',
#  'state_nevada',
#  'state_oregon',
#  'state_washington',
#  'response_Yes',
#  'coverage_Extended',
#  'coverage_Premium',
#  'employmentstatus_Employed',
#  'employmentstatus_Medical Leave',
#  'employmentstatus_Retired',
#  'gender_M',
#  'location_code_Suburban',
#  'location_code_Urban',
#  'marital_status_Married',
#  'marital_status_Single',
#  'policy_type_Personal Auto',
#  'policy_type_Special Auto',
#  'policy_Personal',
#  'policy_Special',
#  'renew_offer_type_Offer2',
#  'renew_offer_type_Offer3',
#  'renew_offer_type_Offer4',
#  'sales_channel_Branch',
#  'sales_channel_Call Center',
#  'sales_channel_Web',
#  'vehicle_class_Sports Car',
#  'vehicle_class_Two-Door Car',
#  'vehicle_size_Medsize',
#  'vehicle_size_Small',
#  'region_east',
#  'region_north',
#  'region_west']

# %%
X= X[[
 'income',
 'months_since_policy_inception',
 "number_of_policies",
 "med_customer_lifetime_value_trans",
 "med_monthly_premium_auto_trans",
 "state_washington",
 "coverage_Extended",
 "location_code_Suburban",
 "location_code_Urban",
 "vehicle_size_Small",
 'region_east']]

# %%
X
# Out:
#        income  months_since_policy_inception  number_of_policies  \
# 0       48029                             52                   3
# 2       22139                             31                   2
# 6       37405                             99                   3
# 7       87197                             45                   3
# 8       66839                             24                   1
# ...       ...                            ...                 ...
# 10901   33531                             15                   1
# 10902   28304                             30                   1
# 10903   59855                             82                   1
# 10906   61146                             68                   3
# 10908   64195                             27                   3
#
#        med_customer_lifetime_value_trans  med_monthly_premium_auto_trans  \
# 0                              -0.245640                       -1.511582
# 2                               2.014000                        0.854797
# 6                              -0.152508                       -1.305648
# 7                              -0.184564                       -1.305648
# 8                               0.198444                        1.970959
# ...                                  ...                             ...
# 10901                          -0.358990                        1.311997
# 10902                          -0.848042                        0.514050
# 10903                          -1.373785                       -0.399868
# 10906                          -0.064366                       -1.114353
# 10908                           1.578195                        2.019295
#
#        state_washington  coverage_Extended  location_code_Suburban  \
# 0                     0                  0                       1
# 2                     1                  0                       1
# 6                     0                  0                       0
# 7                     0                  0                       0
# 8                     0                  0                       1
# ...                 ...                ...                     ...
# 10901                 1                  0                       1
# 10902                 0                  1                       1
# 10903                 0                  0                       1
# 10906                 0                  0                       0
# 10908                 0                  0                       0
#
#        location_code_Urban  vehicle_size_Small  region_east
# 0                        0                   0            0
# 2                        0                   0            1
# 6                        1                   0            0
# 7                        1                   0            0
# 8                        0                   0            0
# ...                    ...                 ...          ...
# 10901                    0                   0            1
# 10902                    0                   0            0
# 10903                    0                   0            0
# 10906                    1                   0            0
# 10908                    1                   0            0
#
# [5895 rows x 11 columns]

# %% [markdown]
# ## Model without the irrelevant variables

# %% [markdown]
# ### With Scaler

# %%
X_train, X_test, y_train, y_test=train_test_split(X, Y, test_size=0.20, random_state=1000)

# %%
std_scaler=StandardScaler().fit(X_train)

X_train_scaled=std_scaler.transform(X_train)
X_test_scaled=std_scaler.transform(X_test)

# %%
X_train_scaled_constant= sm.add_constant(X_train_scaled)
X_test_scaled_constant= sm.add_constant(X_test_scaled)  #adding a constant

model=sm.OLS(y_train,X_train_scaled_constant).fit()
predictions=model.predict(X_test_scaled_constant)

print_model=model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     total_claim_amount   R-squared:                       0.809
# Model:                            OLS   Adj. R-squared:                  0.809
# Method:                 Least Squares   F-statistic:                     1998.
# Date:                Thu, 20 Jan 2022   Prob (F-statistic):               0.00
# Time:                        10:51:48   Log-Likelihood:                -27434.
# No. Observations:                4716   AIC:                         5.489e+04
# Df Residuals:                    4705   BIC:                         5.496e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        341.0948      1.185    287.746      0.000     338.771     343.419
# x1            -4.6330      1.261     -3.673      0.000      -7.106      -2.160
# x2            -2.0960      1.187     -1.766      0.077      -4.423       0.231
# x3            -5.6582      1.635     -3.461      0.001      -8.864      -2.453
# x4             6.0018      1.821      3.297      0.001       2.432       9.571
# x5            80.0283      1.541     51.927      0.000      77.007      83.050
# x6             0.9627      0.593      1.623      0.105      -0.200       2.126
# x7            -6.1705      1.290     -4.782      0.000      -8.700      -3.641
# x8           173.3597      1.534    113.022      0.000     170.353     176.367
# x9            85.3919      1.443     59.161      0.000      82.562      88.222
# x10            1.7902      1.219      1.469      0.142      -0.600       4.180
# x11            0.9627      0.593      1.623      0.105      -0.200       2.126
# ==============================================================================
# Omnibus:                      850.730   Durbin-Watson:                   1.936
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1838.747
# Skew:                           1.049   Prob(JB):                         0.00
# Kurtosis:                       5.226   Cond. No.                     4.60e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.5e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ### Without scaler

# %%
X_train, X_test, y_train, y_test=train_test_split(X, Y, test_size=0.20, random_state=1000)

# %%
X_train_constant= sm.add_constant(X_train)
X_test_constant= sm.add_constant(X_test)  #adding a constant
model=sm.OLS(y_train,X_train_constant).fit()
predictions=model.predict(X_test_constant)

print_model=model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     total_claim_amount   R-squared:                       0.809
# Model:                            OLS   Adj. R-squared:                  0.809
# Method:                 Least Squares   F-statistic:                     1998.
# Date:                Thu, 20 Jan 2022   Prob (F-statistic):               0.00
# Time:                        10:51:48   Log-Likelihood:                -27434.
# No. Observations:                4716   AIC:                         5.489e+04
# Df Residuals:                    4705   BIC:                         5.496e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# const                               138.8867      5.878     23.629      0.000     127.364     150.410
# income                               -0.0002   5.18e-05     -3.673      0.000      -0.000   -8.87e-05
# months_since_policy_inception        -0.0753      0.043     -1.766      0.077      -0.159       0.008
# number_of_policies                   -6.2815      1.815     -3.461      0.001      -9.840      -2.723
# med_customer_lifetime_value_trans     6.0121      1.824      3.297      0.001       2.437       9.587
# med_monthly_premium_auto_trans       80.0677      1.542     51.927      0.000      77.045      83.091
# state_washington                      3.3874      2.087      1.623      0.105      -0.704       7.479
# coverage_Extended                   -13.6330      2.851     -4.782      0.000     -19.222      -8.044
# location_code_Suburban              347.5921      3.075    113.022      0.000     341.563     353.621
# location_code_Urban                 206.2467      3.486     59.161      0.000     199.412     213.081
# vehicle_size_Small                    4.5536      3.101      1.469      0.142      -1.525      10.632
# region_east                           3.3874      2.087      1.623      0.105      -0.704       7.479
# ==============================================================================
# Omnibus:                      850.730   Durbin-Watson:                   1.936
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1838.747
# Skew:                           1.049   Prob(JB):                         0.00
# Kurtosis:                       5.226   Cond. No.                     2.97e+20
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.68e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# C:\Users\merce\anaconda3\envs\Da_Env1\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
model.params.iloc[1:]
# Out:
# income                                -0.000190
# months_since_policy_inception         -0.075337
# number_of_policies                    -6.281457
# med_customer_lifetime_value_trans      6.012050
# med_monthly_premium_auto_trans        80.067699
# state_washington                       3.387382
# coverage_Extended                    -13.633008
# location_code_Suburban               347.592142
# location_code_Urban                  206.246651
# vehicle_size_Small                     4.553630
# region_east                            3.387382
# dtype: float64

# %%
features_importances = pd.DataFrame(data={
    'Attribute': X_train.columns,
    'Importance': model.params.iloc[1:]
})
features_importances = features_importances.sort_values(by='Importance', ascending=False)

# %%
features_importances
# Out:
#                                                            Attribute  \
# location_code_Suburban                        location_code_Suburban
# location_code_Urban                              location_code_Urban
# med_monthly_premium_auto_trans        med_monthly_premium_auto_trans
# med_customer_lifetime_value_trans  med_customer_lifetime_value_trans
# vehicle_size_Small                                vehicle_size_Small
# region_east                                              region_east
# state_washington                                    state_washington
# income                                                        income
# months_since_policy_inception          months_since_policy_inception
# number_of_policies                                number_of_policies
# coverage_Extended                                  coverage_Extended
#
#                                    Importance
# location_code_Suburban             347.592142
# location_code_Urban                206.246651
# med_monthly_premium_auto_trans      80.067699
# med_customer_lifetime_value_trans    6.012050
# vehicle_size_Small                   4.553630
# region_east                          3.387382
# state_washington                     3.387382
# income                              -0.000190
# months_since_policy_inception       -0.075337
# number_of_policies                  -6.281457
# coverage_Extended                  -13.633008

# %%
plt.bar(x=features_importances['Attribute'], height=features_importances['Importance'], color='#2CA1D8')
plt.title('Feature importances obtained from coefficients', size=20)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# ## Modeling using Scikit Learn

# %% [markdown]
# Model fitting

# %%
model=LinearRegression()    # model
model.fit(X_train_scaled, y_train)   # model train
# Out:
# LinearRegression()

# %% [markdown]
# model parameters

# %%
model.coef_
# Out:
# array([ -4.63303714,  -2.09597149,  -5.65815294,   6.00182825,
#         80.02833451,   0.96274591,  -6.17045761, 173.3596549 ,
#         85.39194319,   1.79016707,   0.96274591])

# %%
model.intercept_
# Out:
# 341.09478371501274

# %%
model.score(X_test_scaled,y_test)
# Out:
# 0.8121885995639361

# %% [markdown]
# Making prediction

# %%
y_pred=model.predict(X_test_scaled)   # model prediction
##y_pred_train=model.predict(X_train)

# %%
y_test
# Out:
# 8670      49.0
# 8014     222.0
# 7370     327.0
# 1745     513.0
# 5009     388.0
#          ...
# 1829     629.0
# 2773     291.0
# 4978      33.0
# 1579     446.0
# 10693    511.0
# Name: total_claim_amount, Length: 1179, dtype: float64

# %%
y_pred
# Out:
# array([142.97249813, 325.52791579, 385.11940334, ...,  46.04787829,
#        344.07736736, 414.79662582])

# %%
result=pd.DataFrame({"y_test":y_test,"y_pred":y_pred})

# %%
# Make an scatter plot y_pred vs y
# What kind of plot you will get if all the all the predictions are ok?
# A stright line

fig, ax = plt.subplots(1,3,figsize=(14,4))
ax[0].plot(y_pred, y_test, "o",color="blue")
ax[0].set_xlabel("y_test")
ax[0].set_ylabel("y_pred")
ax[0].set_title("Test Set -Predicted vs real")

# Get a histogram of the residuals ie: y - y_pred.  Homoscdasticity
# It resembles a normal distribution?
ax[1].hist(y_test - y_pred)
ax[1].set_xlabel("Test y-y_pred")
ax[1].set_title("Test Set Residual histogram")

ax[2].plot(y_pred,y_test - y_pred,"o",color="blue")
ax[2].set_xlabel("predited")
ax[2].set_ylabel("residuals")
ax[2].set_title("Residuals by Predicted")
ax[2].plot(y_pred,np.zeros(len(y_pred)),linestyle='dashed')

# %% [markdown]
# more fancy using seaborn

# %%
sns.regplot(x='y_pred',y='y_test', data=result, scatter_kws={"color": "blue"}, line_kws={"color": "black"})
# Out:
# <AxesSubplot:xlabel='y_pred', ylabel='y_test'>

# %% [markdown]
# Error metrics

# %%
print(mse(y_test,y_pred))
print(mae(y_test,y_pred))
# Out:
# 6658.177365235618
# 63.80866951691703

# %%
R2=r2_score(y_test,y_pred)
R2
# Out:
# 0.8121885995639361

# %%
Adj_R2= 1 - (1-R2)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
Adj_R2
# Out:
# 0.8104183121562268

# %% [markdown]
#  Feature Importance

# %%
features_importances = pd.DataFrame(data={
    'Attribute': X_train.columns,
    'Importance': model.coef_
})
features_importances = features_importances.sort_values(by='Importance', ascending=False)

# %%
features_importances
# Out:
#                             Attribute  Importance
# 7              location_code_Suburban  173.359655
# 8                 location_code_Urban   85.391943
# 4      med_monthly_premium_auto_trans   80.028335
# 3   med_customer_lifetime_value_trans    6.001828
# 9                  vehicle_size_Small    1.790167
# 10                        region_east    0.962746
# 5                    state_washington    0.962746
# 1       months_since_policy_inception   -2.095971
# 0                              income   -4.633037
# 2                  number_of_policies   -5.658153
# 6                   coverage_Extended   -6.170458

# %% [markdown]
# ## Model Comparison

# %% [markdown]
# ### Lasso

# %%
#Lasso
clf1 = linear_model.Lasso(alpha=1)
clf1.fit(X_train_scaled, y_train)
# Out:
# Lasso(alpha=1)

# %%
clf1.score(X_test_scaled,y_test)
# Out:
# 0.8113277702672441

# %% [markdown]
# ### Ridge

# %%
# Ridge
clf2 = Ridge(alpha=1.0)
clf2.fit(X_train_scaled, y_train)
# Out:
# Ridge()

# %%
clf2.score(X_test_scaled,y_test)
# Out:
# 0.8121811327701222

# %% [markdown]
# ### Linear regression

# %%
X_train, X_test, y_train, y_test=train_test_split(X, Y, test_size=0.20, random_state=1000)

# %%
std_scaler=StandardScaler().fit(X_train)

X_train_scaled=std_scaler.transform(X_train)
X_test_scaled=std_scaler.transform(X_test)

# %%
X_train_scaled_constant= sm.add_constant(X_train_scaled)
X_test_scaled_constant= sm.add_constant(X_test_scaled)  #adding a constant

model=sm.OLS(y_train,X_train_scaled_constant).fit()
predictions=model.predict(X_test_scaled_constant)

print_model=model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     total_claim_amount   R-squared:                       0.809
# Model:                            OLS   Adj. R-squared:                  0.809
# Method:                 Least Squares   F-statistic:                     1998.
# Date:                Thu, 20 Jan 2022   Prob (F-statistic):               0.00
# Time:                        10:51:51   Log-Likelihood:                -27434.
# No. Observations:                4716   AIC:                         5.489e+04
# Df Residuals:                    4705   BIC:                         5.496e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        341.0948      1.185    287.746      0.000     338.771     343.419
# x1            -4.6330      1.261     -3.673      0.000      -7.106      -2.160
# x2            -2.0960      1.187     -1.766      0.077      -4.423       0.231
# x3            -5.6582      1.635     -3.461      0.001      -8.864      -2.453
# x4             6.0018      1.821      3.297      0.001       2.432       9.571
# x5            80.0283      1.541     51.927      0.000      77.007      83.050
# x6             0.9627      0.593      1.623      0.105      -0.200       2.126
# x7            -6.1705      1.290     -4.782      0.000      -8.700      -3.641
# x8           173.3597      1.534    113.022      0.000     170.353     176.367
# x9            85.3919      1.443     59.161      0.000      82.562      88.222
# x10            1.7902      1.219      1.469      0.142      -0.600       4.180
# x11            0.9627      0.593      1.623      0.105      -0.200       2.126
# ==============================================================================
# Omnibus:                      850.730   Durbin-Watson:                   1.936
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1838.747
# Skew:                           1.049   Prob(JB):                         0.00
# Kurtosis:                       5.226   Cond. No.                     4.60e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.5e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ### KNeighborsRegressor

# %%
from sklearn.neighbors import KNeighborsRegressor # Import KNeighborsClassifier to use the K-NN for classification

# initialize model (set parameters)
neigh = KNeighborsRegressor(n_neighbors=10) # n_neighbors = K

# %%
neigh.fit(X_train_scaled, y_train)
# Minkowski distance with p = 2 -> Euclidean distance
# Out:
# KNeighborsRegressor(n_neighbors=10)

# %%
# make predictions
y_pred_train_knn = neigh.predict(X_train_scaled)
y_pred_test_knn  = neigh.predict(X_test_scaled)

# %%
#R2 for training data
R2_neigh=r2_score((y_train),(y_pred_train_knn))

# %%
R2
# Out:
# 0.8121885995639361

# %%
#R2 for test data
R2=r2_score((y_test),(y_pred_test_knn))

# %%
R2
# Out:
# 0.822818439799548

# %%
def model(X,Y):
    
    X_train, X_test, y_train, y_test=train_test_split(X, Y, test_size=0.20, random_state=1000)
    
    std_scaler=StandardScaler().fit(X_train)
    X_train_scaled=std_scaler.transform(X_train)
    X_test_scaled=std_scaler.transform(X_test)
    
    
    ols=["ols"]
    model=LinearRegression()  
    model.fit(X_train_scaled, y_train) 
    y_pred_test=model.predict(X_test_scaled)   # model prediction
    y_pred_train=model.predict(X_train_scaled)
    R2_lm_test=ols.append(r2_score(y_test,y_pred_test))
    R2_lm_train=ols.append(r2_score(y_train,y_pred_train))
    
    lasso=["Lasso"]
    clf1 = linear_model.Lasso(alpha=10)
    clf1.fit(X_train_scaled, y_train)
    y_pred_test=clf1.predict(X_test_scaled)   # model prediction
    y_pred_train=clf1.predict(X_train_scaled)
    R2_lasso_test=lasso.append(clf1.score(X_test_scaled,y_test))
    R2_lasso_train=lasso.append(clf1.score(X_train_scaled,y_train))
    
    ridge=["Ridge"]
    clf2 = Ridge(alpha=1.0)
    clf2.fit(X_train_scaled, y_train)
    y_pred_test=clf2.predict(X_test_scaled)   # model prediction
    y_pred_train=clf2.predict(X_train_scaled)
    R2_ridge_test=ridge.append(clf2.score(X_test_scaled,y_test))
    R2_ridge_train=ridge.append(clf2.score(X_train_scaled,y_train))
    
    knn=["knn"]
    neigh = KNeighborsRegressor(n_neighbors=10)
    neigh.fit(X_train_scaled, y_train)
    y_pred_test=neigh.predict(X_test_scaled)   # model prediction
    y_pred_train=neigh.predict(X_train_scaled)
    R2_neigh_test=knn.append(r2_score((y_test),(y_pred_test_knn)))
    R2_neigh_train=knn.append(r2_score((y_train),(y_pred_train_knn)))

    
    R2_comparison=pd.DataFrame([ols,lasso,ridge,knn],columns=["model","R2_test", "R2_train"])
    
    return R2_comparison

# %%
model(X,Y)
# Out:
#    model   R2_test  R2_train
# 0    ols  0.812189  0.809403
# 1  Lasso  0.791108  0.790988
# 2  Ridge  0.812181  0.809403
# 3    knn  0.822818  0.858873
