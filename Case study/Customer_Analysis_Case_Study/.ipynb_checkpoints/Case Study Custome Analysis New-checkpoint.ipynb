# %% [markdown]
# # Case Study Customer Analysis

# %% [markdown]
# ## Load data

# %%
# we need to import the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection
# %matplotlib inline
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PowerTransformer
from sklearn.linear_model import LinearRegression
from scipy.stats import boxcox
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae
pd.options.display.max_rows = 50
from ipywidgets import interactive
import ipywidgets as widgets
import statsmodels.api as sm
import math

# %%
# We import our data from Excel file
ca_df=pd.read_csv("Data/Data_Marketing_Customer_Analysis_Round2.csv")
ca_df
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0         Basic   College           2/18/11         Employed      M  ...
# 1         Basic   College           1/18/11       Unemployed      F  ...
# 2         Basic  Bachelor           2/10/11         Employed      M  ...
# 3      Extended   College           1/11/11         Employed      M  ...
# 4       Premium  Bachelor           1/17/11    Medical Leave      F  ...
# ...         ...       ...               ...              ...    ...  ...
# 10905   Premium  Bachelor           1/19/11       Unemployed      F  ...
# 10906     Basic   College            1/6/11         Employed      F  ...
# 10907  Extended  Bachelor            2/6/11         Employed      F  ...
# 10908   Premium   College           2/13/11         Employed      F  ...
# 10909     Basic  Bachelor            1/8/11       Unemployed      M  ...
#
#        Number of Open Complaints Number of Policies     Policy Type  \
# 0                            0.0                  9  Corporate Auto
# 1                            0.0                  1   Personal Auto
# 2                            0.0                  2   Personal Auto
# 3                            0.0                  2  Corporate Auto
# 4                            NaN                  7   Personal Auto
# ...                          ...                ...             ...
# 10905                        NaN                  7   Personal Auto
# 10906                        0.0                  6   Personal Auto
# 10907                        0.0                  2  Corporate Auto
# 10908                        4.0                  6   Personal Auto
# 10909                        0.0                  3   Personal Auto
#
#              Policy  Renew Offer Type  Sales Channel  Total Claim Amount  \
# 0      Corporate L3            Offer3          Agent          292.800000
# 1       Personal L3            Offer4    Call Center          744.924331
# 2       Personal L3            Offer3    Call Center          480.000000
# 3      Corporate L3            Offer2         Branch          484.013411
# 4       Personal L2            Offer1         Branch          707.925645
# ...             ...               ...            ...                 ...
# 10905   Personal L1            Offer3            Web         1214.400000
# 10906   Personal L3            Offer2         Branch          273.018929
# 10907  Corporate L3            Offer1            Web          381.306996
# 10908   Personal L1            Offer1         Branch          618.288849
# 10909   Personal L1            Offer4            Web         1021.719397
#
#        Vehicle Class Vehicle Size Vehicle Type
# 0      Four-Door Car      Medsize          NaN
# 1      Four-Door Car      Medsize          NaN
# 2                SUV      Medsize            A
# 3      Four-Door Car      Medsize            A
# 4      Four-Door Car      Medsize          NaN
# ...              ...          ...          ...
# 10905     Luxury Car      Medsize            A
# 10906  Four-Door Car      Medsize            A
# 10907     Luxury SUV      Medsize          NaN
# 10908            SUV      Medsize            A
# 10909            SUV      Medsize          NaN
#
# [10910 rows x 26 columns]

# %%
def clean_data(df):
    df.columns=[e.lower().replace(' ', '_') for e in df.columns]
    df=df.drop(columns=['unnamed:_0', 'vehicle_type',"customer"])
    df=df.dropna()
    df['effective_to_date']=pd.to_datetime(df['effective_to_date'], errors='coerce')
    df["month"]=list(map(lambda date:date.strftime(format="%B"),df["effective_to_date"]))
    # we drop effective_to_date column
    df=df.drop(columns=['effective_to_date'])
    return df

# %%
def transform(df):
    df=df[df['income']>0]
    df["total_claim_amount"]=round(df["total_claim_amount"],0)
    df["customer_lifetime_value"]=round(df["customer_lifetime_value"],0)
    df.vehicle_class[ca_df.vehicle_class.isin(["Luxury Car","Luxury SUV"])] = "Luxury Car"
    df.vehicle_class[ca_df.vehicle_class.isin(["Four-Door Car","SUV"])] = "Four-Door Car"
    df.policy[df.policy.isin(["Personal L3","Personal L2","Personal L1"]) ] = "Personal"
    df.policy[df.policy.isin(["Corporate L3","Corporate L2","Corporate L1"]) ] = "Corporate"
    df.policy[df.policy.isin(["Special L3","Special L2","Special L1"]) ] = "Special"
    df=df.drop(columns=["month","education"])
    df.number_of_policies[df.number_of_policies>2]=3
    return df

# %%
ca_df=clean_data(ca_df)
ca_df=transform(ca_df)
# Out:
# <ipython-input-148-0836ef558403>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["total_claim_amount"]=round(df["total_claim_amount"],0)
# <ipython-input-148-0836ef558403>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["customer_lifetime_value"]=round(df["customer_lifetime_value"],0)
# <ipython-input-148-0836ef558403>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.vehicle_class[ca_df.vehicle_class.isin(["Luxury Car","Luxury SUV"])] = "Luxury Car"
# C:\Users\merce\anaconda3\lib\site-packages\pandas\core\series.py:992: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# <ipython-input-148-0836ef558403>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.vehicle_class[ca_df.vehicle_class.isin(["Four-Door Car","SUV"])] = "Four-Door Car"
# <ipython-input-148-0836ef558403>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.policy[df.policy.isin(["Personal L3","Personal L2","Personal L1"]) ] = "Personal"
# <ipython-input-148-0836ef558403>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.policy[df.policy.isin(["Corporate L3","Corporate L2","Corporate L1"]) ] = "Corporate"
# <ipython-input-148-0836ef558403>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.policy[df.policy.isin(["Special L3","Special L2","Special L1"]) ] = "Special"
# <ipython-input-148-0836ef558403>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.number_of_policies[df.number_of_policies>2]=3

# %%
ca_df
# Out:
#             state  customer_lifetime_value response  coverage  \
# 0         Arizona                   4809.0       No     Basic
# 2      Washington                  14948.0       No     Basic
# 3          Oregon                  22332.0      Yes  Extended
# 6      California                   5035.0       No     Basic
# 7      California                   4956.0       No     Basic
# ...           ...                      ...      ...       ...
# 10902  California                   3579.0       No  Extended
# 10903     Arizona                   2772.0       No     Basic
# 10906      Oregon                   5259.0       No     Basic
# 10907     Arizona                  23893.0       No  Extended
# 10908  California                  11972.0       No   Premium
#
#       employmentstatus gender  income location_code marital_status  \
# 0             Employed      M   48029      Suburban        Married
# 2             Employed      M   22139      Suburban         Single
# 3             Employed      M   49078      Suburban         Single
# 6             Employed      F   37405         Urban        Married
# 7             Employed      M   87197         Urban         Single
# ...                ...    ...     ...           ...            ...
# 10902         Employed      F   28304      Suburban        Married
# 10903         Employed      M   59855      Suburban        Married
# 10906         Employed      F   61146         Urban        Married
# 10907         Employed      F   39837         Rural        Married
# 10908         Employed      F   64195         Urban       Divorced
#
#        monthly_premium_auto  ...  months_since_policy_inception  \
# 0                        61  ...                             52
# 2                       100  ...                             31
# 3                        97  ...                              3
# 6                        63  ...                             99
# 7                        63  ...                             45
# ...                     ...  ...                            ...
# 10902                    91  ...                             30
# 10903                    74  ...                             82
# 10906                    65  ...                             68
# 10907                   201  ...                             63
# 10908                   158  ...                             27
#
#        number_of_open_complaints  number_of_policies     policy_type  \
# 0                            0.0                   3  Corporate Auto
# 2                            0.0                   2   Personal Auto
# 3                            0.0                   2  Corporate Auto
# 6                            3.0                   3  Corporate Auto
# 7                            0.0                   3   Personal Auto
# ...                          ...                 ...             ...
# 10902                        2.0                   1   Personal Auto
# 10903                        4.0                   1   Personal Auto
# 10906                        0.0                   3   Personal Auto
# 10907                        0.0                   2  Corporate Auto
# 10908                        4.0                   3   Personal Auto
#
#           policy renew_offer_type sales_channel total_claim_amount  \
# 0      Corporate           Offer3         Agent              293.0
# 2       Personal           Offer3   Call Center              480.0
# 3      Corporate           Offer2        Branch              484.0
# 6      Corporate           Offer2        Branch              288.0
# 7       Personal           Offer2        Branch              247.0
# ...          ...              ...           ...                ...
# 10902   Personal           Offer2         Agent              655.0
# 10903   Personal           Offer2        Branch              355.0
# 10906   Personal           Offer2        Branch              273.0
# 10907  Corporate           Offer1           Web              381.0
# 10908   Personal           Offer1        Branch              618.0
#
#        vehicle_class vehicle_size
# 0      Four-Door Car      Medsize
# 2      Four-Door Car      Medsize
# 3      Four-Door Car      Medsize
# 6      Four-Door Car      Medsize
# 7       Two-Door Car      Medsize
# ...              ...          ...
# 10902  Four-Door Car      Medsize
# 10903   Two-Door Car      Medsize
# 10906  Four-Door Car      Medsize
# 10907     Luxury Car      Medsize
# 10908  Four-Door Car      Medsize
#
# [6817 rows x 21 columns]

# %%
# I can see that I have a column name "unnamed=0" that duplicates the column that indicates the number of the row
list(ca_df.columns)
# Out:
# ['Unnamed: 0',
#  'state',
#  'customer_lifetime_value',
#  'education',
#  'gender',
#  'income',
#  'monthly_premium_auto',
#  'number_of_open_complaints',
#  'policy_type',
#  'total_claim_amount',
#  'vehicle_class',
#  'sales_channel',
#  'response']

# %%
ca_df = ca_df[[
 'state',
 'customer_lifetime_value',
 'education',
 'gender',
 'income',
 'monthly_premium_auto',
 'number_of_open_complaints',
 'policy_type',
 'total_claim_amount',
 'vehicle_class',
 'sales_channel',
 'response']]

ca_df
# Out:
#             state  customer_lifetime_value education gender  income  \
# 0         Arizona              4809.216960   College      M   48029
# 1      California              2228.525238   College      F       0
# 2      Washington             14947.917300  Bachelor      M   22139
# 3          Oregon             22332.439460   College      M   49078
# 4          Oregon              9025.067525  Bachelor      F   23675
# ...           ...                      ...       ...    ...     ...
# 10905      Nevada             15563.369440  Bachelor      F       0
# 10906      Oregon              5259.444853   College      F   61146
# 10907     Arizona             23893.304100  Bachelor      F   39837
# 10908  California             11971.977650   College      F   64195
# 10909         NaN              6857.519928  Bachelor      M       0
#
#        monthly_premium_auto  number_of_open_complaints     policy_type  \
# 0                        61                        0.0  Corporate Auto
# 1                        64                        0.0   Personal Auto
# 2                       100                        0.0   Personal Auto
# 3                        97                        0.0  Corporate Auto
# 4                       117                        NaN   Personal Auto
# ...                     ...                        ...             ...
# 10905                   253                        NaN   Personal Auto
# 10906                    65                        0.0   Personal Auto
# 10907                   201                        0.0  Corporate Auto
# 10908                   158                        4.0   Personal Auto
# 10909                   101                        0.0   Personal Auto
#
#        total_claim_amount  vehicle_class sales_channel response
# 0              292.800000  Four-Door Car         Agent       No
# 1              744.924331  Four-Door Car   Call Center       No
# 2              480.000000            SUV   Call Center       No
# 3              484.013411  Four-Door Car        Branch      Yes
# 4              707.925645  Four-Door Car        Branch       No
# ...                   ...            ...           ...      ...
# 10905         1214.400000     Luxury Car           Web       No
# 10906          273.018929  Four-Door Car        Branch       No
# 10907          381.306996     Luxury SUV           Web       No
# 10908          618.288849            SUV        Branch       No
# 10909         1021.719397            SUV           Web      NaN
#
# [10910 rows x 12 columns]

# %% [markdown]
# ## Working with Data type

# %%
# checking data type of our data set
ca_df.info()
# We this function we can see the data type.
# after checkin the data. The column "number of open complaint" should not be a float.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   state                      10279 non-null  object
#  1   customer_lifetime_value    10910 non-null  float64
#  2   education                  10910 non-null  object
#  3   gender                     10910 non-null  object
#  4   income                     10910 non-null  int64
#  5   monthly_premium_auto       10910 non-null  int64
#  6   number_of_open_complaints  10277 non-null  float64
#  7   policy_type                10910 non-null  object
#  8   total_claim_amount         10910 non-null  float64
#  9   vehicle_class              10288 non-null  object
#  10  sales_channel              10910 non-null  object
#  11  response                   10279 non-null  object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 1022.9+ KB

# %%
# variable "number_of_open_complaints" should not be a float number. 
# We can see that there is many NaN values in the columns.
#We cannot transform "number_of_open_complaints" into an integer because of Nan values 
#In this case, we have to replace the NaN values with "0" with replace function.


ca_df['number_of_open_complaints'] = ca_df['number_of_open_complaints'].fillna(0)

# %%
# we can transform "number_of_open_complaints" into an integer

ca_df['number_of_open_complaints'] = ca_df['number_of_open_complaints'].astype('int')

# %%
ca_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6817 entries, 0 to 10908
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   state                          6817 non-null   object
#  1   customer_lifetime_value        6817 non-null   float64
#  2   response                       6817 non-null   object
#  3   coverage                       6817 non-null   object
#  4   employmentstatus               6817 non-null   object
#  5   gender                         6817 non-null   object
#  6   income                         6817 non-null   int64
#  7   location_code                  6817 non-null   object
#  8   marital_status                 6817 non-null   object
#  9   monthly_premium_auto           6817 non-null   int64
#  10  months_since_last_claim        6817 non-null   float64
#  11  months_since_policy_inception  6817 non-null   int64
#  12  number_of_open_complaints      6817 non-null   int32
#  13  number_of_policies             6817 non-null   int64
#  14  policy_type                    6817 non-null   object
#  15  policy                         6817 non-null   object
#  16  renew_offer_type               6817 non-null   object
#  17  sales_channel                  6817 non-null   object
#  18  total_claim_amount             6817 non-null   float64
#  19  vehicle_class                  6817 non-null   object
#  20  vehicle_size                   6817 non-null   object
# dtypes: float64(3), int32(1), int64(4), object(13)
# memory usage: 1.1+ MB

# %% [markdown]
# ## Filtering data and Correcting typos

# %%
# We need to standardize the text in the column "gender".

ca_df['gender'].value_counts()
# Out:
# F    3523
# M    3294
# Name: gender, dtype: int64

# %%
# number of missing values in the column "gender"

len(ca_df[ca_df['gender'].isna()==True])
# Out:
# 0

# %%
# with the new data set, the column text is already standardized

ca_df.gender.unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
#Let's have a look to the column "state"

ca_df['state'].value_counts()
# Out:
# California    2346
# Oregon        1937
# Arizona       1273
# Nevada         665
# Washington     596
# Name: state, dtype: int64

# %%
len(ca_df[ca_df['state'].isna()==True])
# Out:
# 0

# %%
def clean_state(x):
    if x in ['California', 'Cali']:
        return 'california'
    elif x in["Arizona","az"]:
        return 'arizona'
    elif x in ["Washington","wa"]:
         return "washington"
    elif x in ["Oregon"]:
         return "oregon"
    elif x in ["Nevada"]:
        return "nevada"
    else:
        return 'U'

# %%
ca_df['state'] = list(map(clean_state, ca_df['state']))

# %%
ca_df.state.unique()
# Out:
# array(['arizona', 'washington', 'oregon', 'california', 'nevada'],
#       dtype=object)

# %% [markdown]
# ### replace 0 for mean value

# %%
# columns "income" and "number_of_open_complaints" have many "0" values. We will replace the values
ca_df['income']=ca_df['income'].replace(0,ca_df['income'].mean())
ca_df['number_of_open_complaints']=ca_df['number_of_open_complaints'].replace(0,ca_df['number_of_open_complaints'].mean())

# %%
ca_df
# Out:
#             state  customer_lifetime_value response  coverage  \
# 0         arizona                   4809.0       No     Basic
# 2      washington                  14948.0       No     Basic
# 3          oregon                  22332.0      Yes  Extended
# 6      california                   5035.0       No     Basic
# 7      california                   4956.0       No     Basic
# ...           ...                      ...      ...       ...
# 10902  california                   3579.0       No  Extended
# 10903     arizona                   2772.0       No     Basic
# 10906      oregon                   5259.0       No     Basic
# 10907     arizona                  23893.0       No  Extended
# 10908  california                  11972.0       No   Premium
#
#       employmentstatus gender  income location_code marital_status  \
# 0             Employed      M   48029      Suburban        Married
# 2             Employed      M   22139      Suburban         Single
# 3             Employed      M   49078      Suburban         Single
# 6             Employed      F   37405         Urban        Married
# 7             Employed      M   87197         Urban         Single
# ...                ...    ...     ...           ...            ...
# 10902         Employed      F   28304      Suburban        Married
# 10903         Employed      M   59855      Suburban        Married
# 10906         Employed      F   61146         Urban        Married
# 10907         Employed      F   39837         Rural        Married
# 10908         Employed      F   64195         Urban       Divorced
#
#        monthly_premium_auto  ...  months_since_policy_inception  \
# 0                        61  ...                             52
# 2                       100  ...                             31
# 3                        97  ...                              3
# 6                        63  ...                             99
# 7                        63  ...                             45
# ...                     ...  ...                            ...
# 10902                    91  ...                             30
# 10903                    74  ...                             82
# 10906                    65  ...                             68
# 10907                   201  ...                             63
# 10908                   158  ...                             27
#
#        number_of_open_complaints  number_of_policies     policy_type  \
# 0                        0.38184                   3  Corporate Auto
# 2                        0.38184                   2   Personal Auto
# 3                        0.38184                   2  Corporate Auto
# 6                        3.00000                   3  Corporate Auto
# 7                        0.38184                   3   Personal Auto
# ...                          ...                 ...             ...
# 10902                    2.00000                   1   Personal Auto
# 10903                    4.00000                   1   Personal Auto
# 10906                    0.38184                   3   Personal Auto
# 10907                    0.38184                   2  Corporate Auto
# 10908                    4.00000                   3   Personal Auto
#
#           policy renew_offer_type sales_channel total_claim_amount  \
# 0      Corporate           Offer3         Agent              293.0
# 2       Personal           Offer3   Call Center              480.0
# 3      Corporate           Offer2        Branch              484.0
# 6      Corporate           Offer2        Branch              288.0
# 7       Personal           Offer2        Branch              247.0
# ...          ...              ...           ...                ...
# 10902   Personal           Offer2         Agent              655.0
# 10903   Personal           Offer2        Branch              355.0
# 10906   Personal           Offer2        Branch              273.0
# 10907  Corporate           Offer1           Web              381.0
# 10908   Personal           Offer1        Branch              618.0
#
#        vehicle_class vehicle_size
# 0      Four-Door Car      Medsize
# 2      Four-Door Car      Medsize
# 3      Four-Door Car      Medsize
# 6      Four-Door Car      Medsize
# 7       Two-Door Car      Medsize
# ...              ...          ...
# 10902  Four-Door Car      Medsize
# 10903   Two-Door Car      Medsize
# 10906  Four-Door Car      Medsize
# 10907     Luxury Car      Medsize
# 10908  Four-Door Car      Medsize
#
# [6817 rows x 21 columns]

# %% [markdown]
# ## Removing duplicates

# %%
# we have to use the function drop_duplicates()

ca_df.drop_duplicates(inplace=True)

# %%
ca_df
# Out:
#             state  customer_lifetime_value response  coverage  \
# 0         arizona                   4809.0       No     Basic
# 2      washington                  14948.0       No     Basic
# 3          oregon                  22332.0      Yes  Extended
# 6      california                   5035.0       No     Basic
# 7      california                   4956.0       No     Basic
# ...           ...                      ...      ...       ...
# 10902  california                   3579.0       No  Extended
# 10903     arizona                   2772.0       No     Basic
# 10906      oregon                   5259.0       No     Basic
# 10907     arizona                  23893.0       No  Extended
# 10908  california                  11972.0       No   Premium
#
#       employmentstatus gender  income location_code marital_status  \
# 0             Employed      M   48029      Suburban        Married
# 2             Employed      M   22139      Suburban         Single
# 3             Employed      M   49078      Suburban         Single
# 6             Employed      F   37405         Urban        Married
# 7             Employed      M   87197         Urban         Single
# ...                ...    ...     ...           ...            ...
# 10902         Employed      F   28304      Suburban        Married
# 10903         Employed      M   59855      Suburban        Married
# 10906         Employed      F   61146         Urban        Married
# 10907         Employed      F   39837         Rural        Married
# 10908         Employed      F   64195         Urban       Divorced
#
#        monthly_premium_auto  ...  months_since_policy_inception  \
# 0                        61  ...                             52
# 2                       100  ...                             31
# 3                        97  ...                              3
# 6                        63  ...                             99
# 7                        63  ...                             45
# ...                     ...  ...                            ...
# 10902                    91  ...                             30
# 10903                    74  ...                             82
# 10906                    65  ...                             68
# 10907                   201  ...                             63
# 10908                   158  ...                             27
#
#        number_of_open_complaints  number_of_policies     policy_type  \
# 0                        0.38184                   3  Corporate Auto
# 2                        0.38184                   2   Personal Auto
# 3                        0.38184                   2  Corporate Auto
# 6                        3.00000                   3  Corporate Auto
# 7                        0.38184                   3   Personal Auto
# ...                          ...                 ...             ...
# 10902                    2.00000                   1   Personal Auto
# 10903                    4.00000                   1   Personal Auto
# 10906                    0.38184                   3   Personal Auto
# 10907                    0.38184                   2  Corporate Auto
# 10908                    4.00000                   3   Personal Auto
#
#           policy renew_offer_type sales_channel total_claim_amount  \
# 0      Corporate           Offer3         Agent              293.0
# 2       Personal           Offer3   Call Center              480.0
# 3      Corporate           Offer2        Branch              484.0
# 6      Corporate           Offer2        Branch              288.0
# 7       Personal           Offer2        Branch              247.0
# ...          ...              ...           ...                ...
# 10902   Personal           Offer2         Agent              655.0
# 10903   Personal           Offer2        Branch              355.0
# 10906   Personal           Offer2        Branch              273.0
# 10907  Corporate           Offer1           Web              381.0
# 10908   Personal           Offer1        Branch              618.0
#
#        vehicle_class vehicle_size
# 0      Four-Door Car      Medsize
# 2      Four-Door Car      Medsize
# 3      Four-Door Car      Medsize
# 6      Four-Door Car      Medsize
# 7       Two-Door Car      Medsize
# ...              ...          ...
# 10902  Four-Door Car      Medsize
# 10903   Two-Door Car      Medsize
# 10906  Four-Door Car      Medsize
# 10907     Luxury Car      Medsize
# 10908  Four-Door Car      Medsize
#
# [6498 rows x 21 columns]

# %% [markdown]
# ## Replace null values

# %%
# in numerical columns, we will replace the NaN values with the mean of each column
# have a loock to our numerical columns

x_df=ca_df._get_numeric_data()
x_df
# Out:
#        customer_lifetime_value        income  monthly_premium_auto  \
# 0                  4809.216960  48029.000000                    61
# 1                  2228.525238  37536.284785                    64
# 2                 14947.917300  22139.000000                   100
# 3                 22332.439460  49078.000000                    97
# 4                  9025.067525  23675.000000                   117
# ...                        ...           ...                   ...
# 10905             15563.369440  37536.284785                   253
# 10906              5259.444853  61146.000000                    65
# 10907             23893.304100  39837.000000                   201
# 10908             11971.977650  64195.000000                   158
# 10909              6857.519928  37536.284785                   101
#
#        number_of_open_complaints  total_claim_amount
# 0                       0.361962          292.800000
# 1                       0.361962          744.924331
# 2                       0.361962          480.000000
# 3                       0.361962          484.013411
# 4                       0.361962          707.925645
# ...                          ...                 ...
# 10905                   0.361962         1214.400000
# 10906                   0.361962          273.018929
# 10907                   0.361962          381.306996
# 10908                   4.000000          618.288849
# 10909                   0.361962         1021.719397
#
# [10910 rows x 5 columns]

# %%
nulls_df = pd.DataFrame(round(x_df.isna().sum()/len(ca_df),4)*100)
nulls_df = nulls_df.reset_index()
nulls_df.columns = ['header_name', 'percent_nulls']
nulls_df
# Out:
#                  header_name  percent_nulls
# 0    customer_lifetime_value            0.0
# 1                     income            0.0
# 2       monthly_premium_auto            0.0
# 3  number_of_open_complaints            0.0
# 4         total_claim_amount            0.0

# %%
#There are not NaN values in the numerical columns.
# what about the categorical columns?

y_df=ca_df.select_dtypes('object')
y_df

#but we still have some missing values in the following columns: "vehicle_class" and "response"
# Out:
#             state response  coverage employmentstatus gender location_code  \
# 0         arizona       No     Basic         Employed      M      Suburban
# 2      washington       No     Basic         Employed      M      Suburban
# 3          oregon      Yes  Extended         Employed      M      Suburban
# 6      california       No     Basic         Employed      F         Urban
# 7      california       No     Basic         Employed      M         Urban
# ...           ...      ...       ...              ...    ...           ...
# 10902  california       No  Extended         Employed      F      Suburban
# 10903     arizona       No     Basic         Employed      M      Suburban
# 10906      oregon       No     Basic         Employed      F         Urban
# 10907     arizona       No  Extended         Employed      F         Rural
# 10908  california       No   Premium         Employed      F         Urban
#
#       marital_status     policy_type     policy renew_offer_type  \
# 0            Married  Corporate Auto  Corporate           Offer3
# 2             Single   Personal Auto   Personal           Offer3
# 3             Single  Corporate Auto  Corporate           Offer2
# 6            Married  Corporate Auto  Corporate           Offer2
# 7             Single   Personal Auto   Personal           Offer2
# ...              ...             ...        ...              ...
# 10902        Married   Personal Auto   Personal           Offer2
# 10903        Married   Personal Auto   Personal           Offer2
# 10906        Married   Personal Auto   Personal           Offer2
# 10907        Married  Corporate Auto  Corporate           Offer1
# 10908       Divorced   Personal Auto   Personal           Offer1
#
#       sales_channel  vehicle_class vehicle_size
# 0             Agent  Four-Door Car      Medsize
# 2       Call Center  Four-Door Car      Medsize
# 3            Branch  Four-Door Car      Medsize
# 6            Branch  Four-Door Car      Medsize
# 7            Branch   Two-Door Car      Medsize
# ...             ...            ...          ...
# 10902         Agent  Four-Door Car      Medsize
# 10903        Branch   Two-Door Car      Medsize
# 10906        Branch  Four-Door Car      Medsize
# 10907           Web     Luxury Car      Medsize
# 10908        Branch  Four-Door Car      Medsize
#
# [6498 rows x 13 columns]

# %%
nulls_df = pd.DataFrame(round(y_df.isna().sum()/len(ca_df),4)*100)
nulls_df = nulls_df.reset_index()
nulls_df.columns = ['header_name', 'percent_nulls']
nulls_df
# Out:
#      header_name  percent_nulls
# 0          state           0.00
# 1      education           0.00
# 2         gender           0.00
# 3    policy_type           0.00
# 4  vehicle_class           5.70
# 5  sales_channel           0.00
# 6       response           5.78

# %%
# we wll use the function fillna to replace all NaN values with "0" in the column "vehicle_class"
# we will replace the NaN values with the categorial variable "No"


ca_df['vehicle_class'] = ca_df['vehicle_class'].fillna(0)

ca_df["response"]=ca_df["response"].fillna("No")

# %%
ca_df.response.value_counts()
# Out:
# No     5707
# Yes     791
# Name: response, dtype: int64

# %%
# with this function. We can see that we do not have more missing values
nulls_df = pd.DataFrame(round(ca_df.isna().sum()/len(ca_df),4)*100)
nulls_df = nulls_df.reset_index()
nulls_df.columns = ['header_name', 'percent_nulls']
nulls_df
# Out:
#                   header_name  percent_nulls
# 0                       state            0.0
# 1     customer_lifetime_value            0.0
# 2                   education            0.0
# 3                      gender            0.0
# 4                      income            0.0
# 5        monthly_premium_auto            0.0
# 6   number_of_open_complaints            0.0
# 7                 policy_type            0.0
# 8          total_claim_amount            0.0
# 9               vehicle_class            0.0
# 10              sales_channel            0.0
# 11                   response            0.0

# %% [markdown]
# ## Creating groups of data

# %%
# we will create a new column called "region". This new column will represent data from column "state" as follows:

# california = West
# Oregon = North
# washington = East
# Arizona & Nevada = Central

# First, I will create a dictionary with the new labels

# %%
state_labels ={
    "california":"west",
    "oregon":"north",
    "washington":"east",
    "arizona":"central",
    "nevada":"central"
}

# %%
# We can use assign function to append a new column called "region"

ca_df=ca_df.assign(region=ca_df.state.map(state_labels))
ca_df
# Out:
#             state  customer_lifetime_value response  coverage  \
# 0         arizona                   4809.0       No     Basic
# 2      washington                  14948.0       No     Basic
# 3          oregon                  22332.0      Yes  Extended
# 6      california                   5035.0       No     Basic
# 7      california                   4956.0       No     Basic
# ...           ...                      ...      ...       ...
# 10902  california                   3579.0       No  Extended
# 10903     arizona                   2772.0       No     Basic
# 10906      oregon                   5259.0       No     Basic
# 10907     arizona                  23893.0       No  Extended
# 10908  california                  11972.0       No   Premium
#
#       employmentstatus gender  income location_code marital_status  \
# 0             Employed      M   48029      Suburban        Married
# 2             Employed      M   22139      Suburban         Single
# 3             Employed      M   49078      Suburban         Single
# 6             Employed      F   37405         Urban        Married
# 7             Employed      M   87197         Urban         Single
# ...                ...    ...     ...           ...            ...
# 10902         Employed      F   28304      Suburban        Married
# 10903         Employed      M   59855      Suburban        Married
# 10906         Employed      F   61146         Urban        Married
# 10907         Employed      F   39837         Rural        Married
# 10908         Employed      F   64195         Urban       Divorced
#
#        monthly_premium_auto  ...  number_of_open_complaints  \
# 0                        61  ...                    0.38184
# 2                       100  ...                    0.38184
# 3                        97  ...                    0.38184
# 6                        63  ...                    3.00000
# 7                        63  ...                    0.38184
# ...                     ...  ...                        ...
# 10902                    91  ...                    2.00000
# 10903                    74  ...                    4.00000
# 10906                    65  ...                    0.38184
# 10907                   201  ...                    0.38184
# 10908                   158  ...                    4.00000
#
#        number_of_policies     policy_type     policy renew_offer_type  \
# 0                       3  Corporate Auto  Corporate           Offer3
# 2                       2   Personal Auto   Personal           Offer3
# 3                       2  Corporate Auto  Corporate           Offer2
# 6                       3  Corporate Auto  Corporate           Offer2
# 7                       3   Personal Auto   Personal           Offer2
# ...                   ...             ...        ...              ...
# 10902                   1   Personal Auto   Personal           Offer2
# 10903                   1   Personal Auto   Personal           Offer2
# 10906                   3   Personal Auto   Personal           Offer2
# 10907                   2  Corporate Auto  Corporate           Offer1
# 10908                   3   Personal Auto   Personal           Offer1
#
#       sales_channel total_claim_amount  vehicle_class  vehicle_size   region
# 0             Agent              293.0  Four-Door Car       Medsize  central
# 2       Call Center              480.0  Four-Door Car       Medsize     east
# 3            Branch              484.0  Four-Door Car       Medsize    north
# 6            Branch              288.0  Four-Door Car       Medsize     west
# 7            Branch              247.0   Two-Door Car       Medsize     west
# ...             ...                ...            ...           ...      ...
# 10902         Agent              655.0  Four-Door Car       Medsize     west
# 10903        Branch              355.0   Two-Door Car       Medsize  central
# 10906        Branch              273.0  Four-Door Car       Medsize    north
# 10907           Web              381.0     Luxury Car       Medsize  central
# 10908        Branch              618.0  Four-Door Car       Medsize     west
#
# [6498 rows x 22 columns]

# %% [markdown]
# **Which columns are numerical and which columns are categorical?**

# %%
# numerical columns:
ca_df._get_numeric_data()
# Out:
#        customer_lifetime_value        income  monthly_premium_auto  \
# 0                  4809.216960  48029.000000                    61
# 1                  2228.525238  37536.284785                    64
# 2                 14947.917300  22139.000000                   100
# 3                 22332.439460  49078.000000                    97
# 4                  9025.067525  23675.000000                   117
# ...                        ...           ...                   ...
# 10905             15563.369440  37536.284785                   253
# 10906              5259.444853  61146.000000                    65
# 10907             23893.304100  39837.000000                   201
# 10908             11971.977650  64195.000000                   158
# 10909              6857.519928  37536.284785                   101
#
#        number_of_open_complaints  total_claim_amount
# 0                       0.361962          292.800000
# 1                       0.361962          744.924331
# 2                       0.361962          480.000000
# 3                       0.361962          484.013411
# 4                       0.361962          707.925645
# ...                          ...                 ...
# 10905                   0.361962         1214.400000
# 10906                   0.361962          273.018929
# 10907                   0.361962          381.306996
# 10908                   4.000000          618.288849
# 10909                   0.361962         1021.719397
#
# [10910 rows x 5 columns]

# %%
# categorical columns
ca_df.select_dtypes('object')
# Out:
#             state education gender     policy_type  vehicle_class  \
# 0         arizona   College      M  Corporate Auto  Four-Door Car
# 1      california   College      F   Personal Auto  Four-Door Car
# 2      washington  Bachelor      M   Personal Auto            SUV
# 3          oregon   College      M  Corporate Auto  Four-Door Car
# 4          oregon  Bachelor      F   Personal Auto  Four-Door Car
# ...           ...       ...    ...             ...            ...
# 10905      nevada  Bachelor      F   Personal Auto     Luxury Car
# 10906      oregon   College      F   Personal Auto  Four-Door Car
# 10907     arizona  Bachelor      F  Corporate Auto     Luxury SUV
# 10908  california   College      F   Personal Auto            SUV
# 10909           U  Bachelor      M   Personal Auto            SUV
#
#       sales_channel response   region
# 0             Agent       No  central
# 1       Call Center       No     west
# 2       Call Center       No     east
# 3            Branch      Yes    north
# 4            Branch       No    north
# ...             ...      ...      ...
# 10905           Web       No  central
# 10906        Branch       No    north
# 10907           Web       No  central
# 10908        Branch       No     west
# 10909           Web       No      NaN
#
# [10910 rows x 8 columns]

# %%
#check again if we have some missing values
# We can see missing values in the new column "region"
nulls_df = pd.DataFrame(round(ca_df.isna().sum()/len(ca_df),4)*100)
nulls_df = nulls_df.reset_index()
nulls_df.columns = ['header_name', 'percent_nulls']
nulls_df
# Out:
#                   header_name  percent_nulls
# 0                       state           0.00
# 1     customer_lifetime_value           0.00
# 2                   education           0.00
# 3                      gender           0.00
# 4                      income           0.00
# 5        monthly_premium_auto           0.00
# 6   number_of_open_complaints           0.00
# 7                 policy_type           0.00
# 8          total_claim_amount           0.00
# 9               vehicle_class           0.00
# 10              sales_channel           0.00
# 11                   response           0.00
# 12                     region           5.78

# %%
#I replace the NaN values with "0"
ca_df['region'] = ca_df['region'].fillna(0)

# %%
nulls_df = pd.DataFrame(round(ca_df.isna().sum()/len(ca_df),4)*100)
nulls_df = nulls_df.reset_index()
nulls_df.columns = ['header_name', 'percent_nulls']
nulls_df
# Out:
#                   header_name  percent_nulls
# 0                       state            0.0
# 1     customer_lifetime_value            0.0
# 2                   education            0.0
# 3                      gender            0.0
# 4                      income            0.0
# 5        monthly_premium_auto            0.0
# 6   number_of_open_complaints            0.0
# 7                 policy_type            0.0
# 8          total_claim_amount            0.0
# 9               vehicle_class            0.0
# 10              sales_channel            0.0
# 11                   response            0.0
# 12                     region            0.0

# %% [markdown]
# ## Plots

# %%
# we need the plot for the following:
# total number of responses: 

ca_df.response.value_counts()
# Out:
# No     9444
# Yes    1466
# Name: response, dtype: int64

# %%
total_response =ca_df.response.value_counts()

# %%
ca_df['response'].value_counts().plot(kind="bar")
plt.title("total number of responses",{"fontsize":18})
# Out:
# Text(0.5, 1.0, 'total number of responses')

# %%
# response rate by the sales channel.
ca_df.sales_channel.value_counts()
# Out:
# Agent          4121
# Branch         3022
# Call Center    2141
# Web            1626
# Name: sales_channel, dtype: int64

# %% [markdown]
# Response_rate= received answers number/ total answers
# Response_rate=1466/10910

# %%
response_labels ={
    "Yes":"1",
    "No":"0"
}

# %%
ca_df=ca_df.assign(yes_response=ca_df.response.map(response_labels))
ca_df
# Out:
#             state  customer_lifetime_value education gender        income  \
# 0         arizona              4809.216960   College      M  48029.000000
# 1      california              2228.525238   College      F  37536.284785
# 2      washington             14947.917300  Bachelor      M  22139.000000
# 3          oregon             22332.439460   College      M  49078.000000
# 4          oregon              9025.067525  Bachelor      F  23675.000000
# ...           ...                      ...       ...    ...           ...
# 10905      nevada             15563.369440  Bachelor      F  37536.284785
# 10906      oregon              5259.444853   College      F  61146.000000
# 10907     arizona             23893.304100  Bachelor      F  39837.000000
# 10908  california             11971.977650   College      F  64195.000000
# 10909           U              6857.519928  Bachelor      M  37536.284785
#
#        monthly_premium_auto  number_of_open_complaints     policy_type  \
# 0                        61                   0.361962  Corporate Auto
# 1                        64                   0.361962   Personal Auto
# 2                       100                   0.361962   Personal Auto
# 3                        97                   0.361962  Corporate Auto
# 4                       117                   0.361962   Personal Auto
# ...                     ...                        ...             ...
# 10905                   253                   0.361962   Personal Auto
# 10906                    65                   0.361962   Personal Auto
# 10907                   201                   0.361962  Corporate Auto
# 10908                   158                   4.000000   Personal Auto
# 10909                   101                   0.361962   Personal Auto
#
#        total_claim_amount  vehicle_class sales_channel response   region  \
# 0              292.800000  Four-Door Car         Agent       No  central
# 1              744.924331  Four-Door Car   Call Center       No     west
# 2              480.000000            SUV   Call Center       No     east
# 3              484.013411  Four-Door Car        Branch      Yes    north
# 4              707.925645  Four-Door Car        Branch       No    north
# ...                   ...            ...           ...      ...      ...
# 10905         1214.400000     Luxury Car           Web       No  central
# 10906          273.018929  Four-Door Car        Branch       No    north
# 10907          381.306996     Luxury SUV           Web       No  central
# 10908          618.288849            SUV        Branch       No     west
# 10909         1021.719397            SUV           Web       No        0
#
#       yes_response
# 0                0
# 1                0
# 2                0
# 3                1
# 4                0
# ...            ...
# 10905            0
# 10906            0
# 10907            0
# 10908            0
# 10909            0
#
# [10910 rows x 14 columns]

# %%
response_rate = ca_df.groupby(['response','sales_channel'])['yes_response'].count().reset_index()
response_rate
# Out:
#   response sales_channel  yes_response
# 0       No         Agent          3379
# 1       No        Branch          2696
# 2       No   Call Center          1920
# 3       No           Web          1449
# 4      Yes         Agent           742
# 5      Yes        Branch           326
# 6      Yes   Call Center           221
# 7      Yes           Web           177

# %%
sns.set_palette("RdYlGn")
fig,ax=plt.subplots(figsize=(6,6))
sns.barplot(x=response_rate["sales_channel"],y=response_rate["yes_response"],hue=response_rate["response"])
ax.set_title("Response rate by channel")
# Out:
# Text(0.5, 1.0, 'Response rate by channel')

# %%
#Show a plot of the response rate by the total claim amount.
#I create buckets in the variable total_claim_amount
pd.cut(ca_df['total_claim_amount'],4)
# Out:
# 0          (-2.794, 723.384]
# 1        (723.384, 1446.669]
# 2          (-2.794, 723.384]
# 3          (-2.794, 723.384]
# 4          (-2.794, 723.384]
#                 ...
# 10905    (723.384, 1446.669]
# 10906      (-2.794, 723.384]
# 10907      (-2.794, 723.384]
# 10908      (-2.794, 723.384]
# 10909    (723.384, 1446.669]
# Name: total_claim_amount, Length: 10910, dtype: category
# Categories (4, interval[float64]): [(-2.794, 723.384] < (723.384, 1446.669] < (1446.669, 2169.955] < (2169.955, 2893.24]]

# %%
#I create the label for the new column total_claim_amount_binned
total_claim_amount_labels = ['Low', 'Moderate', 'High', 'Very High']
ca_df['total_claim_amount_binned'] = pd.cut(ca_df['total_claim_amount'],4, labels=total_claim_amount_labels)

# %%
response_rate_c=ca_df.groupby(['response',"total_claim_amount_binned"])['yes_response'].count().reset_index()
response_rate_c
# Out:
#   response total_claim_amount_binned  yes_response
# 0       No                       Low          8239
# 1       No                  Moderate          1107
# 2       No                      High            86
# 3       No                 Very High            12
# 4      Yes                       Low          1341
# 5      Yes                  Moderate           125
# 6      Yes                      High             0
# 7      Yes                 Very High             0

# %%
sns.set_palette("colorblind")
fig,ax=plt.subplots(figsize=(6,6))
sns.barplot(x=response_rate_c["total_claim_amount_binned"],y=response_rate_c["yes_response"],hue=response_rate_c["response"])
ax.set_title("Response rate by the total claim amount")
# Out:
# Text(0.5, 1.0, 'Response rate by the total claim amount')

# %%
#Show a plot of the response rate by income.
#I create buckets for the column income
pd.cut(ca_df['income'],4)
# Out:
# 0         (32523.0, 55009.0]
# 1         (32523.0, 55009.0]
# 2        (9947.056, 32523.0]
# 3         (32523.0, 55009.0]
# 4        (9947.056, 32523.0]
#                 ...
# 10905     (32523.0, 55009.0]
# 10906     (55009.0, 77495.0]
# 10907     (32523.0, 55009.0]
# 10908     (55009.0, 77495.0]
# 10909     (32523.0, 55009.0]
# Name: income, Length: 10910, dtype: category
# Categories (4, interval[float64]): [(9947.056, 32523.0] < (32523.0, 55009.0] < (55009.0, 77495.0] < (77495.0, 99981.0]]

# %%
income_labels = ['Low', 'Lower_middel', 'Upper_middle', 'Hight']
ca_df['income_binned'] = pd.cut(ca_df['income'],4, labels=income_labels)

# %%
response_rate_i=ca_df.groupby(['response',"income_binned"])['yes_response'].count().reset_index()
response_rate_i
# Out:
#   response income_binned  yes_response
# 0       No           Low          2026
# 1       No  Lower_middel          4445
# 2       No  Upper_middle          1747
# 3       No         Hight          1226
# 4      Yes           Low           500
# 5      Yes  Lower_middel           487
# 6      Yes  Upper_middle           328
# 7      Yes         Hight           151

# %%
sns.set_palette("Blues_d")
fig,ax=plt.subplots(figsize=(6,6))
sns.barplot(x=response_rate_i["income_binned"],y=response_rate_i["yes_response"],hue=response_rate_i["response"])
ax.set_title("Response rate by income")
# Out:
# Text(0.5, 1.0, 'Response rate by income')

# %%
#I want to see the relation between the variables.

sns.pairplot(ca_df)

# %%
# Plot the Correlation Heatmap
#before, we can check the correlation

ca_df.corr()
# Out:
#                            customer_lifetime_value    income  \
# customer_lifetime_value                   1.000000  0.013773
# income                                    0.013773  1.000000
# monthly_premium_auto                      0.403069 -0.006235
# number_of_open_complaints                -0.033203  0.013433
# total_claim_amount                        0.232626 -0.244572
#
#                            monthly_premium_auto  number_of_open_complaints  \
# customer_lifetime_value                0.403069                  -0.033203
# income                                -0.006235                   0.013433
# monthly_premium_auto                   1.000000                  -0.011001
# number_of_open_complaints             -0.011001                   1.000000
# total_claim_amount                     0.631799                  -0.010617
#
#                            total_claim_amount
# customer_lifetime_value              0.232626
# income                              -0.244572
# monthly_premium_auto                 0.631799
# number_of_open_complaints           -0.010617
# total_claim_amount                   1.000000

# %%
sns.heatmap(ca_df.corr())
# Out:
# <AxesSubplot:>

# %%
ca_df.corr().to_csv("correllation.csv")

# %% [markdown]
# ## Numerical /Categorical variables

# %%
#I will get the numerical columns from ca_df.
#with this columns I will create a new dataframe called numerical_df

ca_df._get_numeric_data()
# Out:
#        customer_lifetime_value  income  monthly_premium_auto  \
# 0                       4809.0   48029                    61
# 2                      14948.0   22139                   100
# 3                      22332.0   49078                    97
# 6                       5035.0   37405                    63
# 7                       4956.0   87197                    63
# ...                        ...     ...                   ...
# 10902                   3579.0   28304                    91
# 10903                   2772.0   59855                    74
# 10906                   5259.0   61146                    65
# 10907                  23893.0   39837                   201
# 10908                  11972.0   64195                   158
#
#        months_since_last_claim  months_since_policy_inception  \
# 0                          7.0                             52
# 2                         34.0                             31
# 3                         10.0                              3
# 6                          8.0                             99
# 7                         35.0                             45
# ...                        ...                            ...
# 10902                     10.0                             30
# 10903                     30.0                             82
# 10906                      7.0                             68
# 10907                     11.0                             63
# 10908                      0.0                             27
#
#        number_of_open_complaints  number_of_policies  total_claim_amount
# 0                        0.38184                   3               293.0
# 2                        0.38184                   2               480.0
# 3                        0.38184                   2               484.0
# 6                        3.00000                   3               288.0
# 7                        0.38184                   3               247.0
# ...                          ...                 ...                 ...
# 10902                    2.00000                   1               655.0
# 10903                    4.00000                   1               355.0
# 10906                    0.38184                   3               273.0
# 10907                    0.38184                   2               381.0
# 10908                    4.00000                   3               618.0
#
# [6498 rows x 8 columns]

# %%
numerical_df=ca_df._get_numeric_data()

# %%
# Out:
#        customer_lifetime_value        income  monthly_premium_auto  \
# 0                  4809.216960  48029.000000                    61
# 1                  2228.525238  37536.284785                    64
# 2                 14947.917300  22139.000000                   100
# 3                 22332.439460  49078.000000                    97
# 4                  9025.067525  23675.000000                   117
# ...                        ...           ...                   ...
# 10905             15563.369440  37536.284785                   253
# 10906              5259.444853  61146.000000                    65
# 10907             23893.304100  39837.000000                   201
# 10908             11971.977650  64195.000000                   158
# 10909              6857.519928  37536.284785                   101
#
#        number_of_open_complaints  total_claim_amount
# 0                       0.361962          292.800000
# 1                       0.361962          744.924331
# 2                       0.361962          480.000000
# 3                       0.361962          484.013411
# 4                       0.361962          707.925645
# ...                          ...                 ...
# 10905                   0.361962         1214.400000
# 10906                   0.361962          273.018929
# 10907                   0.361962          381.306996
# 10908                   4.000000          618.288849
# 10909                   0.361962         1021.719397
#
# [10910 rows x 5 columns]

# %%
#I do the same for categorical dataframe

# %%
categorical_df=ca_df.select_dtypes('object')

# %% [markdown]
# ### Removing outliers
# We will use box plot to identify them and remove them

# %%
#In oder to check the outliers we need the boxplot of the numerical columns:
X =numerical_df

X.boxplot(figsize=(14,14))
# Out:
# <AxesSubplot:>

# %%
# We can see the "customer_lifetime_value" has many outliers. 
# 1. We need to identify the percentile 25 and the percentile 75
# irq: interquartile range

percentile25 = X['customer_lifetime_value'].quantile(0.25)
percentile75 = X['customer_lifetime_value'].quantile(0.75)
iqr = percentile75 - percentile25

# %%
# 2 Finding upper and lower limit

upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr

# %%
# 3 Finding Outliers
X[X['customer_lifetime_value'] > upper_limit]

X[X['customer_lifetime_value'] < lower_limit]
# Out:
# Empty DataFrame
# Columns: [customer_lifetime_value, income, monthly_premium_auto, number_of_open_complaints, total_claim_amount]
# Index: []

# %%
# 4 Trimming
new_X = X[X['customer_lifetime_value'] < upper_limit]
new_X.shape
# Out:
# (9926, 5)

# %%
# 5 Compare the plots after trimming

plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(X['customer_lifetime_value'])
plt.subplot(2,2,2)
sns.boxplot(X['customer_lifetime_value'])
plt.subplot(2,2,3)
sns.distplot(new_X['customer_lifetime_value'])
plt.subplot(2,2,4)
sns.boxplot(new_X['customer_lifetime_value'])
plt.show()
# Out:
# C:\Users\merce\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\merce\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\merce\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\merce\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# 6 Capping

new_X_cap = X.copy()
new_X_cap['customer_lifetime_value'] = np.where(
    new_X_cap['customer_lifetime_value'] > upper_limit,
    upper_limit,
    np.where(
        new_X_cap['customer_lifetime_value'] < lower_limit,
        lower_limit,
        new_X_cap['customer_lifetime_value']
    )
)

# %%
# 7 Compare the plots after capping 
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(X['customer_lifetime_value'])
plt.subplot(2,2,2)
sns.boxplot(X['customer_lifetime_value'])
plt.subplot(2,2,3)
sns.distplot(new_X_cap['customer_lifetime_value'])
plt.subplot(2,2,4)
sns.boxplot(new_X_cap['customer_lifetime_value'])
plt.show()
# Out:
# C:\Users\merce\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\merce\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\merce\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\merce\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
#  We also have to remove the outliers from **"montly_premium_ auto"**

# %%
# 1 We need to identify the percentile 25 and the percentile 75
# irq: interquartile range
percentile25 = X['monthly_premium_auto'].quantile(0.25)
percentile75 = X['monthly_premium_auto'].quantile(0.75)
iqr = percentile75 - percentile25

# %%
# 2 Finding upper and lower limit

upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr

# %%
# 3 Finding Outliers
X[X['monthly_premium_auto'] > upper_limit]

X[X['monthly_premium_auto'] < lower_limit]
# Out:
# Empty DataFrame
# Columns: [customer_lifetime_value, income, monthly_premium_auto, number_of_open_complaints, total_claim_amount]
# Index: []

# %%
# 4 Trimming
new_X = X[X['monthly_premium_auto'] < upper_limit]
new_X.shape
# Out:
# (10393, 5)

# %%
# 5 Compare the plots after trimming

plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(X['monthly_premium_auto'])
plt.subplot(2,2,2)
sns.boxplot(X['monthly_premium_auto'])
plt.subplot(2,2,3)
sns.distplot(new_X['monthly_premium_auto'])
plt.subplot(2,2,4)
sns.boxplot(new_X['monthly_premium_auto'])
plt.show()
# Out:
# C:\Users\merce\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\merce\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\merce\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\merce\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# 6 Capping

new_X_cap = X.copy()
new_X_cap['monthly_premium_auto'] = np.where(
    new_X_cap['monthly_premium_auto'] > upper_limit,
    upper_limit,
    np.where(
        new_X_cap['monthly_premium_auto'] < lower_limit,
        lower_limit,
        new_X_cap['monthly_premium_auto']
    )
)

# %%
# 7 Compare the plots after capping 
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(X['monthly_premium_auto'])
plt.subplot(2,2,2)
sns.boxplot(X['monthly_premium_auto'])
plt.subplot(2,2,3)
sns.distplot(new_X_cap['monthly_premium_auto'])
plt.subplot(2,2,4)
sns.boxplot(new_X_cap['monthly_premium_auto'])
plt.show()
# Out:
# C:\Users\merce\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\merce\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\merce\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\merce\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
#  We also have to remove the outliers from **"total_claim_amount"**

# %%
ca_df=ca_df[ca_df["monthly_premium_auto"]<160]

# %%
ca_df=ca_df[ca_df["customer_lifetime_value"]<16000]

# %%
sns.boxplot(ca_df['monthly_premium_auto'])
# Out:
# C:\Users\merce\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='monthly_premium_auto'>

# %%
X=ca_df.drop('total_claim_amount', axis=1)
Y=ca_df.total_claim_amount

# %%
X=X._get_numeric_data()

# %%
X
# Out:
#        customer_lifetime_value  income  monthly_premium_auto  \
# 0                       4809.0   48029                    61
# 2                      14948.0   22139                   100
# 6                       5035.0   37405                    63
# 7                       4956.0   87197                    63
# 8                       5990.0   66839                   154
# ...                        ...     ...                   ...
# 10901                   4548.0   33531                   116
# 10902                   3579.0   28304                    91
# 10903                   2772.0   59855                    74
# 10906                   5259.0   61146                    65
# 10908                  11972.0   64195                   158
#
#        months_since_last_claim  months_since_policy_inception  \
# 0                          7.0                             52
# 2                         34.0                             31
# 6                          8.0                             99
# 7                         35.0                             45
# 8                         33.0                             24
# ...                        ...                            ...
# 10901                     11.0                             15
# 10902                     10.0                             30
# 10903                     30.0                             82
# 10906                      7.0                             68
# 10908                      0.0                             27
#
#        number_of_open_complaints  number_of_policies
# 0                        0.38184                   3
# 2                        0.38184                   2
# 6                        3.00000                   3
# 7                        0.38184                   3
# 8                        0.38184                   1
# ...                          ...                 ...
# 10901                    0.38184                   1
# 10902                    2.00000                   1
# 10903                    4.00000                   1
# 10906                    0.38184                   3
# 10908                    4.00000                   3
#
# [5663 rows x 7 columns]

# %% [markdown]
# # Normality of the numerical variables

# %%
# we will use sns library to make distribution plots
fig.suptitle("Distribution plots")
sns.displot(numerical_df,x="customer_lifetime_value")
sns.displot(numerical_df, x="income")
sns.displot(numerical_df,x="monthly_premium_auto")
sns.displot(numerical_df, x="number_of_open_complaints")
sns.displot(numerical_df,x="total_claim_amount")

# %%
#use matplotlib to make histograms

fig,ax=plt.subplots(2,3,figsize=(15,15))
fig.suptitle('histograms')
ax[0,0].hist(ca_df["customer_lifetime_value"])
ax[0,0].set_title("customer_lifetime_value histogram")

ax[0,1].hist(ca_df['income'])
ax[0,1].set_title('income histogram')

ax[0,2].hist(ca_df["monthly_premium_auto"])
ax[0,2].set_title("monthly_premium_auto histogram")

ax[1,0].hist(ca_df['number_of_open_complaints'])
ax[1,0].set_title('number_of_open_complaints histogram')

ax[1,1].hist(ca_df['total_claim_amount'])
ax[1,1].set_title('total_claim_amount histogram')

# %% [markdown]
# The distribution of some numerical variables look like a normal distribution. For example:"customer lifetime value", "monthly premium auto", and "total claim amount"

# %%
ca_df

# %%
# We have to drop the columns created for plotting
ca_df.drop(["yes_response","total_claim_amount_binned","income_binned"],axis=1,inplace=True)

# %%
ca_df

# %%
# we use the correlation matrix to check the multicollinearity

corr = numerical_df.corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(9, 7))
    ax = sns.heatmap(corr, mask=mask,cmap='coolwarm', vmin=-1,vmax=1,annot=True, square=True)

# %% [markdown]
# As we do not have values >0.80. I do not delete any column from numerical_df dataframe

# %%
X =numerical_df
X

# %%
X.hist(figsize=(14,14))

# %%
# We use Power Transformation to transform all variables into normal distribution

sns.distplot((ca_df['total_claim_amount']), bins=20)

# %%
pt = PowerTransformer(method="box-cox")
med_total_claim_amount_trans=pt.fit_transform(ca_df['total_claim_amount'].to_numpy().reshape(-1,1))
sns.displot(med_total_claim_amount_trans)

# %%
sns.distplot((ca_df['customer_lifetime_value']), bins=20)

# %%
pt = PowerTransformer(method="box-cox")
med_customer_lifetime_value_trans=pt.fit_transform(ca_df['customer_lifetime_value'].to_numpy().reshape(-1,1))
sns.displot(med_customer_lifetime_value_trans)

# %%
sns.distplot((ca_df['monthly_premium_auto']), bins=20)

# %%
pt = PowerTransformer(method="box-cox")
med_monthly_premium_auto_trans=pt.fit_transform(ca_df['monthly_premium_auto'].to_numpy().reshape(-1,1))
sns.displot(med_monthly_premium_auto_trans)

# %%
sns.distplot((ca_df['number_of_open_complaints']), bins=20)

# %%
pt = PowerTransformer(method="box-cox")
med_number_of_open_complaints_trans=pt.fit_transform(ca_df['number_of_open_complaints'].to_numpy().reshape(-1,1))
sns.displot(med_number_of_open_complaints_trans)

# %%
sns.distplot((ca_df['income']), bins=20)

# %%
pt = PowerTransformer(method="box-cox")
med_income_trans=pt.fit_transform(ca_df['income'].to_numpy().reshape(-1,1))
sns.displot(med_income_trans)

# %%
ca_df

# %%
# We need to introduce the transform variables in the model

ca_df["med_customer_lifetime_value_trans"]= med_customer_lifetime_value_trans
ca_df["med_monthly_premium_auto_trans"]= med_monthly_premium_auto_trans
ca_df["med_number_of_open_complaints_trans"]= med_number_of_open_complaints_trans
ca_df["med_income_trans"]= med_income_trans
ca_df

# %%
# We need to delete the old columns

ca_df.drop(["customer_lifetime_value"],axis=1,inplace=True)
ca_df.drop(["monthly_premium_auto"],axis=1,inplace=True)
ca_df.drop(["number_of_open_complaints"],axis=1,inplace=True)
ca_df.drop(["income"],axis=1,inplace=True)
ca_df

# %%
ca_df

# %% [markdown]
# ### Predictive Modeling

# %% [markdown]
# ### XY split

# %%
X=ca_df.drop('total_claim_amount', axis=1)
Y=ca_df.total_claim_amount

# %%
X
# Out:
#             state  customer_lifetime_value response  coverage  \
# 0         arizona                   4809.0       No     Basic
# 2      washington                  14948.0       No     Basic
# 6      california                   5035.0       No     Basic
# 7      california                   4956.0       No     Basic
# 8      california                   5990.0      Yes   Premium
# ...           ...                      ...      ...       ...
# 10901  washington                   4548.0       No   Premium
# 10902  california                   3579.0       No  Extended
# 10903     arizona                   2772.0       No     Basic
# 10906      oregon                   5259.0       No     Basic
# 10908  california                  11972.0       No   Premium
#
#       employmentstatus gender  income location_code marital_status  \
# 0             Employed      M   48029      Suburban        Married
# 2             Employed      M   22139      Suburban         Single
# 6             Employed      F   37405         Urban        Married
# 7             Employed      M   87197         Urban         Single
# 8             Employed      M   66839      Suburban         Single
# ...                ...    ...     ...           ...            ...
# 10901         Employed      M   33531      Suburban        Married
# 10902         Employed      F   28304      Suburban        Married
# 10903         Employed      M   59855      Suburban        Married
# 10906         Employed      F   61146         Urban        Married
# 10908         Employed      F   64195         Urban       Divorced
#
#        monthly_premium_auto  ...  months_since_policy_inception  \
# 0                        61  ...                             52
# 2                       100  ...                             31
# 6                        63  ...                             99
# 7                        63  ...                             45
# 8                       154  ...                             24
# ...                     ...  ...                            ...
# 10901                   116  ...                             15
# 10902                    91  ...                             30
# 10903                    74  ...                             82
# 10906                    65  ...                             68
# 10908                   158  ...                             27
#
#        number_of_open_complaints  number_of_policies     policy_type  \
# 0                        0.38184                   3  Corporate Auto
# 2                        0.38184                   2   Personal Auto
# 6                        3.00000                   3  Corporate Auto
# 7                        0.38184                   3   Personal Auto
# 8                        0.38184                   1   Personal Auto
# ...                          ...                 ...             ...
# 10901                    0.38184                   1   Personal Auto
# 10902                    2.00000                   1   Personal Auto
# 10903                    4.00000                   1   Personal Auto
# 10906                    0.38184                   3   Personal Auto
# 10908                    4.00000                   3   Personal Auto
#
#           policy renew_offer_type sales_channel  vehicle_class vehicle_size  \
# 0      Corporate           Offer3         Agent  Four-Door Car      Medsize
# 2       Personal           Offer3   Call Center  Four-Door Car      Medsize
# 6      Corporate           Offer2        Branch  Four-Door Car      Medsize
# 7       Personal           Offer2        Branch   Two-Door Car      Medsize
# 8       Personal           Offer2        Branch     Sports Car      Medsize
# ...          ...              ...           ...            ...          ...
# 10901   Personal           Offer4         Agent   Two-Door Car      Medsize
# 10902   Personal           Offer2         Agent  Four-Door Car      Medsize
# 10903   Personal           Offer2        Branch   Two-Door Car      Medsize
# 10906   Personal           Offer2        Branch  Four-Door Car      Medsize
# 10908   Personal           Offer1        Branch  Four-Door Car      Medsize
#
#         region
# 0      central
# 2         east
# 6         west
# 7         west
# 8         west
# ...        ...
# 10901     east
# 10902     west
# 10903  central
# 10906    north
# 10908     west
#
# [5663 rows x 21 columns]

# %%
X =X._get_numeric_data()
X
# Out:
#        customer_lifetime_value  income  monthly_premium_auto  \
# 0                       4809.0   48029                    61
# 2                      14948.0   22139                   100
# 6                       5035.0   37405                    63
# 7                       4956.0   87197                    63
# 8                       5990.0   66839                   154
# ...                        ...     ...                   ...
# 10901                   4548.0   33531                   116
# 10902                   3579.0   28304                    91
# 10903                   2772.0   59855                    74
# 10906                   5259.0   61146                    65
# 10908                  11972.0   64195                   158
#
#        months_since_last_claim  months_since_policy_inception  \
# 0                          7.0                             52
# 2                         34.0                             31
# 6                          8.0                             99
# 7                         35.0                             45
# 8                         33.0                             24
# ...                        ...                            ...
# 10901                     11.0                             15
# 10902                     10.0                             30
# 10903                     30.0                             82
# 10906                      7.0                             68
# 10908                      0.0                             27
#
#        number_of_open_complaints  number_of_policies
# 0                        0.38184                   3
# 2                        0.38184                   2
# 6                        3.00000                   3
# 7                        0.38184                   3
# 8                        0.38184                   1
# ...                          ...                 ...
# 10901                    0.38184                   1
# 10902                    2.00000                   1
# 10903                    4.00000                   1
# 10906                    0.38184                   3
# 10908                    4.00000                   3
#
# [5663 rows x 7 columns]

# %%
# we get our train and test data set
X_train, X_test, y_train, y_test=train_test_split(X_scaled, Y, test_size=0.20, random_state=1000)

# %% [markdown]
# ### Normalize

# %%
#normalize numeric features / rescaling using Normalizer


X_scaled=StandardScaler().fit_transform(X)

# %%
X_scaled.shape
# Out:
# (9509, 4)

# %%
type(X_scaled)
# Out:
# numpy.ndarray

# %%
#variables from X data set are now normalized. 
X_scaled
# Out:
# array([[-0.41292926,  0.03849272, -1.15758511, -0.37580602],
#        [-1.25550445, -0.44301288, -1.02180656, -0.37580602],
#        [ 2.89727526, -1.14958679,  0.60753609, -0.37580602],
#        ...,
#        [-0.26593346,  0.64042548, -0.97654704, -0.37580602],
#        [ 1.92565478,  0.78034261,  3.23258812,  4.22296164],
#        [ 0.25582527, -0.44301288,  0.6527956 , -0.37580602]])

# %%
# we get our train and test data set
X_train, X_test, y_train, y_test=train_test_split(X_scaled, Y, test_size=0.20, random_state=1000)

# %% [markdown]
# ## Hot coding Categorical Variables

# %%
categorical_df=ca_df.select_dtypes('object')

# %%
categorical_df
# Out:
#             state             education gender     policy_type  vehicle_class  \
# 0         arizona               College      M  Corporate Auto  Four-Door Car
# 1      california               College      F   Personal Auto  Four-Door Car
# 2      washington              Bachelor      M   Personal Auto            SUV
# 4          oregon              Bachelor      F   Personal Auto  Four-Door Car
# 5               U  High School or Below      M   Personal Auto  Four-Door Car
# ...           ...                   ...    ...             ...            ...
# 10902  california  High School or Below      F   Personal Auto  Four-Door Car
# 10903     arizona               College      M   Personal Auto   Two-Door Car
# 10906      oregon               College      F   Personal Auto  Four-Door Car
# 10908  california               College      F   Personal Auto            SUV
# 10909           U              Bachelor      M   Personal Auto            SUV
#
#       sales_channel response   region yes_response
# 0             Agent       No  central            0
# 1       Call Center       No     west            0
# 2       Call Center       No     east            0
# 4            Branch       No    north            0
# 5             Agent       No        0            0
# ...             ...      ...      ...          ...
# 10902         Agent       No     west            0
# 10903        Branch       No  central            0
# 10906        Branch       No    north            0
# 10908        Branch       No     west            0
# 10909           Web       No        0            0
#
# [9509 rows x 9 columns]

# %%
ca_df.drop('yes_response',axis=1, inplace=True)

# %%
ca_df
# Out:
#             state  customer_lifetime_value             education gender  \
# 0         arizona              4809.216960               College      M
# 1      california              2228.525238               College      F
# 2      washington             14947.917300              Bachelor      M
# 4          oregon              9025.067525              Bachelor      F
# 5               U              4745.181764  High School or Below      M
# ...           ...                      ...                   ...    ...
# 10902  california              3579.023825  High School or Below      F
# 10903     arizona              2771.663013               College      M
# 10906      oregon              5259.444853               College      F
# 10908  california             11971.977650               College      F
# 10909           U              6857.519928              Bachelor      M
#
#              income  monthly_premium_auto  number_of_open_complaints  \
# 0      48029.000000                    61                   0.361962
# 1      37536.284785                    64                   0.361962
# 2      22139.000000                   100                   0.361962
# 4      23675.000000                   117                   0.361962
# 5      50549.000000                    61                   0.361962
# ...             ...                   ...                        ...
# 10902  28304.000000                    91                   2.000000
# 10903  59855.000000                    74                   4.000000
# 10906  61146.000000                    65                   0.361962
# 10908  64195.000000                   158                   4.000000
# 10909  37536.284785                   101                   0.361962
#
#           policy_type  total_claim_amount  vehicle_class sales_channel  \
# 0      Corporate Auto          292.800000  Four-Door Car         Agent
# 1       Personal Auto          744.924331  Four-Door Car   Call Center
# 2       Personal Auto          480.000000            SUV   Call Center
# 4       Personal Auto          707.925645  Four-Door Car        Branch
# 5       Personal Auto          292.800000  Four-Door Car         Agent
# ...               ...                 ...            ...           ...
# 10902   Personal Auto          655.200000  Four-Door Car         Agent
# 10903   Personal Auto          355.200000   Two-Door Car        Branch
# 10906   Personal Auto          273.018929  Four-Door Car        Branch
# 10908   Personal Auto          618.288849            SUV        Branch
# 10909   Personal Auto         1021.719397            SUV           Web
#
#       response   region total_claim_amount_binned income_binned
# 0           No  central                       Low  Lower_middel
# 1           No     west                  Moderate  Lower_middel
# 2           No     east                       Low           Low
# 4           No    north                       Low           Low
# 5           No        0                       Low  Lower_middel
# ...        ...      ...                       ...           ...
# 10902       No     west                       Low           Low
# 10903       No  central                       Low  Upper_middle
# 10906       No    north                       Low  Upper_middle
# 10908       No     west                       Low  Upper_middle
# 10909       No        0                  Moderate  Lower_middel
#
# [9509 rows x 15 columns]

# %%
# get dummies pandas
##pd.DataFrame(OneHotEncoder(drop='first').fit_transform(categoricals_features).toarray(),
## columns=OneHotEncoder(drop='first').fit(categoricals_features).get_feature_names(input_features=categoricals_features.columns)).head()

categorical_df=pd.get_dummies(categorical_df, drop_first=True)

# %%
categorical_df
# Out:
#        state_california  state_nevada  state_oregon  state_washington  \
# 0                     0             0             0                 0
# 2                     0             0             0                 1
# 6                     1             0             0                 0
# 7                     1             0             0                 0
# 8                     1             0             0                 0
# ...                 ...           ...           ...               ...
# 10901                 0             0             0                 1
# 10902                 1             0             0                 0
# 10903                 0             0             0                 0
# 10906                 0             0             1                 0
# 10908                 1             0             0                 0
#
#        response_Yes  coverage_Extended  coverage_Premium  \
# 0                 0                  0                 0
# 2                 0                  0                 0
# 6                 0                  0                 0
# 7                 0                  0                 0
# 8                 1                  0                 1
# ...             ...                ...               ...
# 10901             0                  0                 1
# 10902             0                  1                 0
# 10903             0                  0                 0
# 10906             0                  0                 0
# 10908             0                  0                 1
#
#        employmentstatus_Employed  employmentstatus_Medical Leave  \
# 0                              1                               0
# 2                              1                               0
# 6                              1                               0
# 7                              1                               0
# 8                              1                               0
# ...                          ...                             ...
# 10901                          1                               0
# 10902                          1                               0
# 10903                          1                               0
# 10906                          1                               0
# 10908                          1                               0
#
#        employmentstatus_Retired  ...  sales_channel_Branch  \
# 0                             0  ...                     0
# 2                             0  ...                     0
# 6                             0  ...                     1
# 7                             0  ...                     1
# 8                             0  ...                     1
# ...                         ...  ...                   ...
# 10901                         0  ...                     0
# 10902                         0  ...                     0
# 10903                         0  ...                     1
# 10906                         0  ...                     1
# 10908                         0  ...                     1
#
#        sales_channel_Call Center  sales_channel_Web  vehicle_class_Sports Car  \
# 0                              0                  0                         0
# 2                              1                  0                         0
# 6                              0                  0                         0
# 7                              0                  0                         0
# 8                              0                  0                         1
# ...                          ...                ...                       ...
# 10901                          0                  0                         0
# 10902                          0                  0                         0
# 10903                          0                  0                         0
# 10906                          0                  0                         0
# 10908                          0                  0                         0
#
#        vehicle_class_Two-Door Car  vehicle_size_Medsize  vehicle_size_Small  \
# 0                               0                     1                   0
# 2                               0                     1                   0
# 6                               0                     1                   0
# 7                               1                     1                   0
# 8                               0                     1                   0
# ...                           ...                   ...                 ...
# 10901                           1                     1                   0
# 10902                           0                     1                   0
# 10903                           1                     1                   0
# 10906                           0                     1                   0
# 10908                           0                     1                   0
#
#        region_east  region_north  region_west
# 0                0             0            0
# 2                1             0            0
# 6                0             0            1
# 7                0             0            1
# 8                0             0            1
# ...            ...           ...          ...
# 10901            1             0            0
# 10902            0             0            1
# 10903            0             0            0
# 10906            0             1            0
# 10908            0             0            1
#
# [5663 rows x 32 columns]

# %%
X
# Out:
#             state  customer_lifetime_value response  coverage  \
# 0         arizona                   4809.0       No     Basic
# 2      washington                  14948.0       No     Basic
# 6      california                   5035.0       No     Basic
# 7      california                   4956.0       No     Basic
# 8      california                   5990.0      Yes   Premium
# ...           ...                      ...      ...       ...
# 10901  washington                   4548.0       No   Premium
# 10902  california                   3579.0       No  Extended
# 10903     arizona                   2772.0       No     Basic
# 10906      oregon                   5259.0       No     Basic
# 10908  california                  11972.0       No   Premium
#
#       employmentstatus gender  income location_code marital_status  \
# 0             Employed      M   48029      Suburban        Married
# 2             Employed      M   22139      Suburban         Single
# 6             Employed      F   37405         Urban        Married
# 7             Employed      M   87197         Urban         Single
# 8             Employed      M   66839      Suburban         Single
# ...                ...    ...     ...           ...            ...
# 10901         Employed      M   33531      Suburban        Married
# 10902         Employed      F   28304      Suburban        Married
# 10903         Employed      M   59855      Suburban        Married
# 10906         Employed      F   61146         Urban        Married
# 10908         Employed      F   64195         Urban       Divorced
#
#        monthly_premium_auto  ...  months_since_policy_inception  \
# 0                        61  ...                             52
# 2                       100  ...                             31
# 6                        63  ...                             99
# 7                        63  ...                             45
# 8                       154  ...                             24
# ...                     ...  ...                            ...
# 10901                   116  ...                             15
# 10902                    91  ...                             30
# 10903                    74  ...                             82
# 10906                    65  ...                             68
# 10908                   158  ...                             27
#
#        number_of_open_complaints  number_of_policies     policy_type  \
# 0                        0.38184                   3  Corporate Auto
# 2                        0.38184                   2   Personal Auto
# 6                        3.00000                   3  Corporate Auto
# 7                        0.38184                   3   Personal Auto
# 8                        0.38184                   1   Personal Auto
# ...                          ...                 ...             ...
# 10901                    0.38184                   1   Personal Auto
# 10902                    2.00000                   1   Personal Auto
# 10903                    4.00000                   1   Personal Auto
# 10906                    0.38184                   3   Personal Auto
# 10908                    4.00000                   3   Personal Auto
#
#           policy renew_offer_type sales_channel  vehicle_class vehicle_size  \
# 0      Corporate           Offer3         Agent  Four-Door Car      Medsize
# 2       Personal           Offer3   Call Center  Four-Door Car      Medsize
# 6      Corporate           Offer2        Branch  Four-Door Car      Medsize
# 7       Personal           Offer2        Branch   Two-Door Car      Medsize
# 8       Personal           Offer2        Branch     Sports Car      Medsize
# ...          ...              ...           ...            ...          ...
# 10901   Personal           Offer4         Agent   Two-Door Car      Medsize
# 10902   Personal           Offer2         Agent  Four-Door Car      Medsize
# 10903   Personal           Offer2        Branch   Two-Door Car      Medsize
# 10906   Personal           Offer2        Branch  Four-Door Car      Medsize
# 10908   Personal           Offer1        Branch  Four-Door Car      Medsize
#
#         region
# 0      central
# 2         east
# 6         west
# 7         west
# 8         west
# ...        ...
# 10901     east
# 10902     west
# 10903  central
# 10906    north
# 10908     west
#
# [5663 rows x 21 columns]

# %% [markdown]
# ### apply linear regresion

# %% [markdown]
# modeling using statsmodels

# %%
X=pd.concat([X, categorical_df], axis=1) # concat numerical and categorical transformations

# %%
X_train, X_test, y_train, y_test=train_test_split(X, Y, test_size=0.20, random_state=1000)

# %%
std_scaler=StandardScaler().fit(X_train)

X_train_scaled=std_scaler.transform(X_train)
X_test_scaled=std_scaler.transform(X_test)

# %%
X_train_constant= sm.add_constant(X_train)
X_test_constant= sm.add_constant(X_test)  #adding a constant
model=sm.OLS(y_train,X_train_constant).fit()
predictions=model.predict(X_test_constant)

print_model=model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     total_claim_amount   R-squared:                       0.786
# Model:                            OLS   Adj. R-squared:                  0.785
# Method:                 Least Squares   F-statistic:                     486.8
# Date:                Wed, 10 Nov 2021   Prob (F-statistic):               0.00
# Time:                        18:32:24   Log-Likelihood:                -26869.
# No. Observations:                4530   AIC:                         5.381e+04
# Df Residuals:                    4495   BIC:                         5.403e+04
# Df Model:                          34
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                           -231.8762     12.652    -18.327      0.000    -256.681    -207.071
# customer_lifetime_value            0.0008      0.001      1.442      0.149      -0.000       0.002
# income                            -0.0002   6.89e-05     -3.060      0.002      -0.000   -7.58e-05
# monthly_premium_auto               3.9833      0.092     43.218      0.000       3.803       4.164
# months_since_last_claim            0.1083      0.136      0.797      0.425      -0.158       0.375
# months_since_policy_inception     -0.0551      0.049     -1.115      0.265      -0.152       0.042
# number_of_open_complaints         -0.1079      1.718     -0.063      0.950      -3.476       3.260
# number_of_policies                -2.7384      1.804     -1.518      0.129      -6.276       0.799
# state_california                   0.2287      1.948      0.117      0.907      -3.590       4.048
# state_nevada                      -2.6423      5.312     -0.497      0.619     -13.056       7.771
# state_oregon                      -0.3080      2.020     -0.152      0.879      -4.269       3.653
# state_washington                   1.2368      2.789      0.443      0.657      -4.230       6.704
# response_Yes                      -6.5265      4.532     -1.440      0.150     -15.412       2.359
# coverage_Extended                  0.3417      3.459      0.099      0.921      -6.439       7.122
# coverage_Premium                   2.9930      6.161      0.486      0.627      -9.085      15.071
# employmentstatus_Employed         -3.0666      6.273     -0.489      0.625     -15.365       9.232
# employmentstatus_Medical Leave     5.9975      7.667      0.782      0.434      -9.034      21.029
# employmentstatus_Retired           2.1873      9.321      0.235      0.814     -16.086      20.461
# gender_M                           3.2546      2.747      1.185      0.236      -2.130       8.639
# location_code_Suburban           352.9943      3.568     98.947      0.000     346.000     359.988
# location_code_Urban              206.0118      3.941     52.269      0.000     198.285     213.739
# marital_status_Married            -3.0583      3.840     -0.796      0.426     -10.587       4.471
# marital_status_Single              0.4458      4.800      0.093      0.926      -8.965       9.856
# policy_type_Personal Auto          2.3378      1.654      1.413      0.158      -0.905       5.580
# policy_type_Special Auto           4.6939      3.485      1.347      0.178      -2.137      11.525
# policy_Personal                    2.3378      1.654      1.413      0.158      -0.905       5.580
# policy_Special                     4.6939      3.485      1.347      0.178      -2.137      11.525
# renew_offer_type_Offer2            8.5949      3.462      2.483      0.013       1.808      15.381
# renew_offer_type_Offer3            3.7964      4.151      0.915      0.360      -4.341      11.933
# renew_offer_type_Offer4            6.0616      4.671      1.298      0.194      -3.095      15.218
# sales_channel_Branch               8.1564      3.423      2.383      0.017       1.446      14.867
# sales_channel_Call Center         -1.2805      3.868     -0.331      0.741      -8.864       6.303
# sales_channel_Web                  4.3955      4.217      1.042      0.297      -3.872      12.663
# vehicle_class_Sports Car         -18.9258      6.953     -2.722      0.007     -32.557      -5.295
# vehicle_class_Two-Door Car         3.4940      3.434      1.017      0.309      -3.239      10.227
# vehicle_size_Medsize               5.4802      4.520      1.213      0.225      -3.381      14.341
# vehicle_size_Small                14.3739      5.316      2.704      0.007       3.951      24.796
# region_east                        1.2368      2.789      0.443      0.657      -4.230       6.704
# region_north                      -0.3080      2.020     -0.152      0.879      -4.269       3.653
# region_west                        0.2287      1.948      0.117      0.907      -3.590       4.048
# ==============================================================================
# Omnibus:                     1996.614   Durbin-Watson:                   1.975
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            16856.459
# Skew:                           1.897   Prob(JB):                         0.00
# Kurtosis:                      11.655   Cond. No.                     1.11e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.18e-19. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
X_train_scaled_constant= sm.add_constant(X_train_scaled)
X_test_scaled_constant= sm.add_constant(X_test_scaled)  #adding a constant
model=sm.OLS(y_train,X_train_scaled_constant).fit()
predictions=model.predict(X_test_scaled_constant)

print_model=model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     total_claim_amount   R-squared:                       0.786
# Model:                            OLS   Adj. R-squared:                  0.785
# Method:                 Least Squares   F-statistic:                     486.8
# Date:                Wed, 10 Nov 2021   Prob (F-statistic):               0.00
# Time:                        18:33:14   Log-Likelihood:                -26869.
# No. Observations:                4530   AIC:                         5.381e+04
# Df Residuals:                    4495   BIC:                         5.403e+04
# Df Model:                          34
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        342.9276      1.359    252.257      0.000     340.262     345.593
# x1             2.5916      1.797      1.442      0.149      -0.932       6.115
# x2            -5.1331      1.677     -3.060      0.002      -8.421      -1.845
# x3            86.3252      1.997     43.218      0.000      82.409      90.241
# x4             1.0913      1.369      0.797      0.425      -1.593       3.775
# x5            -1.5362      1.377     -1.115      0.265      -4.236       1.164
# x6            -0.0857      1.365     -0.063      0.950      -2.762       2.591
# x7            -2.4706      1.628     -1.518      0.129      -5.662       0.721
# x8             0.1084      0.923      0.117      0.907      -1.701       1.918
# x9            -0.7950      1.598     -0.497      0.619      -3.928       2.338
# x10           -0.1384      0.908     -0.152      0.879      -1.918       1.641
# x11            0.3481      0.785      0.443      0.657      -1.191       1.887
# x12           -2.1710      1.508     -1.440      0.150      -5.127       0.785
# x13            0.1564      1.583      0.099      0.921      -2.947       3.260
# x14            0.7735      1.592      0.486      0.627      -2.348       3.895
# x15           -1.1349      2.322     -0.489      0.625      -5.687       3.417
# x16            1.4868      1.901      0.782      0.434      -2.240       5.213
# x17            0.4133      1.761      0.235      0.814      -3.040       3.867
# x18            1.6267      1.373      1.185      0.236      -1.065       4.318
# x19          176.3699      1.782     98.947      0.000     172.875     179.864
# x20           86.3764      1.653     52.269      0.000      83.137      89.616
# x21           -1.4329      1.799     -0.796      0.426      -4.960       2.095
# x22            0.1645      1.771      0.093      0.926      -3.307       3.636
# x23            1.0354      0.733      1.413      0.158      -0.401       2.472
# x24            0.9869      0.733      1.347      0.178      -0.449       2.423
# x25            1.0354      0.733      1.413      0.158      -0.401       2.472
# x26            0.9869      0.733      1.347      0.178      -0.449       2.423
# x27            4.0777      1.642      2.483      0.013       0.858       7.297
# x28            1.4073      1.539      0.915      0.360      -1.609       4.424
# x29            2.0058      1.546      1.298      0.194      -1.024       5.036
# x30            3.6645      1.538      2.383      0.017       0.650       6.679
# x31           -0.5064      1.530     -0.331      0.741      -3.505       2.492
# x32            1.5728      1.509      1.042      0.297      -1.386       4.531
# x33           -4.0595      1.491     -2.722      0.007      -6.983      -1.136
# x34            1.4455      1.421      1.017      0.309      -1.340       4.231
# x35            2.4936      2.056      1.213      0.225      -1.538       6.525
# x36            5.6195      2.078      2.704      0.007       1.545       9.694
# x37            0.3481      0.785      0.443      0.657      -1.191       1.887
# x38           -0.1384      0.908     -0.152      0.879      -1.918       1.641
# x39            0.1084      0.923      0.117      0.907      -1.701       1.918
# ==============================================================================
# Omnibus:                     1996.614   Durbin-Watson:                   1.975
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            16856.459
# Skew:                           1.897   Prob(JB):                         0.00
# Kurtosis:                      11.655   Cond. No.                     6.73e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.91e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
model.params.iloc[1:]
# Out:
# x1       2.591623
# x2      -5.133067
# x3      86.325169
# x4       1.091261
# x5      -1.536188
# x6      -0.085721
# x7      -2.470648
# x8       0.108367
# x9      -0.795010
# x10     -0.138402
# x11      0.348118
# x12     -2.171022
# x13      0.156390
# x14      0.773475
# x15     -1.134933
# x16      1.486793
# x17      0.413337
# x18      1.626708
# x19    176.369861
# x20     86.376424
# x21     -1.432879
# x22      0.164453
# x23      1.035440
# x24      0.986940
# x25      1.035440
# x26      0.986940
# x27      4.077700
# x28      1.407299
# x29      2.005821
# x30      3.664521
# x31     -0.506379
# x32      1.572829
# x33     -4.059457
# x34      1.445479
# x35      2.493556
# x36      5.619512
# x37      0.348118
# x38     -0.138402
# x39      0.108367
# dtype: float64

# %%
features_importances = pd.DataFrame(data={
    'Attribute': X_train.columns,
    'Importance': model.params.iloc[1:]
})
features_importances = features_importances.sort_values(by='Importance', ascending=False)

# %%
features_importances
# Out:
#                           Attribute  Importance
# x19          location_code_Suburban  176.369861
# x20             location_code_Urban   86.376424
# x3             monthly_premium_auto   86.325169
# x36              vehicle_size_Small    5.619512
# x27         renew_offer_type_Offer2    4.077700
# x30            sales_channel_Branch    3.664521
# x1          customer_lifetime_value    2.591623
# x35            vehicle_size_Medsize    2.493556
# x29         renew_offer_type_Offer4    2.005821
# x18                        gender_M    1.626708
# x32               sales_channel_Web    1.572829
# x16  employmentstatus_Medical Leave    1.486793
# x34      vehicle_class_Two-Door Car    1.445479
# x28         renew_offer_type_Offer3    1.407299
# x4          months_since_last_claim    1.091261
# x25                 policy_Personal    1.035440
# x23       policy_type_Personal Auto    1.035440
# x24        policy_type_Special Auto    0.986940
# x26                  policy_Special    0.986940
# x14                coverage_Premium    0.773475
# x17        employmentstatus_Retired    0.413337
# x11                state_washington    0.348118
# x37                     region_east    0.348118
# x22           marital_status_Single    0.164453
# x13               coverage_Extended    0.156390
# x8                 state_california    0.108367
# x39                     region_west    0.108367
# x6        number_of_open_complaints   -0.085721
# x10                    state_oregon   -0.138402
# x38                    region_north   -0.138402
# x31       sales_channel_Call Center   -0.506379
# x9                     state_nevada   -0.795010
# x15       employmentstatus_Employed   -1.134933
# x21          marital_status_Married   -1.432879
# x5    months_since_policy_inception   -1.536188
# x12                    response_Yes   -2.171022
# x7               number_of_policies   -2.470648
# x33        vehicle_class_Sports Car   -4.059457
# x2                           income   -5.133067

# %% [markdown]
# # modeling using scikit Learn

# %%
X_train, X_test, y_train, y_test=train_test_split(X_scaled, Y, test_size=.20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-103-b67b60448fde> in <module>
# ----> 1 X_train, X_test, y_train, y_test=train_test_split(X_scaled, Y, test_size=.20)
#       2
#
# NameError: name 'X_scaled' is not defined

# %%
model=LinearRegression()    # model
model.fit(X_train, y_train)

# %%
model.coef_

# %%
y_pred=model.predict(X_test)

# %%
y_pred

# %%
result=pd.DataFrame({"y_test":y_test,"y_pred":y_pred})

# %%
# Make an scatter plot y_pred vs y
# What kind of plot you will get if all the all the predictions are ok?
# A stright line

fig, ax = plt.subplots(1,2,figsize=(9,4))
ax[0].plot(y_pred, y_test, 'o')
ax[0].set_xlabel("y_test")
ax[0].set_ylabel("y_pred")
ax[0].set_title("Test Set -Predicted vs real")

# Get a histogram of the residuals ie: y - y_pred.  Homoscdasticity
# It resembles a normal distribution?
ax[1].hist(y_test - y_pred)
ax[1].set_xlabel("Test y-y_pred")
ax[1].set_title("Test Set Residual histogram")

# %% [markdown]
# ### now using sns

# %%
sns.regplot(x='y_pred',y='y_test', data=result, scatter_kws={"color": "purple"}, line_kws={"color": "black"})

# %% [markdown]
# ### Evaluating predictions

# %% [markdown]
# # ME: mean error
# ME = np.mean( Y - y_pred )

# %% [markdown]
# ### MAE: mean absolute error
# MAE = np.mean( np.abs( y - y_pred ) )

# %%
print(mae(y_test,y_pred))

# %% [markdown]
# ### MSE: mean squared error
# MSE = np.mean( np.power( y - y_pred , 2 ) )

# %%
print(mse(y_test,y_pred))

# %%
R2=r2_score(y_test,y_pred)
R2

# %%
Adj_R2= 1 - (1-R2)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
Adj_R2

# %%
# MAPE: mean absolute percentual error
MAPE = np.mean( np.abs( y - y_pred) / y )
